# %% [markdown]
# # Import libraries

# %%
import pandas as pd
import yfinance as yf
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

import statsmodels.api as sm
from statsmodels.tsa.stattools import adfuller

from linearmodels import PanelOLS, RandomEffects

from stargazer.stargazer import Stargazer
from statsmodels.formula.api import ols

#!pip install patsy
#!pip install transliterate
from transliterate import translit

from sklearn.svm import LinearSVC
from sklearn.feature_selection import SelectFromModel

import pandas_datareader as dr

import lightgbm as lgbm
from pandas.plotting import scatter_matrix

import random
random.seed(13)

from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import uniform
from scipy.stats import loguniform

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Download data

# %%
data = pd.read_csv('final_data_without_prefs_and_with_HAMADA_factors.csv')
data_ret = pd.read_csv('data_ret.csv')
data_ret.drop(columns=['Unnamed: 0'], inplace=True)
#data_ret.set_index('Date', inplace=True)
data.set_index('Date', inplace = True)
macro_data = pd.read_csv('macro_data.csv')
macro_data.set_index('Date', inplace = True)

# %% [markdown]
# # Summary for R2 adjusted and MSE quality metrics for classical multifactor models and their extensions

# %% [markdown]
# ## CAPM

# %%
lag_autolag_return_30 = 30
lag_autolag_return_60 = 60
lag_autolag_return_90 = 90
lag_30 = 30
lag_60 = 60
lag_90 = 90

r_2_results_capm = []
mse_results_capm = []

for name in data_ret.columns[2:]:
    
    df1 = data[[name, 'Hamada_beta_MRP_for_{}'.format(name[7:11]), 'risk_free_rate_based_on_g_curve',
                 'Hamada_d_mcap_ratio_SMB_for_{}'.format(name[7:11]),
                 'Hamada_d_mcap_ratio_HML_for_{}'.format(name[7:11]),
                 'MOM']].dropna()
    df_autolag = pd.DataFrame(data[name] - data['risk_free_rate_based_on_g_curve']).rename(columns = {0:'{}_premium_lag_{}_days'.format(name[7:], lag_autolag_return_30)})
    df_autolag = pd.DataFrame(df_autolag['{}_premium_lag_{}_days'.format(name[7:], lag_autolag_return_30)].shift(lag_autolag_return_30).dropna())
    
    df_autolag_2 = pd.DataFrame(data[name] - data['risk_free_rate_based_on_g_curve']).rename(columns = {0:'{}_premium_lag_{}_days'.format(name[7:], lag_autolag_return_60)})
    df_autolag_2 = pd.DataFrame(df_autolag_2['{}_premium_lag_{}_days'.format(name[7:], lag_autolag_return_60)].shift(lag_autolag_return_60).dropna())
    
    df_autolag_3 = pd.DataFrame(data[name] - data['risk_free_rate_based_on_g_curve']).rename(columns = {0:'{}_premium_lag_{}_days'.format(name[7:], lag_autolag_return_90)})
    df_autolag_3 = pd.DataFrame(df_autolag_3['{}_premium_lag_{}_days'.format(name[7:], lag_autolag_return_90)].shift(lag_autolag_return_90).dropna())
    
    df2 = data[['Hamada_d_mcap_ratio_SMB_for_{}'.format(name[7:11]),
            'Hamada_d_mcap_ratio_HML_for_{}'.format(name[7:11]), 'MOM']].shift(lag_30).dropna()
    
    
    
    df2.rename(columns = {'Hamada_d_mcap_ratio_SMB_for_{}'.format(name[7:11]):'Hamada_d_mcap_ratio_SMB_for_{}_lag_{}_days'.format(name[7:11], lag_30),
                          'Hamada_d_mcap_ratio_HML_for_{}'.format(name[7:11]):'Hamada_d_mcap_ratio_HML_for_{}_lag_{}_days'.format(name[7:11], lag_30), 
                          'MOM':'MOM_lag_{}_days'.format(lag_30)}, inplace = True)
    
    result = pd.concat([df1, df2], axis=1, join="inner")
    
    df3 = data[['Hamada_d_mcap_ratio_SMB_for_{}'.format(name[7:11]),
            'Hamada_d_mcap_ratio_HML_for_{}'.format(name[7:11]), 'MOM']].shift(lag_60).dropna()
    
    df3.rename(columns = {'Hamada_d_mcap_ratio_SMB_for_{}'.format(name[7:11]):'Hamada_d_mcap_ratio_SMB_for_{}_lag_{}_days'.format(name[7:11], lag_60),
                          'Hamada_d_mcap_ratio_HML_for_{}'.format(name[7:11]):'Hamada_d_mcap_ratio_HML_for_{}_lag_{}_days'.format(name[7:11], lag_60), 
                          'MOM':'MOM_lag_{}_days'.format(lag_60)}, inplace = True)
    
    result = pd.concat([result, df3], axis=1, join="inner")
    
    df4 = data[['Hamada_d_mcap_ratio_SMB_for_{}'.format(name[7:11]),
            'Hamada_d_mcap_ratio_HML_for_{}'.format(name[7:11]), 'MOM']].shift(lag_90).dropna()
    
    df4.rename(columns = {'Hamada_d_mcap_ratio_SMB_for_{}'.format(name[7:11]):'Hamada_d_mcap_ratio_SMB_for_{}_lag_{}_days'.format(name[7:11], lag_90),
                          'Hamada_d_mcap_ratio_HML_for_{}'.format(name[7:11]):'Hamada_d_mcap_ratio_HML_for_{}_lag_{}_days'.format(name[7:11], lag_90), 
                          'MOM':'MOM_lag_{}_days'.format(lag_90)}, inplace = True)
    
    result = pd.concat([result, df4], axis=1, join="inner")
    
    result = pd.merge(result, macro_data, left_index=True, right_index=True)
    result = pd.merge(result, df_autolag, left_index=True, right_index=True)
    result = pd.merge(result, df_autolag_2, left_index=True, right_index=True)
    result = pd.merge(result, df_autolag_3, left_index=True, right_index=True)
    
    Base = result.dropna()
    
    Y = pd.DataFrame(Base[name] - Base['risk_free_rate_based_on_g_curve'])
    Y.rename(columns = {0:'{} - risk free rate'.format(name)}, inplace = True)
    X = Base[['Hamada_beta_MRP_for_{}'.format(name[7:11])]]
    model = sm.OLS(Y,X)
    results = model.fit(cov_type = 'HC1')
    print('###################################################################################')
    print(name[7:11])
    print(results.summary())
    
    print(results)
    r_2_results_capm.append(results.rsquared_adj)
    mse_results_capm.append(results.mse_resid)
# Out:
# ###################################################################################
# SBER
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_SBER_RM_Equity - risk free rate   R-squared (uncentered):                   0.403
# Model:                                                OLS   Adj. R-squared (uncentered):              0.403
# Method:                                     Least Squares   F-statistic:                              232.5
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                    1.00e-49
# Time:                                            19:27:31   Log-Likelihood:                          2245.3
# No. Observations:                                    1979   AIC:                                     -4489.
# Df Residuals:                                        1978   BIC:                                     -4483.
# Df Model:                                               1
# Covariance Type:                                      HC1
# ============================================================================================
#                                coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_SBER     0.4437      0.029     15.249      0.000       0.387       0.501
# ==============================================================================
# Omnibus:                      231.678   Durbin-Watson:                   0.083
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              425.699
# Skew:                          -0.760   Prob(JB):                     3.64e-93
# Kurtosis:                       4.689   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe6e923d730>
# ###################################################################################
# GAZP
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_GAZP_RM_Equity - risk free rate   R-squared (uncentered):                   0.618
# Model:                                                OLS   Adj. R-squared (uncentered):              0.618
# Method:                                     Least Squares   F-statistic:                              2048.
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                   1.29e-307
# Time:                                            19:27:31   Log-Likelihood:                          2901.2
# No. Observations:                                    1979   AIC:                                     -5800.
# Df Residuals:                                        1978   BIC:                                     -5795.
# Df Model:                                               1
# Covariance Type:                                      HC1
# ============================================================================================
#                                coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_GAZP     0.7438      0.016     45.259      0.000       0.712       0.776
# ==============================================================================
# Omnibus:                      619.607   Durbin-Watson:                   0.072
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2850.951
# Skew:                           1.427   Prob(JB):                         0.00
# Kurtosis:                       8.141   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe6d8d1a280>
# ###################################################################################
# LKOH
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_LKOH_RM_Equity - risk free rate   R-squared (uncentered):                   0.677
# Model:                                                OLS   Adj. R-squared (uncentered):              0.677
# Method:                                     Least Squares   F-statistic:                              1967.
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                   8.37e-299
# Time:                                            19:27:31   Log-Likelihood:                          3332.9
# No. Observations:                                    1979   AIC:                                     -6664.
# Df Residuals:                                        1978   BIC:                                     -6658.
# Df Model:                                               1
# Covariance Type:                                      HC1
# ============================================================================================
#                                coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_LKOH     0.8998      0.020     44.347      0.000       0.860       0.940
# ==============================================================================
# Omnibus:                       70.047   Durbin-Watson:                   0.125
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              108.753
# Skew:                          -0.322   Prob(JB):                     2.42e-24
# Kurtosis:                       3.951   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe719fd4dc0>
# ###################################################################################
# GMKN
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_GMKN_RM_Equity - risk free rate   R-squared (uncentered):                   0.427
# Model:                                                OLS   Adj. R-squared (uncentered):              0.427
# Method:                                     Least Squares   F-statistic:                              1086.
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                   3.46e-190
# Time:                                            19:27:31   Log-Likelihood:                          2660.0
# No. Observations:                                    1979   AIC:                                     -5318.
# Df Residuals:                                        1978   BIC:                                     -5312.
# Df Model:                                               1
# Covariance Type:                                      HC1
# ============================================================================================
#                                coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_GMKN     0.7533      0.023     32.951      0.000       0.708       0.798
# ==============================================================================
# Omnibus:                        7.683   Durbin-Watson:                   0.130
# Prob(Omnibus):                  0.021   Jarque-Bera (JB):                7.714
# Skew:                           0.132   Prob(JB):                       0.0211
# Kurtosis:                       3.154   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe719fd4f10>
# ###################################################################################
# NVTK
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_NVTK_RM_Equity - risk free rate   R-squared (uncentered):                   0.413
# Model:                                                OLS   Adj. R-squared (uncentered):              0.413
# Method:                                     Least Squares   F-statistic:                              1019.
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                   1.03e-180
# Time:                                            19:27:31   Log-Likelihood:                          2645.7
# No. Observations:                                    1979   AIC:                                     -5289.
# Df Residuals:                                        1978   BIC:                                     -5284.
# Df Model:                                               1
# Covariance Type:                                      HC1
# ============================================================================================
#                                coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_NVTK     0.8031      0.025     31.922      0.000       0.754       0.852
# ==============================================================================
# Omnibus:                       11.664   Durbin-Watson:                   0.113
# Prob(Omnibus):                  0.003   Jarque-Bera (JB):               13.088
# Skew:                           0.126   Prob(JB):                      0.00144
# Kurtosis:                       3.308   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe719ea7e80>
# ###################################################################################
# SNGS
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_SNGS_RM_Equity - risk free rate   R-squared (uncentered):                   0.539
# Model:                                                OLS   Adj. R-squared (uncentered):              0.538
# Method:                                     Least Squares   F-statistic:                              1245.
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                   2.96e-196
# Time:                                            19:27:31   Log-Likelihood:                          1615.0
# No. Observations:                                    1417   AIC:                                     -3228.
# Df Residuals:                                        1416   BIC:                                     -3223.
# Df Model:                                               1
# Covariance Type:                                      HC1
# ============================================================================================
#                                coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_SNGS     1.2592      0.036     35.290      0.000       1.189       1.329
# ==============================================================================
# Omnibus:                      186.227   Durbin-Watson:                   0.087
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              370.841
# Skew:                           0.800   Prob(JB):                     2.97e-81
# Kurtosis:                       4.929   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe6e92e2b80>
# ###################################################################################
# PLZL
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_PLZL_RM_Equity - risk free rate   R-squared (uncentered):                   0.003
# Model:                                                OLS   Adj. R-squared (uncentered):              0.002
# Method:                                     Least Squares   F-statistic:                              1.254
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                       0.263
# Time:                                            19:27:31   Log-Likelihood:                          609.41
# No. Observations:                                     753   AIC:                                     -1217.
# Df Residuals:                                         752   BIC:                                     -1212.
# Df Model:                                               1
# Covariance Type:                                      HC1
# ============================================================================================
#                                coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_PLZL    -0.0788      0.070     -1.120      0.263      -0.217       0.059
# ==============================================================================
# Omnibus:                       17.376   Durbin-Watson:                   0.070
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               25.831
# Skew:                           0.205   Prob(JB):                     2.46e-06
# Kurtosis:                       3.809   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe719ea3f40>
# ###################################################################################
# TATN
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_TATN_RM_Equity - risk free rate   R-squared (uncentered):                   0.658
# Model:                                                OLS   Adj. R-squared (uncentered):              0.658
# Method:                                     Least Squares   F-statistic:                              2622.
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                        0.00
# Time:                                            19:27:31   Log-Likelihood:                          2794.7
# No. Observations:                                    1979   AIC:                                     -5587.
# Df Residuals:                                        1978   BIC:                                     -5582.
# Df Model:                                               1
# Covariance Type:                                      HC1
# ============================================================================================
#                                coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_TATN     1.1876      0.023     51.201      0.000       1.142       1.233
# ==============================================================================
# Omnibus:                       33.229   Durbin-Watson:                   0.153
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               35.193
# Skew:                           0.295   Prob(JB):                     2.28e-08
# Kurtosis:                       3.279   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe6d8d10820>
# ###################################################################################
# ROSN
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_ROSN_RM_Equity - risk free rate   R-squared (uncentered):                   0.574
# Model:                                                OLS   Adj. R-squared (uncentered):              0.574
# Method:                                     Least Squares   F-statistic:                              1080.
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                   6.57e-189
# Time:                                            19:27:31   Log-Likelihood:                          2614.1
# No. Observations:                                    1956   AIC:                                     -5226.
# Df Residuals:                                        1955   BIC:                                     -5221.
# Df Model:                                               1
# Covariance Type:                                      HC1
# ============================================================================================
#                                coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_ROSN     0.7144      0.022     32.858      0.000       0.672       0.757
# ==============================================================================
# Omnibus:                       78.809   Durbin-Watson:                   0.078
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              170.805
# Skew:                           0.247   Prob(JB):                     8.13e-38
# Kurtosis:                       4.361   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe6e923d6a0>
# ###################################################################################
# MGNT
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_MGNT_RM_Equity - risk free rate   R-squared (uncentered):                   0.164
# Model:                                                OLS   Adj. R-squared (uncentered):              0.164
# Method:                                     Least Squares   F-statistic:                              424.1
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                    1.57e-85
# Time:                                            19:27:31   Log-Likelihood:                          1828.1
# No. Observations:                                    1979   AIC:                                     -3654.
# Df Residuals:                                        1978   BIC:                                     -3649.
# Df Model:                                               1
# Covariance Type:                                      HC1
# ============================================================================================
#                                coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_MGNT     0.4601      0.022     20.593      0.000       0.416       0.504
# ==============================================================================
# Omnibus:                      322.303   Durbin-Watson:                   0.080
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              715.085
# Skew:                          -0.933   Prob(JB):                    5.26e-156
# Kurtosis:                       5.278   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe6e923d9a0>
# ###################################################################################
# MTSS
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_MTSS_RM_Equity - risk free rate   R-squared (uncentered):                   0.417
# Model:                                                OLS   Adj. R-squared (uncentered):              0.416
# Method:                                     Least Squares   F-statistic:                              1089.
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                   1.11e-190
# Time:                                            19:27:31   Log-Likelihood:                          2516.5
# No. Observations:                                    1979   AIC:                                     -5031.
# Df Residuals:                                        1978   BIC:                                     -5025.
# Df Model:                                               1
# Covariance Type:                                      HC1
# ============================================================================================
#                                coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_MTSS     0.6160      0.019     33.005      0.000       0.579       0.653
# ==============================================================================
# Omnibus:                      407.526   Durbin-Watson:                   0.090
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1355.232
# Skew:                          -1.010   Prob(JB):                    5.19e-295
# Kurtosis:                       6.515   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe71a006df0>
# ###################################################################################
# MOEX
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_MOEX_RM_Equity - risk free rate   R-squared (uncentered):                   0.087
# Model:                                                OLS   Adj. R-squared (uncentered):              0.087
# Method:                                     Least Squares   F-statistic:                              126.7
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                    2.75e-28
# Time:                                            19:27:31   Log-Likelihood:                          1651.2
# No. Observations:                                    1507   AIC:                                     -3300.
# Df Residuals:                                        1506   BIC:                                     -3295.
# Df Model:                                               1
# Covariance Type:                                      HC1
# ============================================================================================
#                                coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_MOEX     0.1061      0.009     11.258      0.000       0.088       0.125
# ==============================================================================
# Omnibus:                       34.076   Durbin-Watson:                   0.092
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               52.181
# Skew:                           0.215   Prob(JB):                     4.67e-12
# Kurtosis:                       3.804   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe71a006e50>
# ###################################################################################
# IRAO
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_IRAO_RM_Equity - risk free rate   R-squared (uncentered):                   0.210
# Model:                                                OLS   Adj. R-squared (uncentered):              0.209
# Method:                                     Least Squares   F-statistic:                              454.3
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                    8.17e-85
# Time:                                            19:27:31   Log-Likelihood:                          1054.9
# No. Observations:                                    1114   AIC:                                     -2108.
# Df Residuals:                                        1113   BIC:                                     -2103.
# Df Model:                                               1
# Covariance Type:                                      HC1
# ============================================================================================
#                                coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_IRAO     0.7468      0.035     21.315      0.000       0.678       0.815
# ==============================================================================
# Omnibus:                      163.336   Durbin-Watson:                   0.086
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              252.776
# Skew:                           0.994   Prob(JB):                     1.29e-55
# Kurtosis:                       4.221   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe719ead130>
# ###################################################################################
# NLMK
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_NLMK_RM_Equity - risk free rate   R-squared (uncentered):                   0.392
# Model:                                                OLS   Adj. R-squared (uncentered):              0.392
# Method:                                     Least Squares   F-statistic:                              1343.
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                   6.85e-225
# Time:                                            19:27:31   Log-Likelihood:                          2061.8
# No. Observations:                                    1979   AIC:                                     -4122.
# Df Residuals:                                        1978   BIC:                                     -4116.
# Df Model:                                               1
# Covariance Type:                                      HC1
# ============================================================================================
#                                coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_NLMK     0.9006      0.025     36.652      0.000       0.852       0.949
# ==============================================================================
# Omnibus:                        9.230   Durbin-Watson:                   0.097
# Prob(Omnibus):                  0.010   Jarque-Bera (JB):                9.189
# Skew:                           0.162   Prob(JB):                       0.0101
# Kurtosis:                       3.078   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe719ead040>
# ###################################################################################
# ALRS
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_ALRS_RM_Equity - risk free rate   R-squared (uncentered):                   0.202
# Model:                                                OLS   Adj. R-squared (uncentered):              0.201
# Method:                                     Least Squares   F-statistic:                              303.8
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                    7.31e-63
# Time:                                            19:27:31   Log-Likelihood:                          1674.9
# No. Observations:                                    1752   AIC:                                     -3348.
# Df Residuals:                                        1751   BIC:                                     -3342.
# Df Model:                                               1
# Covariance Type:                                      HC1
# ============================================================================================
#                                coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_ALRS     0.6293      0.036     17.429      0.000       0.558       0.700
# ==============================================================================
# Omnibus:                      182.170   Durbin-Watson:                   0.074
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              337.139
# Skew:                           0.684   Prob(JB):                     6.18e-74
# Kurtosis:                       4.658   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe719ea7e20>
# ###################################################################################
# CHMF
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_CHMF_RM_Equity - risk free rate   R-squared (uncentered):                   0.326
# Model:                                                OLS   Adj. R-squared (uncentered):              0.325
# Method:                                     Least Squares   F-statistic:                              675.4
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                   2.38e-128
# Time:                                            19:27:31   Log-Likelihood:                          2011.9
# No. Observations:                                    1979   AIC:                                     -4022.
# Df Residuals:                                        1978   BIC:                                     -4016.
# Df Model:                                               1
# Covariance Type:                                      HC1
# ============================================================================================
#                                coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_CHMF     0.7666      0.029     25.989      0.000       0.709       0.824
# ==============================================================================
# Omnibus:                       25.142   Durbin-Watson:                   0.075
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               27.255
# Skew:                           0.236   Prob(JB):                     1.21e-06
# Kurtosis:                       3.328   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe6c8304460>
# ###################################################################################
# VTBR
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_VTBR_RM_Equity - risk free rate   R-squared (uncentered):                   0.230
# Model:                                                OLS   Adj. R-squared (uncentered):              0.230
# Method:                                     Least Squares   F-statistic:                              262.3
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                    1.72e-55
# Time:                                            19:27:31   Log-Likelihood:                          1999.3
# No. Observations:                                    1979   AIC:                                     -3997.
# Df Residuals:                                        1978   BIC:                                     -3991.
# Df Model:                                               1
# Covariance Type:                                      HC1
# ============================================================================================
#                                coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_VTBR     0.1863      0.012     16.195      0.000       0.164       0.209
# ==============================================================================
# Omnibus:                      691.854   Durbin-Watson:                   0.063
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4699.587
# Skew:                           1.474   Prob(JB):                         0.00
# Kurtosis:                       9.950   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe719ea7280>
# ###################################################################################
# RTKM
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_RTKM_RM_Equity - risk free rate   R-squared (uncentered):                   0.270
# Model:                                                OLS   Adj. R-squared (uncentered):              0.269
# Method:                                     Least Squares   F-statistic:                              684.2
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                   2.16e-128
# Time:                                            19:27:31   Log-Likelihood:                          2285.1
# No. Observations:                                    1831   AIC:                                     -4568.
# Df Residuals:                                        1830   BIC:                                     -4563.
# Df Model:                                               1
# Covariance Type:                                      HC1
# ============================================================================================
#                                coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_RTKM     0.3777      0.014     26.157      0.000       0.349       0.406
# ==============================================================================
# Omnibus:                       18.134   Durbin-Watson:                   0.094
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               26.820
# Skew:                           0.077   Prob(JB):                     1.50e-06
# Kurtosis:                       3.573   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe69820ddf0>
# ###################################################################################
# PHOR
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_PHOR_RM_Equity - risk free rate   R-squared (uncentered):                   0.117
# Model:                                                OLS   Adj. R-squared (uncentered):              0.117
# Method:                                     Least Squares   F-statistic:                              137.4
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                    1.41e-30
# Time:                                            19:27:31   Log-Likelihood:                          1955.6
# No. Observations:                                    1720   AIC:                                     -3909.
# Df Residuals:                                        1719   BIC:                                     -3904.
# Df Model:                                               1
# Covariance Type:                                      HC1
# ============================================================================================
#                                coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_PHOR     0.3629      0.031     11.720      0.000       0.302       0.424
# ==============================================================================
# Omnibus:                      203.831   Durbin-Watson:                   0.074
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              774.483
# Skew:                           0.535   Prob(JB):                    6.66e-169
# Kurtosis:                       6.108   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe719ea7850>
# ###################################################################################
# AFKS
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_AFKS_RM_Equity - risk free rate   R-squared (uncentered):                   0.173
# Model:                                                OLS   Adj. R-squared (uncentered):              0.172
# Method:                                     Least Squares   F-statistic:                              553.4
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                   4.29e-108
# Time:                                            19:27:31   Log-Likelihood:                          693.13
# No. Observations:                                    1979   AIC:                                     -1384.
# Df Residuals:                                        1978   BIC:                                     -1379.
# Df Model:                                               1
# Covariance Type:                                      HC1
# ============================================================================================
#                                coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_AFKS     0.2573      0.011     23.524      0.000       0.236       0.279
# ==============================================================================
# Omnibus:                     1277.672   Durbin-Watson:                   0.070
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            18266.631
# Skew:                          -2.843   Prob(JB):                         0.00
# Kurtosis:                      16.755   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe719ea7760>
# ###################################################################################
# MAGN
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_MAGN_RM_Equity - risk free rate   R-squared (uncentered):                   0.373
# Model:                                                OLS   Adj. R-squared (uncentered):              0.373
# Method:                                     Least Squares   F-statistic:                              753.5
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                   8.08e-141
# Time:                                            19:27:31   Log-Likelihood:                          1709.1
# No. Observations:                                    1979   AIC:                                     -3416.
# Df Residuals:                                        1978   BIC:                                     -3411.
# Df Model:                                               1
# Covariance Type:                                      HC1
# ============================================================================================
#                                coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_MAGN     0.8523      0.031     27.449      0.000       0.791       0.913
# ==============================================================================
# Omnibus:                       75.280   Durbin-Watson:                   0.067
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               92.418
# Skew:                           0.421   Prob(JB):                     8.55e-21
# Kurtosis:                       3.642   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe719ea7160>
# ###################################################################################
# PIKK
# ...
# ###################################################################################
# MSTT
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_MSTT_RM_Equity - risk free rate   R-squared (uncentered):                   0.005
# Model:                                                OLS   Adj. R-squared (uncentered):              0.004
# Method:                                     Least Squares   F-statistic:                              2.306
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                       0.129
# Time:                                            19:27:32   Log-Likelihood:                          1485.4
# No. Observations:                                    1922   AIC:                                     -2969.
# Df Residuals:                                        1921   BIC:                                     -2963.
# Df Model:                                               1
# Covariance Type:                                      HC1
# ============================================================================================
#                                coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_MSTT     0.0600      0.039      1.518      0.129      -0.017       0.137
# ==============================================================================
# Omnibus:                      192.685   Durbin-Watson:                   0.087
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              716.912
# Skew:                           0.446   Prob(JB):                    2.11e-156
# Kurtosis:                       5.856   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe71a006ac0>
# ###################################################################################
# BSPB
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_BSPB_RM_Equity - risk free rate   R-squared (uncentered):                   0.182
# Model:                                                OLS   Adj. R-squared (uncentered):              0.182
# Method:                                     Least Squares   F-statistic:                              200.2
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                    2.24e-43
# Time:                                            19:27:32   Log-Likelihood:                          1666.1
# No. Observations:                                    1979   AIC:                                     -3330.
# Df Residuals:                                        1978   BIC:                                     -3325.
# Df Model:                                               1
# Covariance Type:                                      HC1
# ============================================================================================
#                                coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_BSPB     0.1208      0.009     14.151      0.000       0.104       0.138
# ==============================================================================
# Omnibus:                       75.752   Durbin-Watson:                   0.080
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              187.783
# Skew:                          -0.172   Prob(JB):                     1.67e-41
# Kurtosis:                       4.469   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe719ea7df0>
# ###################################################################################
# MSRS
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_MSRS_RM_Equity - risk free rate   R-squared (uncentered):                   0.427
# Model:                                                OLS   Adj. R-squared (uncentered):              0.426
# Method:                                     Least Squares   F-statistic:                              465.7
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                    6.00e-78
# Time:                                            19:27:32   Log-Likelihood:                          825.35
# No. Observations:                                     638   AIC:                                     -1649.
# Df Residuals:                                         637   BIC:                                     -1644.
# Df Model:                                               1
# Covariance Type:                                      HC1
# ============================================================================================
#                                coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_MSRS     0.3497      0.016     21.581      0.000       0.318       0.381
# ==============================================================================
# Omnibus:                       49.976   Durbin-Watson:                   0.099
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               59.665
# Skew:                           0.727   Prob(JB):                     1.11e-13
# Kurtosis:                       3.365   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe719ea7250>
# ###################################################################################
# KMAZ
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_KMAZ_RM_Equity - risk free rate   R-squared (uncentered):                   0.205
# Model:                                                OLS   Adj. R-squared (uncentered):              0.204
# Method:                                     Least Squares   F-statistic:                              528.7
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                   6.94e-104
# Time:                                            19:27:32   Log-Likelihood:                          1680.9
# No. Observations:                                    1979   AIC:                                     -3360.
# Df Residuals:                                        1978   BIC:                                     -3354.
# Df Model:                                               1
# Covariance Type:                                      HC1
# ============================================================================================
#                                coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_KMAZ     0.4010      0.017     22.994      0.000       0.367       0.435
# ==============================================================================
# Omnibus:                      411.101   Durbin-Watson:                   0.103
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              989.507
# Skew:                           1.135   Prob(JB):                    1.35e-215
# Kurtosis:                       5.618   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe719ea62b0>
# ###################################################################################
# RASP
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_RASP_RM_Equity - risk free rate   R-squared (uncentered):                   0.291
# Model:                                                OLS   Adj. R-squared (uncentered):              0.291
# Method:                                     Least Squares   F-statistic:                              467.6
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                    2.90e-93
# Time:                                            19:27:32   Log-Likelihood:                          1108.8
# No. Observations:                                    1979   AIC:                                     -2216.
# Df Residuals:                                        1978   BIC:                                     -2210.
# Df Model:                                               1
# Covariance Type:                                      HC1
# ============================================================================================
#                                coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_RASP     0.9483      0.044     21.625      0.000       0.862       1.034
# ==============================================================================
# Omnibus:                      169.697   Durbin-Watson:                   0.075
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              241.175
# Skew:                           0.681   Prob(JB):                     4.26e-53
# Kurtosis:                       4.034   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe719ea60d0>
# ###################################################################################
# OGKB
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_OGKB_RM_Equity - risk free rate   R-squared (uncentered):                   0.207
# Model:                                                OLS   Adj. R-squared (uncentered):              0.206
# Method:                                     Least Squares   F-statistic:                              201.6
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                    1.25e-43
# Time:                                            19:27:32   Log-Likelihood:                          1270.6
# No. Observations:                                    1956   AIC:                                     -2539.
# Df Residuals:                                        1955   BIC:                                     -2534.
# Df Model:                                               1
# Covariance Type:                                      HC1
# ============================================================================================
#                                coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_OGKB     0.5024      0.035     14.200      0.000       0.433       0.572
# ==============================================================================
# Omnibus:                      123.562   Durbin-Watson:                   0.067
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              271.228
# Skew:                           0.400   Prob(JB):                     1.27e-59
# Kurtosis:                       4.639   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe71a006ca0>
# ###################################################################################
# VZRZ
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_VZRZ_RM_Equity - risk free rate   R-squared (uncentered):                   0.003
# Model:                                                OLS   Adj. R-squared (uncentered):              0.003
# Method:                                     Least Squares   F-statistic:                              5.965
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                      0.0147
# Time:                                            19:27:32   Log-Likelihood:                          1628.0
# No. Observations:                                    1979   AIC:                                     -3254.
# Df Residuals:                                        1978   BIC:                                     -3248.
# Df Model:                                               1
# Covariance Type:                                      HC1
# ============================================================================================
#                                coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_VZRZ     0.0417      0.017      2.442      0.015       0.008       0.075
# ==============================================================================
# Omnibus:                       40.330   Durbin-Watson:                   0.092
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               78.732
# Skew:                          -0.087   Prob(JB):                     8.01e-18
# Kurtosis:                       3.961   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe719fec760>

# %% [markdown]
# ## 3 factor Fama-French model

# %%
lag_autolag_return_30 = 30
lag_autolag_return_60 = 60
lag_autolag_return_90 = 90
lag_30 = 30
lag_60 = 60
lag_90 = 90

r_2_results_ff3 = []
mse_results_ff3 = []

for name in data_ret.columns[2:]:
    
    df1 = data[[name, 'Hamada_beta_MRP_for_{}'.format(name[7:11]), 'risk_free_rate_based_on_g_curve',
                 'Hamada_d_mcap_ratio_SMB_for_{}'.format(name[7:11]),
                 'Hamada_d_mcap_ratio_HML_for_{}'.format(name[7:11]),
                 'MOM']].dropna()
    df_autolag = pd.DataFrame(data[name] - data['risk_free_rate_based_on_g_curve']).rename(columns = {0:'{}_premium_lag_{}_days'.format(name[7:], lag_autolag_return_30)})
    df_autolag = pd.DataFrame(df_autolag['{}_premium_lag_{}_days'.format(name[7:], lag_autolag_return_30)].shift(lag_autolag_return_30).dropna())
    
    df_autolag_2 = pd.DataFrame(data[name] - data['risk_free_rate_based_on_g_curve']).rename(columns = {0:'{}_premium_lag_{}_days'.format(name[7:], lag_autolag_return_60)})
    df_autolag_2 = pd.DataFrame(df_autolag_2['{}_premium_lag_{}_days'.format(name[7:], lag_autolag_return_60)].shift(lag_autolag_return_60).dropna())
    
    df_autolag_3 = pd.DataFrame(data[name] - data['risk_free_rate_based_on_g_curve']).rename(columns = {0:'{}_premium_lag_{}_days'.format(name[7:], lag_autolag_return_90)})
    df_autolag_3 = pd.DataFrame(df_autolag_3['{}_premium_lag_{}_days'.format(name[7:], lag_autolag_return_90)].shift(lag_autolag_return_90).dropna())
    
    df2 = data[['Hamada_d_mcap_ratio_SMB_for_{}'.format(name[7:11]),
            'Hamada_d_mcap_ratio_HML_for_{}'.format(name[7:11]), 'MOM']].shift(lag_30).dropna()
    
    
    
    df2.rename(columns = {'Hamada_d_mcap_ratio_SMB_for_{}'.format(name[7:11]):'Hamada_d_mcap_ratio_SMB_for_{}_lag_{}_days'.format(name[7:11], lag_30),
                          'Hamada_d_mcap_ratio_HML_for_{}'.format(name[7:11]):'Hamada_d_mcap_ratio_HML_for_{}_lag_{}_days'.format(name[7:11], lag_30), 
                          'MOM':'MOM_lag_{}_days'.format(lag_30)}, inplace = True)
    
    result = pd.concat([df1, df2], axis=1, join="inner")
    
    df3 = data[['Hamada_d_mcap_ratio_SMB_for_{}'.format(name[7:11]),
            'Hamada_d_mcap_ratio_HML_for_{}'.format(name[7:11]), 'MOM']].shift(lag_60).dropna()
    
    df3.rename(columns = {'Hamada_d_mcap_ratio_SMB_for_{}'.format(name[7:11]):'Hamada_d_mcap_ratio_SMB_for_{}_lag_{}_days'.format(name[7:11], lag_60),
                          'Hamada_d_mcap_ratio_HML_for_{}'.format(name[7:11]):'Hamada_d_mcap_ratio_HML_for_{}_lag_{}_days'.format(name[7:11], lag_60), 
                          'MOM':'MOM_lag_{}_days'.format(lag_60)}, inplace = True)
    
    result = pd.concat([result, df3], axis=1, join="inner")
    
    df4 = data[['Hamada_d_mcap_ratio_SMB_for_{}'.format(name[7:11]),
            'Hamada_d_mcap_ratio_HML_for_{}'.format(name[7:11]), 'MOM']].shift(lag_90).dropna()
    
    df4.rename(columns = {'Hamada_d_mcap_ratio_SMB_for_{}'.format(name[7:11]):'Hamada_d_mcap_ratio_SMB_for_{}_lag_{}_days'.format(name[7:11], lag_90),
                          'Hamada_d_mcap_ratio_HML_for_{}'.format(name[7:11]):'Hamada_d_mcap_ratio_HML_for_{}_lag_{}_days'.format(name[7:11], lag_90), 
                          'MOM':'MOM_lag_{}_days'.format(lag_90)}, inplace = True)
    
    result = pd.concat([result, df4], axis=1, join="inner")
    
    result = pd.merge(result, macro_data, left_index=True, right_index=True)
    result = pd.merge(result, df_autolag, left_index=True, right_index=True)
    result = pd.merge(result, df_autolag_2, left_index=True, right_index=True)
    result = pd.merge(result, df_autolag_3, left_index=True, right_index=True)
    
    Base = result.dropna()
    
    Y = pd.DataFrame(Base[name] - Base['risk_free_rate_based_on_g_curve'])
    Y.rename(columns = {0:'{} - risk free rate'.format(name)}, inplace = True)
    X = Base[['Hamada_beta_MRP_for_{}'.format(name[7:11]), 
              'Hamada_d_mcap_ratio_SMB_for_{}'.format(name[7:11]),
              'Hamada_d_mcap_ratio_HML_for_{}'.format(name[7:11])]]
    model = sm.OLS(Y,X)
    results = model.fit(cov_type = 'HC1')
    print('###################################################################################')
    print(name[7:11])
    print(results.summary())
    
    print(results)
    r_2_results_ff3.append(results.rsquared_adj)
    mse_results_ff3.append(results.mse_resid)
# Out:
# ###################################################################################
# SBER
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_SBER_RM_Equity - risk free rate   R-squared (uncentered):                   0.410
# Model:                                                OLS   Adj. R-squared (uncentered):              0.409
# Method:                                     Least Squares   F-statistic:                              84.56
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                    1.80e-51
# Time:                                            19:27:32   Log-Likelihood:                          2256.5
# No. Observations:                                    1979   AIC:                                     -4507.
# Df Residuals:                                        1976   BIC:                                     -4490.
# Df Model:                                               3
# Covariance Type:                                      HC1
# ====================================================================================================
#                                        coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_SBER             0.4209      0.028     15.232      0.000       0.367       0.475
# Hamada_d_mcap_ratio_SMB_for_SBER     0.0806      0.026      3.127      0.002       0.030       0.131
# Hamada_d_mcap_ratio_HML_for_SBER    -0.0209      0.010     -1.997      0.046      -0.041      -0.000
# ==============================================================================
# Omnibus:                      286.442   Durbin-Watson:                   0.086
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              584.582
# Skew:                          -0.869   Prob(JB):                    1.15e-127
# Kurtosis:                       5.016   Cond. No.                         1.89
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe69822c640>
# ###################################################################################
# GAZP
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_GAZP_RM_Equity - risk free rate   R-squared (uncentered):                   0.624
# Model:                                                OLS   Adj. R-squared (uncentered):              0.623
# Method:                                     Least Squares   F-statistic:                              784.9
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                        0.00
# Time:                                            19:27:32   Log-Likelihood:                          2916.0
# No. Observations:                                    1979   AIC:                                     -5826.
# Df Residuals:                                        1976   BIC:                                     -5809.
# Df Model:                                               3
# Covariance Type:                                      HC1
# ====================================================================================================
#                                        coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_GAZP             0.7550      0.016     47.709      0.000       0.724       0.786
# Hamada_d_mcap_ratio_SMB_for_GAZP    -0.0730      0.019     -3.798      0.000      -0.111      -0.035
# Hamada_d_mcap_ratio_HML_for_GAZP    -0.0480      0.012     -4.073      0.000      -0.071      -0.025
# ==============================================================================
# Omnibus:                      647.994   Durbin-Watson:                   0.075
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3168.326
# Skew:                           1.477   Prob(JB):                         0.00
# Kurtosis:                       8.450   Cond. No.                         1.56
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe6e923d640>
# ###################################################################################
# LKOH
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_LKOH_RM_Equity - risk free rate   R-squared (uncentered):                   0.680
# Model:                                                OLS   Adj. R-squared (uncentered):              0.680
# Method:                                     Least Squares   F-statistic:                              687.8
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                   4.06e-306
# Time:                                            19:27:32   Log-Likelihood:                          3343.2
# No. Observations:                                    1979   AIC:                                     -6680.
# Df Residuals:                                        1976   BIC:                                     -6664.
# Df Model:                                               3
# Covariance Type:                                      HC1
# ====================================================================================================
#                                        coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_LKOH             0.9061      0.020     44.898      0.000       0.867       0.946
# Hamada_d_mcap_ratio_SMB_for_LKOH    -0.0078      0.019     -0.402      0.688      -0.046       0.030
# Hamada_d_mcap_ratio_HML_for_LKOH     0.0621      0.014      4.544      0.000       0.035       0.089
# ==============================================================================
# Omnibus:                       54.553   Durbin-Watson:                   0.129
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               83.140
# Skew:                          -0.266   Prob(JB):                     8.84e-19
# Kurtosis:                       3.852   Cond. No.                         1.63
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe69821ebb0>
# ###################################################################################
# GMKN
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_GMKN_RM_Equity - risk free rate   R-squared (uncentered):                   0.428
# Model:                                                OLS   Adj. R-squared (uncentered):              0.427
# Method:                                     Least Squares   F-statistic:                              365.7
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                   7.21e-189
# Time:                                            19:27:32   Log-Likelihood:                          2661.4
# No. Observations:                                    1979   AIC:                                     -5317.
# Df Residuals:                                        1976   BIC:                                     -5300.
# Df Model:                                               3
# Covariance Type:                                      HC1
# ====================================================================================================
#                                        coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_GMKN             0.7535      0.023     32.402      0.000       0.708       0.799
# Hamada_d_mcap_ratio_SMB_for_GMKN     0.0108      0.030      0.356      0.722      -0.049       0.070
# Hamada_d_mcap_ratio_HML_for_GMKN     0.0319      0.018      1.751      0.080      -0.004       0.068
# ==============================================================================
# Omnibus:                        7.234   Durbin-Watson:                   0.131
# Prob(Omnibus):                  0.027   Jarque-Bera (JB):                7.258
# Skew:                           0.127   Prob(JB):                       0.0265
# Kurtosis:                       3.153   Cond. No.                         1.59
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe719ea3550>
# ###################################################################################
# NVTK
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_NVTK_RM_Equity - risk free rate   R-squared (uncentered):                   0.432
# Model:                                                OLS   Adj. R-squared (uncentered):              0.431
# Method:                                     Least Squares   F-statistic:                              369.2
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                   2.32e-190
# Time:                                            19:27:32   Log-Likelihood:                          2678.7
# No. Observations:                                    1979   AIC:                                     -5351.
# Df Residuals:                                        1976   BIC:                                     -5335.
# Df Model:                                               3
# Covariance Type:                                      HC1
# ====================================================================================================
#                                        coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_NVTK             0.8454      0.026     32.867      0.000       0.795       0.896
# Hamada_d_mcap_ratio_SMB_for_NVTK    -0.2392      0.030     -7.981      0.000      -0.298      -0.180
# Hamada_d_mcap_ratio_HML_for_NVTK    -0.0620      0.025     -2.494      0.013      -0.111      -0.013
# ==============================================================================
# Omnibus:                        4.948   Durbin-Watson:                   0.119
# Prob(Omnibus):                  0.084   Jarque-Bera (JB):                5.021
# Skew:                           0.090   Prob(JB):                       0.0812
# Kurtosis:                       3.169   Cond. No.                         1.62
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe719ea34c0>
# ###################################################################################
# SNGS
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_SNGS_RM_Equity - risk free rate   R-squared (uncentered):                   0.543
# Model:                                                OLS   Adj. R-squared (uncentered):              0.542
# Method:                                     Least Squares   F-statistic:                              412.6
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                   1.71e-192
# Time:                                            19:27:32   Log-Likelihood:                          1621.0
# No. Observations:                                    1417   AIC:                                     -3236.
# Df Residuals:                                        1414   BIC:                                     -3220.
# Df Model:                                               3
# Covariance Type:                                      HC1
# ====================================================================================================
#                                        coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_SNGS             1.2775      0.037     34.384      0.000       1.205       1.350
# Hamada_d_mcap_ratio_SMB_for_SNGS    -0.1019      0.047     -2.181      0.029      -0.193      -0.010
# Hamada_d_mcap_ratio_HML_for_SNGS    -0.0746      0.025     -2.969      0.003      -0.124      -0.025
# ==============================================================================
# Omnibus:                      164.452   Durbin-Watson:                   0.090
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              296.009
# Skew:                           0.754   Prob(JB):                     5.28e-65
# Kurtosis:                       4.654   Cond. No.                         1.59
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe719ffc580>
# ###################################################################################
# PLZL
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_PLZL_RM_Equity - risk free rate   R-squared (uncentered):                   0.031
# Model:                                                OLS   Adj. R-squared (uncentered):              0.027
# Method:                                     Least Squares   F-statistic:                              13.06
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                    2.53e-08
# Time:                                            19:27:33   Log-Likelihood:                          619.96
# No. Observations:                                     753   AIC:                                     -1234.
# Df Residuals:                                         750   BIC:                                     -1220.
# Df Model:                                               3
# Covariance Type:                                      HC1
# ====================================================================================================
#                                        coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_PLZL            -0.0556      0.073     -0.758      0.449      -0.199       0.088
# Hamada_d_mcap_ratio_SMB_for_PLZL    -0.1460      0.065     -2.243      0.025      -0.274      -0.018
# Hamada_d_mcap_ratio_HML_for_PLZL     0.3119      0.051      6.078      0.000       0.211       0.412
# ==============================================================================
# Omnibus:                       30.024   Durbin-Watson:                   0.074
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               58.435
# Skew:                           0.250   Prob(JB):                     2.05e-13
# Kurtosis:                       4.270   Cond. No.                         1.72
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe69822c520>
# ###################################################################################
# TATN
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_TATN_RM_Equity - risk free rate   R-squared (uncentered):                   0.668
# Model:                                                OLS   Adj. R-squared (uncentered):              0.668
# Method:                                     Least Squares   F-statistic:                              904.8
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                        0.00
# Time:                                            19:27:33   Log-Likelihood:                          2824.8
# No. Observations:                                    1979   AIC:                                     -5644.
# Df Residuals:                                        1976   BIC:                                     -5627.
# Df Model:                                               3
# Covariance Type:                                      HC1
# ====================================================================================================
#                                        coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_TATN             1.2284      0.024     52.043      0.000       1.182       1.275
# Hamada_d_mcap_ratio_SMB_for_TATN    -0.1906      0.028     -6.691      0.000      -0.246      -0.135
# Hamada_d_mcap_ratio_HML_for_TATN     0.0768      0.016      4.727      0.000       0.045       0.109
# ==============================================================================
# Omnibus:                       48.785   Durbin-Watson:                   0.162
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               52.412
# Skew:                           0.372   Prob(JB):                     4.16e-12
# Kurtosis:                       3.289   Cond. No.                         1.62
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe719356130>
# ###################################################################################
# ROSN
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_ROSN_RM_Equity - risk free rate   R-squared (uncentered):                   0.581
# Model:                                                OLS   Adj. R-squared (uncentered):              0.580
# Method:                                     Least Squares   F-statistic:                              479.7
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                   1.76e-233
# Time:                                            19:27:33   Log-Likelihood:                          2629.9
# No. Observations:                                    1956   AIC:                                     -5254.
# Df Residuals:                                        1953   BIC:                                     -5237.
# Df Model:                                               3
# Covariance Type:                                      HC1
# ====================================================================================================
#                                        coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_ROSN             0.7171      0.023     31.529      0.000       0.672       0.762
# Hamada_d_mcap_ratio_SMB_for_ROSN    -0.0338      0.017     -1.993      0.046      -0.067      -0.001
# Hamada_d_mcap_ratio_HML_for_ROSN    -0.0720      0.011     -6.402      0.000      -0.094      -0.050
# ==============================================================================
# Omnibus:                       82.412   Durbin-Watson:                   0.081
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              201.704
# Skew:                           0.213   Prob(JB):                     1.59e-44
# Kurtosis:                       4.514   Cond. No.                         1.60
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe6b90b4790>
# ###################################################################################
# MGNT
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_MGNT_RM_Equity - risk free rate   R-squared (uncentered):                   0.210
# Model:                                                OLS   Adj. R-squared (uncentered):              0.209
# Method:                                     Least Squares   F-statistic:                              170.9
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                    1.76e-98
# Time:                                            19:27:33   Log-Likelihood:                          1883.6
# No. Observations:                                    1979   AIC:                                     -3761.
# Df Residuals:                                        1976   BIC:                                     -3744.
# Df Model:                                               3
# Covariance Type:                                      HC1
# ====================================================================================================
#                                        coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_MGNT             0.4376      0.027     16.415      0.000       0.385       0.490
# Hamada_d_mcap_ratio_SMB_for_MGNT     0.1853      0.038      4.830      0.000       0.110       0.260
# Hamada_d_mcap_ratio_HML_for_MGNT     0.2322      0.023     10.176      0.000       0.187       0.277
# ==============================================================================
# Omnibus:                      334.188   Durbin-Watson:                   0.091
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              757.139
# Skew:                          -0.957   Prob(JB):                    3.88e-165
# Kurtosis:                       5.350   Cond. No.                         1.78
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe719fec310>
# ###################################################################################
# MTSS
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_MTSS_RM_Equity - risk free rate   R-squared (uncentered):                   0.430
# Model:                                                OLS   Adj. R-squared (uncentered):              0.429
# Method:                                     Least Squares   F-statistic:                              388.9
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                   1.75e-198
# Time:                                            19:27:33   Log-Likelihood:                          2538.7
# No. Observations:                                    1979   AIC:                                     -5071.
# Df Residuals:                                        1976   BIC:                                     -5055.
# Df Model:                                               3
# Covariance Type:                                      HC1
# ====================================================================================================
#                                        coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_MTSS             0.6037      0.018     32.841      0.000       0.568       0.640
# Hamada_d_mcap_ratio_SMB_for_MTSS     0.0229      0.024      0.962      0.336      -0.024       0.069
# Hamada_d_mcap_ratio_HML_for_MTSS    -0.1108      0.019     -5.799      0.000      -0.148      -0.073
# ==============================================================================
# Omnibus:                      401.794   Durbin-Watson:                   0.095
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1519.614
# Skew:                          -0.955   Prob(JB):                         0.00
# Kurtosis:                       6.844   Cond. No.                         1.62
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe698237fa0>
# ###################################################################################
# MOEX
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_MOEX_RM_Equity - risk free rate   R-squared (uncentered):                   0.099
# Model:                                                OLS   Adj. R-squared (uncentered):              0.097
# Method:                                     Least Squares   F-statistic:                              47.73
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                    1.83e-29
# Time:                                            19:27:33   Log-Likelihood:                          1660.3
# No. Observations:                                    1507   AIC:                                     -3315.
# Df Residuals:                                        1504   BIC:                                     -3299.
# Df Model:                                               3
# Covariance Type:                                      HC1
# ====================================================================================================
#                                        coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_MOEX             0.1041      0.010     10.407      0.000       0.084       0.124
# Hamada_d_mcap_ratio_SMB_for_MOEX     0.0326      0.008      3.939      0.000       0.016       0.049
# Hamada_d_mcap_ratio_HML_for_MOEX    -0.0389      0.010     -3.776      0.000      -0.059      -0.019
# ==============================================================================
# Omnibus:                       30.725   Durbin-Watson:                   0.095
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               50.952
# Skew:                           0.162   Prob(JB):                     8.63e-12
# Kurtosis:                       3.840   Cond. No.                         1.56
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe6e9408df0>
# ###################################################################################
# IRAO
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_IRAO_RM_Equity - risk free rate   R-squared (uncentered):                   0.234
# Model:                                                OLS   Adj. R-squared (uncentered):              0.232
# Method:                                     Least Squares   F-statistic:                              145.3
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                    2.05e-79
# Time:                                            19:27:33   Log-Likelihood:                          1071.9
# No. Observations:                                    1114   AIC:                                     -2138.
# Df Residuals:                                        1111   BIC:                                     -2123.
# Df Model:                                               3
# Covariance Type:                                      HC1
# ====================================================================================================
#                                        coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_IRAO             0.6821      0.036     19.191      0.000       0.612       0.752
# Hamada_d_mcap_ratio_SMB_for_IRAO     0.2817      0.059      4.762      0.000       0.166       0.398
# Hamada_d_mcap_ratio_HML_for_IRAO     0.1205      0.066      1.824      0.068      -0.009       0.250
# ==============================================================================
# Omnibus:                      162.569   Durbin-Watson:                   0.094
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              260.640
# Skew:                           0.967   Prob(JB):                     2.53e-57
# Kurtosis:                       4.371   Cond. No.                         1.55
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe6e9408d90>
# ###################################################################################
# NLMK
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_NLMK_RM_Equity - risk free rate   R-squared (uncentered):                   0.394
# Model:                                                OLS   Adj. R-squared (uncentered):              0.393
# Method:                                     Least Squares   F-statistic:                              464.6
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                   2.14e-228
# Time:                                            19:27:33   Log-Likelihood:                          2064.9
# No. Observations:                                    1979   AIC:                                     -4124.
# Df Residuals:                                        1976   BIC:                                     -4107.
# Df Model:                                               3
# Covariance Type:                                      HC1
# ====================================================================================================
#                                        coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_NLMK             0.8921      0.025     36.388      0.000       0.844       0.940
# Hamada_d_mcap_ratio_SMB_for_NLMK     0.0215      0.036      0.601      0.548      -0.049       0.092
# Hamada_d_mcap_ratio_HML_for_NLMK    -0.0587      0.021     -2.799      0.005      -0.100      -0.018
# ==============================================================================
# Omnibus:                        7.218   Durbin-Watson:                   0.097
# Prob(Omnibus):                  0.027   Jarque-Bera (JB):                7.161
# Skew:                           0.145   Prob(JB):                       0.0279
# Kurtosis:                       3.054   Cond. No.                         1.63
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe6e9408be0>
# ###################################################################################
# ALRS
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_ALRS_RM_Equity - risk free rate   R-squared (uncentered):                   0.203
# Model:                                                OLS   Adj. R-squared (uncentered):              0.201
# Method:                                     Least Squares   F-statistic:                              103.5
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                    1.13e-61
# Time:                                            19:27:33   Log-Likelihood:                          1676.0
# No. Observations:                                    1752   AIC:                                     -3346.
# Df Residuals:                                        1749   BIC:                                     -3330.
# Df Model:                                               3
# Covariance Type:                                      HC1
# ====================================================================================================
#                                        coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_ALRS             0.6168      0.035     17.467      0.000       0.548       0.686
# Hamada_d_mcap_ratio_SMB_for_ALRS     0.0619      0.044      1.405      0.160      -0.024       0.148
# Hamada_d_mcap_ratio_HML_for_ALRS     0.0102      0.028      0.363      0.717      -0.045       0.065
# ==============================================================================
# Omnibus:                      179.624   Durbin-Watson:                   0.074
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              337.934
# Skew:                           0.670   Prob(JB):                     4.15e-74
# Kurtosis:                       4.683   Cond. No.                         1.62
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe698237df0>
# ###################################################################################
# CHMF
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_CHMF_RM_Equity - risk free rate   R-squared (uncentered):                   0.339
# Model:                                                OLS   Adj. R-squared (uncentered):              0.338
# Method:                                     Least Squares   F-statistic:                              252.0
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                   1.83e-138
# Time:                                            19:27:33   Log-Likelihood:                          2031.4
# No. Observations:                                    1979   AIC:                                     -4057.
# Df Residuals:                                        1976   BIC:                                     -4040.
# Df Model:                                               3
# Covariance Type:                                      HC1
# ====================================================================================================
#                                        coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_CHMF             0.7594      0.031     24.256      0.000       0.698       0.821
# Hamada_d_mcap_ratio_SMB_for_CHMF     0.0962      0.039      2.445      0.014       0.019       0.173
# Hamada_d_mcap_ratio_HML_for_CHMF     0.1372      0.027      5.148      0.000       0.085       0.189
# ==============================================================================
# Omnibus:                       16.771   Durbin-Watson:                   0.079
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               18.180
# Skew:                           0.180   Prob(JB):                     0.000113
# Kurtosis:                       3.301   Cond. No.                         1.62
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe6e9408850>
# ###################################################################################
# VTBR
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_VTBR_RM_Equity - risk free rate   R-squared (uncentered):                   0.231
# Model:                                                OLS   Adj. R-squared (uncentered):              0.229
# Method:                                     Least Squares   F-statistic:                              95.11
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                    1.69e-57
# Time:                                            19:27:33   Log-Likelihood:                          1999.8
# No. Observations:                                    1979   AIC:                                     -3994.
# Df Residuals:                                        1976   BIC:                                     -3977.
# Df Model:                                               3
# Covariance Type:                                      HC1
# ====================================================================================================
#                                        coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_VTBR             0.1867      0.011     16.504      0.000       0.165       0.209
# Hamada_d_mcap_ratio_SMB_for_VTBR    -0.0031      0.011     -0.269      0.788      -0.025       0.019
# Hamada_d_mcap_ratio_HML_for_VTBR    -0.0066      0.005     -1.244      0.214      -0.017       0.004
# ==============================================================================
# Omnibus:                      683.188   Durbin-Watson:                   0.064
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4593.069
# Skew:                           1.456   Prob(JB):                         0.00
# Kurtosis:                       9.872   Cond. No.                         1.78
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe719ffcbe0>
# ###################################################################################
# RTKM
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_RTKM_RM_Equity - risk free rate   R-squared (uncentered):                   0.279
# Model:                                                OLS   Adj. R-squared (uncentered):              0.278
# Method:                                     Least Squares   F-statistic:                              252.1
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                   6.61e-137
# Time:                                            19:27:33   Log-Likelihood:                          2296.9
# No. Observations:                                    1831   AIC:                                     -4588.
# Df Residuals:                                        1828   BIC:                                     -4571.
# Df Model:                                               3
# Covariance Type:                                      HC1
# ====================================================================================================
#                                        coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_RTKM             0.3966      0.015     27.341      0.000       0.368       0.425
# Hamada_d_mcap_ratio_SMB_for_RTKM    -0.1047      0.021     -4.992      0.000      -0.146      -0.064
# Hamada_d_mcap_ratio_HML_for_RTKM     0.0302      0.016      1.928      0.054      -0.000       0.061
# ==============================================================================
# Omnibus:                       14.600   Durbin-Watson:                   0.096
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               20.556
# Skew:                           0.065   Prob(JB):                     3.44e-05
# Kurtosis:                       3.502   Cond. No.                         1.66
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe71a006e50>
# ###################################################################################
# PHOR
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_PHOR_RM_Equity - risk free rate   R-squared (uncentered):                   0.150
# Model:                                                OLS   Adj. R-squared (uncentered):              0.148
# Method:                                     Least Squares   F-statistic:                              61.56
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                    8.44e-38
# Time:                                            19:27:33   Log-Likelihood:                          1988.3
# No. Observations:                                    1720   AIC:                                     -3971.
# Df Residuals:                                        1717   BIC:                                     -3954.
# Df Model:                                               3
# Covariance Type:                                      HC1
# ====================================================================================================
#                                        coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_PHOR             0.3322      0.031     10.561      0.000       0.271       0.394
# Hamada_d_mcap_ratio_SMB_for_PHOR     0.1757      0.038      4.670      0.000       0.102       0.249
# Hamada_d_mcap_ratio_HML_for_PHOR     0.1358      0.023      5.796      0.000       0.090       0.182
# ==============================================================================
# Omnibus:                      189.621   Durbin-Watson:                   0.080
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              654.205
# Skew:                           0.522   Prob(JB):                    8.73e-143
# Kurtosis:                       5.835   Cond. No.                         1.56
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe698237ee0>
# ###################################################################################
# AFKS
#                                            OLS Regression Results
# ...
# Hamada_d_mcap_ratio_SMB_for_MSTT     0.0135      0.030      0.451      0.652      -0.045       0.072
# Hamada_d_mcap_ratio_HML_for_MSTT    -0.1825      0.021     -8.868      0.000      -0.223      -0.142
# ==============================================================================
# Omnibus:                      151.730   Durbin-Watson:                   0.093
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              502.480
# Skew:                           0.360   Prob(JB):                    7.73e-110
# Kurtosis:                       5.399   Cond. No.                         1.76
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe69824e250>
# ###################################################################################
# BSPB
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_BSPB_RM_Equity - risk free rate   R-squared (uncentered):                   0.201
# Model:                                                OLS   Adj. R-squared (uncentered):              0.200
# Method:                                     Least Squares   F-statistic:                              73.67
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                    3.63e-45
# Time:                                            19:27:34   Log-Likelihood:                          1689.5
# No. Observations:                                    1979   AIC:                                     -3373.
# Df Residuals:                                        1976   BIC:                                     -3356.
# Df Model:                                               3
# Covariance Type:                                      HC1
# ====================================================================================================
#                                        coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_BSPB             0.1110      0.009     12.829      0.000       0.094       0.128
# Hamada_d_mcap_ratio_SMB_for_BSPB     0.0338      0.009      3.932      0.000       0.017       0.051
# Hamada_d_mcap_ratio_HML_for_BSPB    -0.0289      0.005     -5.473      0.000      -0.039      -0.019
# ==============================================================================
# Omnibus:                       93.501   Durbin-Watson:                   0.085
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              178.547
# Skew:                          -0.341   Prob(JB):                     1.69e-39
# Kurtosis:                       4.304   Cond. No.                         1.73
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe719fe9f70>
# ###################################################################################
# MSRS
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_MSRS_RM_Equity - risk free rate   R-squared (uncentered):                   0.438
# Model:                                                OLS   Adj. R-squared (uncentered):              0.436
# Method:                                     Least Squares   F-statistic:                              171.6
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                    1.84e-81
# Time:                                            19:27:34   Log-Likelihood:                          831.56
# No. Observations:                                     638   AIC:                                     -1657.
# Df Residuals:                                         635   BIC:                                     -1644.
# Df Model:                                               3
# Covariance Type:                                      HC1
# ====================================================================================================
#                                        coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_MSRS             0.3383      0.017     19.664      0.000       0.305       0.372
# Hamada_d_mcap_ratio_SMB_for_MSRS     0.0789      0.019      4.134      0.000       0.042       0.116
# Hamada_d_mcap_ratio_HML_for_MSRS    -0.0277      0.016     -1.785      0.074      -0.058       0.003
# ==============================================================================
# Omnibus:                       48.774   Durbin-Watson:                   0.103
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               57.968
# Skew:                           0.710   Prob(JB):                     2.58e-13
# Kurtosis:                       3.404   Cond. No.                         1.63
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe69823fe50>
# ###################################################################################
# KMAZ
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_KMAZ_RM_Equity - risk free rate   R-squared (uncentered):                   0.213
# Model:                                                OLS   Adj. R-squared (uncentered):              0.211
# Method:                                     Least Squares   F-statistic:                              175.2
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                   1.01e-100
# Time:                                            19:27:34   Log-Likelihood:                          1690.4
# No. Observations:                                    1979   AIC:                                     -3375.
# Df Residuals:                                        1976   BIC:                                     -3358.
# Df Model:                                               3
# Covariance Type:                                      HC1
# ====================================================================================================
#                                        coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_KMAZ             0.3998      0.019     21.109      0.000       0.363       0.437
# Hamada_d_mcap_ratio_SMB_for_KMAZ    -0.0147      0.030     -0.497      0.619      -0.073       0.043
# Hamada_d_mcap_ratio_HML_for_KMAZ    -0.0831      0.022     -3.825      0.000      -0.126      -0.041
# ==============================================================================
# Omnibus:                      399.623   Durbin-Watson:                   0.106
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              908.393
# Skew:                           1.128   Prob(JB):                    5.56e-198
# Kurtosis:                       5.435   Cond. No.                         1.64
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe719fe98b0>
# ###################################################################################
# RASP
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_RASP_RM_Equity - risk free rate   R-squared (uncentered):                   0.294
# Model:                                                OLS   Adj. R-squared (uncentered):              0.293
# Method:                                     Least Squares   F-statistic:                              154.7
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                    4.71e-90
# Time:                                            19:27:34   Log-Likelihood:                          1113.0
# No. Observations:                                    1979   AIC:                                     -2220.
# Df Residuals:                                        1976   BIC:                                     -2203.
# Df Model:                                               3
# Covariance Type:                                      HC1
# ====================================================================================================
#                                        coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_RASP             0.9126      0.047     19.549      0.000       0.821       1.004
# Hamada_d_mcap_ratio_SMB_for_RASP     0.1386      0.053      2.607      0.009       0.034       0.243
# Hamada_d_mcap_ratio_HML_for_RASP    -0.0016      0.031     -0.052      0.959      -0.063       0.060
# ==============================================================================
# Omnibus:                      143.226   Durbin-Watson:                   0.075
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              194.613
# Skew:                           0.617   Prob(JB):                     5.50e-43
# Kurtosis:                       3.916   Cond. No.                         1.82
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe698229e80>
# ###################################################################################
# OGKB
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_OGKB_RM_Equity - risk free rate   R-squared (uncentered):                   0.233
# Model:                                                OLS   Adj. R-squared (uncentered):              0.231
# Method:                                     Least Squares   F-statistic:                              89.45
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                    3.10e-54
# Time:                                            19:27:34   Log-Likelihood:                          1302.9
# No. Observations:                                    1956   AIC:                                     -2600.
# Df Residuals:                                        1953   BIC:                                     -2583.
# Df Model:                                               3
# Covariance Type:                                      HC1
# ====================================================================================================
#                                        coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_OGKB             0.5078      0.037     13.852      0.000       0.436       0.580
# Hamada_d_mcap_ratio_SMB_for_OGKB    -0.0621      0.038     -1.620      0.105      -0.137       0.013
# Hamada_d_mcap_ratio_HML_for_OGKB    -0.1627      0.020     -8.224      0.000      -0.201      -0.124
# ==============================================================================
# Omnibus:                      143.988   Durbin-Watson:                   0.074
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              317.258
# Skew:                           0.462   Prob(JB):                     1.28e-69
# Kurtosis:                       4.743   Cond. No.                         1.72
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe698229e50>
# ###################################################################################
# VZRZ
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_VZRZ_RM_Equity - risk free rate   R-squared (uncentered):                   0.036
# Model:                                                OLS   Adj. R-squared (uncentered):              0.034
# Method:                                     Least Squares   F-statistic:                              21.39
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                    1.23e-13
# Time:                                            19:27:34   Log-Likelihood:                          1660.8
# No. Observations:                                    1979   AIC:                                     -3316.
# Df Residuals:                                        1976   BIC:                                     -3299.
# Df Model:                                               3
# Covariance Type:                                      HC1
# ====================================================================================================
#                                        coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_VZRZ             0.0075      0.018      0.412      0.680      -0.028       0.043
# Hamada_d_mcap_ratio_SMB_for_VZRZ     0.1906      0.024      7.885      0.000       0.143       0.238
# Hamada_d_mcap_ratio_HML_for_VZRZ     0.0171      0.017      0.994      0.320      -0.017       0.051
# ==============================================================================
# Omnibus:                       33.872   Durbin-Watson:                   0.103
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               57.471
# Skew:                          -0.121   Prob(JB):                     3.31e-13
# Kurtosis:                       3.799   Cond. No.                         1.66
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe719ea3b50>

# %% [markdown]
# ## 4 factor Carhart model

# %%
lag_autolag_return_30 = 30
lag_autolag_return_60 = 60
lag_autolag_return_90 = 90
lag_30 = 30
lag_60 = 60
lag_90 = 90

r_2_results_carh = []
mse_results_carh = []

for name in data_ret.columns[2:]:
    
    df1 = data[[name, 'Hamada_beta_MRP_for_{}'.format(name[7:11]), 'risk_free_rate_based_on_g_curve',
                 'Hamada_d_mcap_ratio_SMB_for_{}'.format(name[7:11]),
                 'Hamada_d_mcap_ratio_HML_for_{}'.format(name[7:11]),
                 'MOM']].dropna()
    df_autolag = pd.DataFrame(data[name] - data['risk_free_rate_based_on_g_curve']).rename(columns = {0:'{}_premium_lag_{}_days'.format(name[7:], lag_autolag_return_30)})
    df_autolag = pd.DataFrame(df_autolag['{}_premium_lag_{}_days'.format(name[7:], lag_autolag_return_30)].shift(lag_autolag_return_30).dropna())
    
    df_autolag_2 = pd.DataFrame(data[name] - data['risk_free_rate_based_on_g_curve']).rename(columns = {0:'{}_premium_lag_{}_days'.format(name[7:], lag_autolag_return_60)})
    df_autolag_2 = pd.DataFrame(df_autolag_2['{}_premium_lag_{}_days'.format(name[7:], lag_autolag_return_60)].shift(lag_autolag_return_60).dropna())
    
    df_autolag_3 = pd.DataFrame(data[name] - data['risk_free_rate_based_on_g_curve']).rename(columns = {0:'{}_premium_lag_{}_days'.format(name[7:], lag_autolag_return_90)})
    df_autolag_3 = pd.DataFrame(df_autolag_3['{}_premium_lag_{}_days'.format(name[7:], lag_autolag_return_90)].shift(lag_autolag_return_90).dropna())
    
    df2 = data[['Hamada_d_mcap_ratio_SMB_for_{}'.format(name[7:11]),
            'Hamada_d_mcap_ratio_HML_for_{}'.format(name[7:11]), 'MOM']].shift(lag_30).dropna()
    
    
    
    df2.rename(columns = {'Hamada_d_mcap_ratio_SMB_for_{}'.format(name[7:11]):'Hamada_d_mcap_ratio_SMB_for_{}_lag_{}_days'.format(name[7:11], lag_30),
                          'Hamada_d_mcap_ratio_HML_for_{}'.format(name[7:11]):'Hamada_d_mcap_ratio_HML_for_{}_lag_{}_days'.format(name[7:11], lag_30), 
                          'MOM':'MOM_lag_{}_days'.format(lag_30)}, inplace = True)
    
    result = pd.concat([df1, df2], axis=1, join="inner")
    
    df3 = data[['Hamada_d_mcap_ratio_SMB_for_{}'.format(name[7:11]),
            'Hamada_d_mcap_ratio_HML_for_{}'.format(name[7:11]), 'MOM']].shift(lag_60).dropna()
    
    df3.rename(columns = {'Hamada_d_mcap_ratio_SMB_for_{}'.format(name[7:11]):'Hamada_d_mcap_ratio_SMB_for_{}_lag_{}_days'.format(name[7:11], lag_60),
                          'Hamada_d_mcap_ratio_HML_for_{}'.format(name[7:11]):'Hamada_d_mcap_ratio_HML_for_{}_lag_{}_days'.format(name[7:11], lag_60), 
                          'MOM':'MOM_lag_{}_days'.format(lag_60)}, inplace = True)
    
    result = pd.concat([result, df3], axis=1, join="inner")
    
    df4 = data[['Hamada_d_mcap_ratio_SMB_for_{}'.format(name[7:11]),
            'Hamada_d_mcap_ratio_HML_for_{}'.format(name[7:11]), 'MOM']].shift(lag_90).dropna()
    
    df4.rename(columns = {'Hamada_d_mcap_ratio_SMB_for_{}'.format(name[7:11]):'Hamada_d_mcap_ratio_SMB_for_{}_lag_{}_days'.format(name[7:11], lag_90),
                          'Hamada_d_mcap_ratio_HML_for_{}'.format(name[7:11]):'Hamada_d_mcap_ratio_HML_for_{}_lag_{}_days'.format(name[7:11], lag_90), 
                          'MOM':'MOM_lag_{}_days'.format(lag_90)}, inplace = True)
    
    result = pd.concat([result, df4], axis=1, join="inner")
    
    result = pd.merge(result, macro_data, left_index=True, right_index=True)
    result = pd.merge(result, df_autolag, left_index=True, right_index=True)
    result = pd.merge(result, df_autolag_2, left_index=True, right_index=True)
    result = pd.merge(result, df_autolag_3, left_index=True, right_index=True)
    
    Base = result.dropna()
    
    Y = pd.DataFrame(Base[name] - Base['risk_free_rate_based_on_g_curve'])
    Y.rename(columns = {0:'{} - risk free rate'.format(name)}, inplace = True)
    X = Base[['Hamada_beta_MRP_for_{}'.format(name[7:11]), 
              'Hamada_d_mcap_ratio_SMB_for_{}'.format(name[7:11]),
              'Hamada_d_mcap_ratio_HML_for_{}'.format(name[7:11]),'MOM']]
    model = sm.OLS(Y,X)
    results = model.fit(cov_type = 'HC1')
    print('###################################################################################')
    print(name[7:11])
    print(results.summary())
    
    print(results)
    r_2_results_carh.append(results.rsquared_adj)
    mse_results_carh.append(results.mse_resid)
# Out:
# ###################################################################################
# SBER
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_SBER_RM_Equity - risk free rate   R-squared (uncentered):                   0.410
# Model:                                                OLS   Adj. R-squared (uncentered):              0.409
# Method:                                     Least Squares   F-statistic:                              65.35
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                    5.71e-52
# Time:                                            19:27:34   Log-Likelihood:                          2256.8
# No. Observations:                                    1979   AIC:                                     -4506.
# Df Residuals:                                        1975   BIC:                                     -4483.
# Df Model:                                               4
# Covariance Type:                                      HC1
# ====================================================================================================
#                                        coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_SBER             0.4217      0.027     15.339      0.000       0.368       0.476
# Hamada_d_mcap_ratio_SMB_for_SBER     0.0803      0.026      3.102      0.002       0.030       0.131
# Hamada_d_mcap_ratio_HML_for_SBER    -0.0187      0.012     -1.602      0.109      -0.041       0.004
# MOM                                 -0.0110      0.017     -0.656      0.512      -0.044       0.022
# ==============================================================================
# Omnibus:                      284.576   Durbin-Watson:                   0.085
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              581.224
# Skew:                          -0.864   Prob(JB):                    6.15e-127
# Kurtosis:                       5.015   Cond. No.                         1.95
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe6e94070a0>
# ###################################################################################
# GAZP
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_GAZP_RM_Equity - risk free rate   R-squared (uncentered):                   0.641
# Model:                                                OLS   Adj. R-squared (uncentered):              0.641
# Method:                                     Least Squares   F-statistic:                              681.4
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                        0.00
# Time:                                            19:27:34   Log-Likelihood:                          2963.8
# No. Observations:                                    1979   AIC:                                     -5920.
# Df Residuals:                                        1975   BIC:                                     -5897.
# Df Model:                                               4
# Covariance Type:                                      HC1
# ====================================================================================================
#                                        coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_GAZP             0.7680      0.016     48.720      0.000       0.737       0.799
# Hamada_d_mcap_ratio_SMB_for_GAZP    -0.1028      0.019     -5.327      0.000      -0.141      -0.065
# Hamada_d_mcap_ratio_HML_for_GAZP    -0.0131      0.012     -1.110      0.267      -0.036       0.010
# MOM                                 -0.1037      0.010    -10.212      0.000      -0.124      -0.084
# ==============================================================================
# Omnibus:                      653.117   Durbin-Watson:                   0.080
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3226.387
# Skew:                           1.486   Prob(JB):                         0.00
# Kurtosis:                       8.504   Cond. No.                         2.03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe69823f6d0>
# ###################################################################################
# LKOH
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_LKOH_RM_Equity - risk free rate   R-squared (uncentered):                   0.683
# Model:                                                OLS   Adj. R-squared (uncentered):              0.683
# Method:                                     Least Squares   F-statistic:                              586.5
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                        0.00
# Time:                                            19:27:34   Log-Likelihood:                          3352.3
# No. Observations:                                    1979   AIC:                                     -6697.
# Df Residuals:                                        1975   BIC:                                     -6674.
# Df Model:                                               4
# Covariance Type:                                      HC1
# ====================================================================================================
#                                        coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_LKOH             0.9011      0.021     42.755      0.000       0.860       0.942
# Hamada_d_mcap_ratio_SMB_for_LKOH     0.0047      0.019      0.242      0.809      -0.033       0.043
# Hamada_d_mcap_ratio_HML_for_LKOH     0.0447      0.015      2.918      0.004       0.015       0.075
# MOM                                  0.0369      0.010      3.816      0.000       0.018       0.056
# ==============================================================================
# Omnibus:                       60.885   Durbin-Watson:                   0.130
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               91.534
# Skew:                          -0.296   Prob(JB):                     1.33e-20
# Kurtosis:                       3.871   Cond. No.                         2.67
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe6e94071c0>
# ###################################################################################
# GMKN
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_GMKN_RM_Equity - risk free rate   R-squared (uncentered):                   0.438
# Model:                                                OLS   Adj. R-squared (uncentered):              0.437
# Method:                                     Least Squares   F-statistic:                              311.3
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                   8.17e-208
# Time:                                            19:27:34   Log-Likelihood:                          2679.4
# No. Observations:                                    1979   AIC:                                     -5351.
# Df Residuals:                                        1975   BIC:                                     -5328.
# Df Model:                                               4
# Covariance Type:                                      HC1
# ====================================================================================================
#                                        coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_GMKN             0.7428      0.022     33.866      0.000       0.700       0.786
# Hamada_d_mcap_ratio_SMB_for_GMKN     0.0375      0.031      1.200      0.230      -0.024       0.099
# Hamada_d_mcap_ratio_HML_for_GMKN    -0.0026      0.018     -0.140      0.888      -0.038       0.033
# MOM                                  0.0733      0.013      5.666      0.000       0.048       0.099
# ==============================================================================
# Omnibus:                        4.040   Durbin-Watson:                   0.133
# Prob(Omnibus):                  0.133   Jarque-Bera (JB):                3.951
# Skew:                           0.096   Prob(JB):                        0.139
# Kurtosis:                       3.103   Cond. No.                         2.63
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe719ea3a60>
# ###################################################################################
# NVTK
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_NVTK_RM_Equity - risk free rate   R-squared (uncentered):                   0.444
# Model:                                                OLS   Adj. R-squared (uncentered):              0.443
# Method:                                     Least Squares   F-statistic:                              304.0
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                   7.02e-204
# Time:                                            19:27:34   Log-Likelihood:                          2699.1
# No. Observations:                                    1979   AIC:                                     -5390.
# Df Residuals:                                        1975   BIC:                                     -5368.
# Df Model:                                               4
# Covariance Type:                                      HC1
# ====================================================================================================
#                                        coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_NVTK             0.8347      0.027     31.282      0.000       0.782       0.887
# Hamada_d_mcap_ratio_SMB_for_NVTK    -0.2085      0.030     -6.902      0.000      -0.268      -0.149
# Hamada_d_mcap_ratio_HML_for_NVTK    -0.1024      0.026     -3.985      0.000      -0.153      -0.052
# MOM                                  0.0776      0.013      5.995      0.000       0.052       0.103
# ==============================================================================
# Omnibus:                        3.883   Durbin-Watson:                   0.122
# Prob(Omnibus):                  0.144   Jarque-Bera (JB):                4.019
# Skew:                           0.063   Prob(JB):                        0.134
# Kurtosis:                       3.181   Cond. No.                         2.89
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe6e9409ac0>
# ###################################################################################
# SNGS
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_SNGS_RM_Equity - risk free rate   R-squared (uncentered):                   0.547
# Model:                                                OLS   Adj. R-squared (uncentered):              0.546
# Method:                                     Least Squares   F-statistic:                              329.9
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                   1.53e-200
# Time:                                            19:27:34   Log-Likelihood:                          1627.8
# No. Observations:                                    1417   AIC:                                     -3248.
# Df Residuals:                                        1413   BIC:                                     -3227.
# Df Model:                                               4
# Covariance Type:                                      HC1
# ====================================================================================================
#                                        coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_SNGS             1.2910      0.036     35.393      0.000       1.220       1.363
# Hamada_d_mcap_ratio_SMB_for_SNGS    -0.1145      0.047     -2.438      0.015      -0.207      -0.022
# Hamada_d_mcap_ratio_HML_for_SNGS    -0.0501      0.028     -1.791      0.073      -0.105       0.005
# MOM                                 -0.0613      0.017     -3.521      0.000      -0.095      -0.027
# ==============================================================================
# Omnibus:                      169.616   Durbin-Watson:                   0.091
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              306.603
# Skew:                           0.773   Prob(JB):                     2.64e-67
# Kurtosis:                       4.675   Cond. No.                         2.95
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe719fe9e50>
# ###################################################################################
# PLZL
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_PLZL_RM_Equity - risk free rate   R-squared (uncentered):                   0.089
# Model:                                                OLS   Adj. R-squared (uncentered):              0.085
# Method:                                     Least Squares   F-statistic:                              30.32
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                    2.07e-23
# Time:                                            19:27:34   Log-Likelihood:                          643.41
# No. Observations:                                     753   AIC:                                     -1279.
# Df Residuals:                                         749   BIC:                                     -1260.
# Df Model:                                               4
# Covariance Type:                                      HC1
# ====================================================================================================
#                                        coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_PLZL            -0.1036      0.067     -1.558      0.119      -0.234       0.027
# Hamada_d_mcap_ratio_SMB_for_PLZL     0.1120      0.068      1.657      0.097      -0.020       0.244
# Hamada_d_mcap_ratio_HML_for_PLZL     0.1928      0.053      3.661      0.000       0.090       0.296
# MOM                                  0.2383      0.031      7.701      0.000       0.178       0.299
# ==============================================================================
# Omnibus:                       31.734   Durbin-Watson:                   0.083
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               55.958
# Skew:                           0.303   Prob(JB):                     7.06e-13
# Kurtosis:                       4.190   Cond. No.                         3.07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe69820d700>
# ###################################################################################
# TATN
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_TATN_RM_Equity - risk free rate   R-squared (uncentered):                   0.670
# Model:                                                OLS   Adj. R-squared (uncentered):              0.669
# Method:                                     Least Squares   F-statistic:                              673.6
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                        0.00
# Time:                                            19:27:34   Log-Likelihood:                          2829.0
# No. Observations:                                    1979   AIC:                                     -5650.
# Df Residuals:                                        1975   BIC:                                     -5628.
# Df Model:                                               4
# Covariance Type:                                      HC1
# ====================================================================================================
#                                        coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_TATN             1.2241      0.024     51.161      0.000       1.177       1.271
# Hamada_d_mcap_ratio_SMB_for_TATN    -0.1750      0.029     -5.997      0.000      -0.232      -0.118
# Hamada_d_mcap_ratio_HML_for_TATN     0.0589      0.019      3.086      0.002       0.021       0.096
# MOM                                  0.0332      0.012      2.750      0.006       0.010       0.057
# ==============================================================================
# Omnibus:                       46.258   Durbin-Watson:                   0.161
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               49.619
# Skew:                           0.359   Prob(JB):                     1.68e-11
# Kurtosis:                       3.293   Cond. No.                         2.85
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe69820d1f0>
# ###################################################################################
# ROSN
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_ROSN_RM_Equity - risk free rate   R-squared (uncentered):                   0.583
# Model:                                                OLS   Adj. R-squared (uncentered):              0.582
# Method:                                     Least Squares   F-statistic:                              425.6
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                   7.29e-264
# Time:                                            19:27:34   Log-Likelihood:                          2633.5
# No. Observations:                                    1956   AIC:                                     -5259.
# Df Residuals:                                        1952   BIC:                                     -5237.
# Df Model:                                               4
# Covariance Type:                                      HC1
# ====================================================================================================
#                                        coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_ROSN             0.7209      0.023     31.491      0.000       0.676       0.766
# Hamada_d_mcap_ratio_SMB_for_ROSN    -0.0416      0.017     -2.433      0.015      -0.075      -0.008
# Hamada_d_mcap_ratio_HML_for_ROSN    -0.0621      0.012     -5.033      0.000      -0.086      -0.038
# MOM                                 -0.0326      0.012     -2.647      0.008      -0.057      -0.008
# ==============================================================================
# Omnibus:                       77.133   Durbin-Watson:                   0.081
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              179.914
# Skew:                           0.211   Prob(JB):                     8.55e-40
# Kurtosis:                       4.425   Cond. No.                         1.94
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe719ea6c70>
# ###################################################################################
# MGNT
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_MGNT_RM_Equity - risk free rate   R-squared (uncentered):                   0.222
# Model:                                                OLS   Adj. R-squared (uncentered):              0.220
# Method:                                     Least Squares   F-statistic:                              116.6
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                    2.29e-89
# Time:                                            19:27:34   Log-Likelihood:                          1898.9
# No. Observations:                                    1979   AIC:                                     -3790.
# Df Residuals:                                        1975   BIC:                                     -3767.
# Df Model:                                               4
# Covariance Type:                                      HC1
# ====================================================================================================
#                                        coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_MGNT             0.4474      0.028     16.012      0.000       0.393       0.502
# Hamada_d_mcap_ratio_SMB_for_MGNT     0.1450      0.036      3.988      0.000       0.074       0.216
# Hamada_d_mcap_ratio_HML_for_MGNT     0.2748      0.024     11.431      0.000       0.228       0.322
# MOM                                 -0.1000      0.017     -5.857      0.000      -0.133      -0.067
# ==============================================================================
# Omnibus:                      347.950   Durbin-Watson:                   0.094
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              812.821
# Skew:                          -0.981   Prob(JB):                    3.15e-177
# Kurtosis:                       5.451   Cond. No.                         2.42
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe71a006d30>
# ###################################################################################
# MTSS
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_MTSS_RM_Equity - risk free rate   R-squared (uncentered):                   0.432
# Model:                                                OLS   Adj. R-squared (uncentered):              0.431
# Method:                                     Least Squares   F-statistic:                              281.6
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                   1.10e-191
# Time:                                            19:27:34   Log-Likelihood:                          2542.5
# No. Observations:                                    1979   AIC:                                     -5077.
# Df Residuals:                                        1975   BIC:                                     -5055.
# Df Model:                                               4
# Covariance Type:                                      HC1
# ====================================================================================================
#                                        coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_MTSS             0.6082      0.020     31.170      0.000       0.570       0.646
# Hamada_d_mcap_ratio_SMB_for_MTSS     0.0119      0.024      0.495      0.621      -0.035       0.059
# Hamada_d_mcap_ratio_HML_for_MTSS    -0.0976      0.019     -5.060      0.000      -0.135      -0.060
# MOM                                 -0.0360      0.014     -2.487      0.013      -0.064      -0.008
# ==============================================================================
# Omnibus:                      392.352   Durbin-Watson:                   0.095
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1443.686
# Skew:                          -0.941   Prob(JB):                         0.00
# Kurtosis:                       6.737   Cond. No.                         2.15
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe71a006dc0>
# ###################################################################################
# MOEX
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_MOEX_RM_Equity - risk free rate   R-squared (uncentered):                   0.105
# Model:                                                OLS   Adj. R-squared (uncentered):              0.103
# Method:                                     Least Squares   F-statistic:                              36.32
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                    5.17e-29
# Time:                                            19:27:34   Log-Likelihood:                          1665.9
# No. Observations:                                    1507   AIC:                                     -3324.
# Df Residuals:                                        1503   BIC:                                     -3303.
# Df Model:                                               4
# Covariance Type:                                      HC1
# ====================================================================================================
#                                        coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_MOEX             0.0982      0.010      9.441      0.000       0.078       0.119
# Hamada_d_mcap_ratio_SMB_for_MOEX     0.0429      0.009      4.557      0.000       0.024       0.061
# Hamada_d_mcap_ratio_HML_for_MOEX    -0.0452      0.011     -4.010      0.000      -0.067      -0.023
# MOM                                  0.0588      0.018      3.301      0.001       0.024       0.094
# ==============================================================================
# Omnibus:                       32.559   Durbin-Watson:                   0.096
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               56.601
# Skew:                           0.156   Prob(JB):                     5.12e-13
# Kurtosis:                       3.897   Cond. No.                         2.42
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe71a006eb0>
# ###################################################################################
# IRAO
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_IRAO_RM_Equity - risk free rate   R-squared (uncentered):                   0.309
# Model:                                                OLS   Adj. R-squared (uncentered):              0.307
# Method:                                     Least Squares   F-statistic:                              132.7
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                    1.15e-92
# Time:                                            19:27:34   Log-Likelihood:                          1129.5
# No. Observations:                                    1114   AIC:                                     -2251.
# Df Residuals:                                        1110   BIC:                                     -2231.
# Df Model:                                               4
# Covariance Type:                                      HC1
# ====================================================================================================
#                                        coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_IRAO             0.6391      0.042     15.265      0.000       0.557       0.721
# Hamada_d_mcap_ratio_SMB_for_IRAO     0.3103      0.059      5.227      0.000       0.194       0.427
# Hamada_d_mcap_ratio_HML_for_IRAO     0.1303      0.057      2.267      0.023       0.018       0.243
# MOM                                  0.2430      0.022     10.806      0.000       0.199       0.287
# ==============================================================================
# Omnibus:                      161.232   Durbin-Watson:                   0.106
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              258.440
# Skew:                           0.959   Prob(JB):                     7.59e-57
# Kurtosis:                       4.373   Cond. No.                         2.72
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe6b0fb3790>
# ###################################################################################
# NLMK
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_NLMK_RM_Equity - risk free rate   R-squared (uncentered):                   0.394
# Model:                                                OLS   Adj. R-squared (uncentered):              0.393
# Method:                                     Least Squares   F-statistic:                              360.9
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                   2.04e-233
# Time:                                            19:27:34   Log-Likelihood:                          2064.9
# No. Observations:                                    1979   AIC:                                     -4122.
# Df Residuals:                                        1975   BIC:                                     -4100.
# Df Model:                                               4
# Covariance Type:                                      HC1
# ====================================================================================================
#                                        coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_NLMK             0.8927      0.025     35.527      0.000       0.843       0.942
# Hamada_d_mcap_ratio_SMB_for_NLMK     0.0200      0.037      0.545      0.586      -0.052       0.092
# Hamada_d_mcap_ratio_HML_for_NLMK    -0.0566      0.023     -2.469      0.014      -0.101      -0.012
# MOM                                 -0.0048      0.017     -0.283      0.777      -0.038       0.029
# ==============================================================================
# Omnibus:                        7.285   Durbin-Watson:                   0.097
# Prob(Omnibus):                  0.026   Jarque-Bera (JB):                7.228
# Skew:                           0.145   Prob(JB):                       0.0269
# Kurtosis:                       3.056   Cond. No.                         2.54
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe71a006f70>
# ###################################################################################
# ALRS
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_ALRS_RM_Equity - risk free rate   R-squared (uncentered):                   0.206
# Model:                                                OLS   Adj. R-squared (uncentered):              0.204
# Method:                                     Least Squares   F-statistic:                              84.22
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                    1.80e-65
# Time:                                            19:27:34   Log-Likelihood:                          1679.5
# No. Observations:                                    1752   AIC:                                     -3351.
# Df Residuals:                                        1748   BIC:                                     -3329.
# Df Model:                                               4
# Covariance Type:                                      HC1
# ====================================================================================================
#                                        coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_ALRS             0.6079      0.037     16.535      0.000       0.536       0.680
# Hamada_d_mcap_ratio_SMB_for_ALRS     0.0727      0.045      1.633      0.102      -0.015       0.160
# Hamada_d_mcap_ratio_HML_for_ALRS    -0.0096      0.030     -0.323      0.747      -0.068       0.049
# MOM                                  0.0498      0.022      2.266      0.023       0.007       0.093
# ==============================================================================
# Omnibus:                      170.102   Durbin-Watson:                   0.074
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              312.695
# Skew:                           0.648   Prob(JB):                     1.26e-68
# Kurtosis:                       4.613   Cond. No.                         2.46
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe719fecf40>
# ###################################################################################
# CHMF
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_CHMF_RM_Equity - risk free rate   R-squared (uncentered):                   0.340
# Model:                                                OLS   Adj. R-squared (uncentered):              0.339
# Method:                                     Least Squares   F-statistic:                              216.0
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                   6.74e-154
# Time:                                            19:27:34   Log-Likelihood:                          2033.5
# No. Observations:                                    1979   AIC:                                     -4059.
# Df Residuals:                                        1975   BIC:                                     -4037.
# Df Model:                                               4
# Covariance Type:                                      HC1
# ====================================================================================================
#                                        coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_CHMF             0.7557      0.032     23.964      0.000       0.694       0.817
# Hamada_d_mcap_ratio_SMB_for_CHMF     0.1081      0.040      2.670      0.008       0.029       0.187
# Hamada_d_mcap_ratio_HML_for_CHMF     0.1218      0.027      4.437      0.000       0.068       0.176
# MOM                                  0.0350      0.018      1.966      0.049       0.000       0.070
# ==============================================================================
# Omnibus:                       16.079   Durbin-Watson:                   0.079
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               17.454
# Skew:                           0.174   Prob(JB):                     0.000162
# Kurtosis:                       3.300   Cond. No.                         2.45
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe71a006b80>
# ###################################################################################
# VTBR
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_VTBR_RM_Equity - risk free rate   R-squared (uncentered):                   0.249
# Model:                                                OLS   Adj. R-squared (uncentered):              0.248
# Method:                                     Least Squares   F-statistic:                              80.98
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                    1.04e-63
# Time:                                            19:27:34   Log-Likelihood:                          2024.1
# No. Observations:                                    1979   AIC:                                     -4040.
# Df Residuals:                                        1975   BIC:                                     -4018.
# Df Model:                                               4
# Covariance Type:                                      HC1
# ====================================================================================================
#                                        coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_VTBR             0.1908      0.011     17.351      0.000       0.169       0.212
# Hamada_d_mcap_ratio_SMB_for_VTBR    -0.0118      0.011     -1.065      0.287      -0.034       0.010
# Hamada_d_mcap_ratio_HML_for_VTBR     0.0071      0.006      1.171      0.242      -0.005       0.019
# MOM                                 -0.1184      0.020     -6.021      0.000      -0.157      -0.080
# ==============================================================================
# Omnibus:                      703.554   Durbin-Watson:                   0.066
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4819.200
# Skew:                           1.501   Prob(JB):                         0.00
# Kurtosis:                      10.031   Cond. No.                         2.66
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe71a006e80>
# ###################################################################################
# RTKM
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_RTKM_RM_Equity - risk free rate   R-squared (uncentered):                   0.297
# Model:                                                OLS   Adj. R-squared (uncentered):              0.296
# Method:                                     Least Squares   F-statistic:                              201.0
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                   5.53e-143
# Time:                                            19:27:34   Log-Likelihood:                          2320.2
# No. Observations:                                    1831   AIC:                                     -4632.
# Df Residuals:                                        1827   BIC:                                     -4610.
# Df Model:                                               4
# Covariance Type:                                      HC1
# ====================================================================================================
#                                        coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_RTKM             0.4051      0.014     28.009      0.000       0.377       0.433
# Hamada_d_mcap_ratio_SMB_for_RTKM    -0.1274      0.021     -6.076      0.000      -0.169      -0.086
# Hamada_d_mcap_ratio_HML_for_RTKM     0.0596      0.016      3.673      0.000       0.028       0.091
# MOM                                 -0.0934      0.014     -6.728      0.000      -0.121      -0.066
# ==============================================================================
# Omnibus:                       11.667   Durbin-Watson:                   0.099
# Prob(Omnibus):                  0.003   Jarque-Bera (JB):               15.171
# Skew:                           0.074   Prob(JB):                     0.000508
# Kurtosis:                       3.421   Cond. No.                         1.93
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe71a0069d0>
# ###################################################################################
# PHOR
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_PHOR_RM_Equity - risk free rate   R-squared (uncentered):                   0.150
# Model:                                                OLS   Adj. R-squared (uncentered):              0.148
# Method:                                     Least Squares   F-statistic:                              46.51
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                    3.73e-37
# Time:                                            19:27:34   Log-Likelihood:                          1988.4
# No. Observations:                                    1720   AIC:                                     -3969.
# ...
# Kurtosis:                       5.431   Cond. No.                         1.78
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe698253610>
# ###################################################################################
# BSPB
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_BSPB_RM_Equity - risk free rate   R-squared (uncentered):                   0.218
# Model:                                                OLS   Adj. R-squared (uncentered):              0.216
# Method:                                     Least Squares   F-statistic:                              68.90
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                    1.17e-54
# Time:                                            19:27:35   Log-Likelihood:                          1709.8
# No. Observations:                                    1979   AIC:                                     -3412.
# Df Residuals:                                        1975   BIC:                                     -3389.
# Df Model:                                               4
# Covariance Type:                                      HC1
# ====================================================================================================
#                                        coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_BSPB             0.1150      0.009     13.239      0.000       0.098       0.132
# Hamada_d_mcap_ratio_SMB_for_BSPB     0.0307      0.009      3.433      0.001       0.013       0.048
# Hamada_d_mcap_ratio_HML_for_BSPB    -0.0206      0.006     -3.368      0.001      -0.033      -0.009
# MOM                                 -0.1249      0.023     -5.520      0.000      -0.169      -0.081
# ==============================================================================
# Omnibus:                       76.892   Durbin-Watson:                   0.086
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              148.180
# Skew:                          -0.278   Prob(JB):                     6.65e-33
# Kurtosis:                       4.220   Cond. No.                         3.84
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe698253c40>
# ###################################################################################
# MSRS
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_MSRS_RM_Equity - risk free rate   R-squared (uncentered):                   0.439
# Model:                                                OLS   Adj. R-squared (uncentered):              0.435
# Method:                                     Least Squares   F-statistic:                              134.2
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                    5.06e-83
# Time:                                            19:27:35   Log-Likelihood:                          831.86
# No. Observations:                                     638   AIC:                                     -1656.
# Df Residuals:                                         634   BIC:                                     -1638.
# Df Model:                                               4
# Covariance Type:                                      HC1
# ====================================================================================================
#                                        coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_MSRS             0.3413      0.017     19.967      0.000       0.308       0.375
# Hamada_d_mcap_ratio_SMB_for_MSRS     0.0692      0.022      3.081      0.002       0.025       0.113
# Hamada_d_mcap_ratio_HML_for_MSRS    -0.0242      0.017     -1.408      0.159      -0.058       0.009
# MOM                                 -0.0184      0.021     -0.864      0.388      -0.060       0.023
# ==============================================================================
# Omnibus:                       47.393   Durbin-Watson:                   0.103
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               55.998
# Skew:                           0.700   Prob(JB):                     6.92e-13
# Kurtosis:                       3.384   Cond. No.                         2.08
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe6e9401e50>
# ###################################################################################
# KMAZ
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_KMAZ_RM_Equity - risk free rate   R-squared (uncentered):                   0.213
# Model:                                                OLS   Adj. R-squared (uncentered):              0.212
# Method:                                     Least Squares   F-statistic:                              131.7
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                   8.94e-100
# Time:                                            19:27:35   Log-Likelihood:                          1691.2
# No. Observations:                                    1979   AIC:                                     -3374.
# Df Residuals:                                        1975   BIC:                                     -3352.
# Df Model:                                               4
# Covariance Type:                                      HC1
# ====================================================================================================
#                                        coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_KMAZ             0.4020      0.019     20.954      0.000       0.364       0.440
# Hamada_d_mcap_ratio_SMB_for_KMAZ    -0.0203      0.030     -0.678      0.498      -0.079       0.038
# Hamada_d_mcap_ratio_HML_for_KMAZ    -0.0767      0.023     -3.383      0.001      -0.121      -0.032
# MOM                                 -0.0243      0.021     -1.174      0.240      -0.065       0.016
# ==============================================================================
# Omnibus:                      398.920   Durbin-Watson:                   0.106
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              903.506
# Skew:                           1.127   Prob(JB):                    6.40e-197
# Kurtosis:                       5.424   Cond. No.                         1.71
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe698237b50>
# ###################################################################################
# RASP
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_RASP_RM_Equity - risk free rate   R-squared (uncentered):                   0.296
# Model:                                                OLS   Adj. R-squared (uncentered):              0.295
# Method:                                     Least Squares   F-statistic:                              117.2
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                    9.26e-90
# Time:                                            19:27:35   Log-Likelihood:                          1115.8
# No. Observations:                                    1979   AIC:                                     -2224.
# Df Residuals:                                        1975   BIC:                                     -2201.
# Df Model:                                               4
# Covariance Type:                                      HC1
# ====================================================================================================
#                                        coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_RASP             0.9196      0.048     19.208      0.000       0.826       1.013
# Hamada_d_mcap_ratio_SMB_for_RASP     0.1361      0.054      2.536      0.011       0.031       0.241
# Hamada_d_mcap_ratio_HML_for_RASP     0.0162      0.035      0.462      0.644      -0.052       0.085
# MOM                                 -0.0619      0.030     -2.072      0.038      -0.120      -0.003
# ==============================================================================
# Omnibus:                      151.004   Durbin-Watson:                   0.076
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              209.318
# Skew:                           0.633   Prob(JB):                     3.53e-46
# Kurtosis:                       3.967   Cond. No.                         2.15
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe6982539a0>
# ###################################################################################
# OGKB
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_OGKB_RM_Equity - risk free rate   R-squared (uncentered):                   0.235
# Model:                                                OLS   Adj. R-squared (uncentered):              0.234
# Method:                                     Least Squares   F-statistic:                              68.74
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                    1.68e-54
# Time:                                            19:27:35   Log-Likelihood:                          1306.3
# No. Observations:                                    1956   AIC:                                     -2605.
# Df Residuals:                                        1952   BIC:                                     -2582.
# Df Model:                                               4
# Covariance Type:                                      HC1
# ====================================================================================================
#                                        coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_OGKB             0.5135      0.037     13.704      0.000       0.440       0.587
# Hamada_d_mcap_ratio_SMB_for_OGKB    -0.0662      0.039     -1.685      0.092      -0.143       0.011
# Hamada_d_mcap_ratio_HML_for_OGKB    -0.1491      0.021     -7.090      0.000      -0.190      -0.108
# MOM                                 -0.0621      0.026     -2.384      0.017      -0.113      -0.011
# ==============================================================================
# Omnibus:                      149.592   Durbin-Watson:                   0.073
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              335.433
# Skew:                           0.473   Prob(JB):                     1.45e-73
# Kurtosis:                       4.794   Cond. No.                         1.80
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe698253790>
# ###################################################################################
# VZRZ
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_VZRZ_RM_Equity - risk free rate   R-squared (uncentered):                   0.048
# Model:                                                OLS   Adj. R-squared (uncentered):              0.046
# Method:                                     Least Squares   F-statistic:                              24.79
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                    4.69e-20
# Time:                                            19:27:36   Log-Likelihood:                          1674.0
# No. Observations:                                    1979   AIC:                                     -3340.
# Df Residuals:                                        1975   BIC:                                     -3318.
# Df Model:                                               4
# Covariance Type:                                      HC1
# ====================================================================================================
#                                        coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_VZRZ             0.0150      0.018      0.838      0.402      -0.020       0.050
# Hamada_d_mcap_ratio_SMB_for_VZRZ     0.1788      0.024      7.389      0.000       0.131       0.226
# Hamada_d_mcap_ratio_HML_for_VZRZ     0.0395      0.018      2.182      0.029       0.004       0.075
# MOM                                 -0.1036      0.019     -5.341      0.000      -0.142      -0.066
# ==============================================================================
# Omnibus:                       37.433   Durbin-Watson:                   0.103
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               63.969
# Skew:                          -0.140   Prob(JB):                     1.29e-14
# Kurtosis:                       3.835   Cond. No.                         1.76
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe698253100>

# %% [markdown]
# ## Carhart model with lags

# %%
lag_autolag_return_30 = 30
lag_autolag_return_60 = 60
lag_autolag_return_90 = 90
lag_30 = 30
lag_60 = 60
lag_90 = 90

r_2_results_carh_l = []
mse_results_carh_l = []

for name in data_ret.columns[2:]:
    
    df1 = data[[name, 'Hamada_beta_MRP_for_{}'.format(name[7:11]), 'risk_free_rate_based_on_g_curve',
                 'Hamada_d_mcap_ratio_SMB_for_{}'.format(name[7:11]),
                 'Hamada_d_mcap_ratio_HML_for_{}'.format(name[7:11]),
                 'MOM']].dropna()
    df_autolag = pd.DataFrame(data[name] - data['risk_free_rate_based_on_g_curve']).rename(columns = {0:'{}_premium_lag_{}_days'.format(name[7:], lag_autolag_return_30)})
    df_autolag = pd.DataFrame(df_autolag['{}_premium_lag_{}_days'.format(name[7:], lag_autolag_return_30)].shift(lag_autolag_return_30).dropna())
    
    df_autolag_2 = pd.DataFrame(data[name] - data['risk_free_rate_based_on_g_curve']).rename(columns = {0:'{}_premium_lag_{}_days'.format(name[7:], lag_autolag_return_60)})
    df_autolag_2 = pd.DataFrame(df_autolag_2['{}_premium_lag_{}_days'.format(name[7:], lag_autolag_return_60)].shift(lag_autolag_return_60).dropna())
    
    df_autolag_3 = pd.DataFrame(data[name] - data['risk_free_rate_based_on_g_curve']).rename(columns = {0:'{}_premium_lag_{}_days'.format(name[7:], lag_autolag_return_90)})
    df_autolag_3 = pd.DataFrame(df_autolag_3['{}_premium_lag_{}_days'.format(name[7:], lag_autolag_return_90)].shift(lag_autolag_return_90).dropna())
    
    df2 = data[['Hamada_d_mcap_ratio_SMB_for_{}'.format(name[7:11]),
            'Hamada_d_mcap_ratio_HML_for_{}'.format(name[7:11]), 'MOM']].shift(lag_30).dropna()
    
    
    
    df2.rename(columns = {'Hamada_d_mcap_ratio_SMB_for_{}'.format(name[7:11]):'Hamada_d_mcap_ratio_SMB_for_{}_lag_{}_days'.format(name[7:11], lag_30),
                          'Hamada_d_mcap_ratio_HML_for_{}'.format(name[7:11]):'Hamada_d_mcap_ratio_HML_for_{}_lag_{}_days'.format(name[7:11], lag_30), 
                          'MOM':'MOM_lag_{}_days'.format(lag_30)}, inplace = True)
    
    result = pd.concat([df1, df2], axis=1, join="inner")
    
    df3 = data[['Hamada_d_mcap_ratio_SMB_for_{}'.format(name[7:11]),
            'Hamada_d_mcap_ratio_HML_for_{}'.format(name[7:11]), 'MOM']].shift(lag_60).dropna()
    
    df3.rename(columns = {'Hamada_d_mcap_ratio_SMB_for_{}'.format(name[7:11]):'Hamada_d_mcap_ratio_SMB_for_{}_lag_{}_days'.format(name[7:11], lag_60),
                          'Hamada_d_mcap_ratio_HML_for_{}'.format(name[7:11]):'Hamada_d_mcap_ratio_HML_for_{}_lag_{}_days'.format(name[7:11], lag_60), 
                          'MOM':'MOM_lag_{}_days'.format(lag_60)}, inplace = True)
    
    result = pd.concat([result, df3], axis=1, join="inner")
    
    df4 = data[['Hamada_d_mcap_ratio_SMB_for_{}'.format(name[7:11]),
            'Hamada_d_mcap_ratio_HML_for_{}'.format(name[7:11]), 'MOM']].shift(lag_90).dropna()
    
    df4.rename(columns = {'Hamada_d_mcap_ratio_SMB_for_{}'.format(name[7:11]):'Hamada_d_mcap_ratio_SMB_for_{}_lag_{}_days'.format(name[7:11], lag_90),
                          'Hamada_d_mcap_ratio_HML_for_{}'.format(name[7:11]):'Hamada_d_mcap_ratio_HML_for_{}_lag_{}_days'.format(name[7:11], lag_90), 
                          'MOM':'MOM_lag_{}_days'.format(lag_90)}, inplace = True)
    
    result = pd.concat([result, df4], axis=1, join="inner")
    
    result = pd.merge(result, macro_data, left_index=True, right_index=True)
    result = pd.merge(result, df_autolag, left_index=True, right_index=True)
    result = pd.merge(result, df_autolag_2, left_index=True, right_index=True)
    result = pd.merge(result, df_autolag_3, left_index=True, right_index=True)
    
    Base = result.dropna()
    
    Y = pd.DataFrame(Base[name] - Base['risk_free_rate_based_on_g_curve'])
    Y.rename(columns = {0:'{} - risk free rate'.format(name)}, inplace = True)
    X = Base[['Hamada_beta_MRP_for_{}'.format(name[7:11]), 
              'Hamada_d_mcap_ratio_SMB_for_{}'.format(name[7:11]),
              'Hamada_d_mcap_ratio_HML_for_{}'.format(name[7:11]), 
              'Hamada_d_mcap_ratio_SMB_for_{}_lag_{}_days'.format(name[7:11], lag_30),
              'Hamada_d_mcap_ratio_HML_for_{}_lag_{}_days'.format(name[7:11], lag_30),
              'Hamada_d_mcap_ratio_SMB_for_{}_lag_{}_days'.format(name[7:11], lag_60),
              'Hamada_d_mcap_ratio_HML_for_{}_lag_{}_days'.format(name[7:11], lag_60),
              'Hamada_d_mcap_ratio_SMB_for_{}_lag_{}_days'.format(name[7:11], lag_90),
              'Hamada_d_mcap_ratio_HML_for_{}_lag_{}_days'.format(name[7:11], lag_90),
              'MOM','MOM_lag_{}_days'.format(lag_30),'MOM_lag_{}_days'.format(lag_60),
              'MOM_lag_{}_days'.format(lag_90)]]
    model = sm.OLS(Y,X)
    results = model.fit(cov_type = 'HC1')
    print('###################################################################################')
    print(name[7:11])
    print(results.summary())
   
    print(results)
    r_2_results_carh_l.append(results.rsquared_adj)
    mse_results_carh_l.append(results.mse_resid)
# Out:
# ###################################################################################
# SBER
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_SBER_RM_Equity - risk free rate   R-squared (uncentered):                   0.545
# Model:                                                OLS   Adj. R-squared (uncentered):              0.542
# Method:                                     Least Squares   F-statistic:                              106.8
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                   7.35e-217
# Time:                                            19:27:36   Log-Likelihood:                          2514.2
# No. Observations:                                    1979   AIC:                                     -5002.
# Df Residuals:                                        1966   BIC:                                     -4930.
# Df Model:                                              13
# Covariance Type:                                      HC1
# ================================================================================================================
#                                                    coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_SBER                         0.4270      0.023     18.766      0.000       0.382       0.472
# Hamada_d_mcap_ratio_SMB_for_SBER                 0.0539      0.022      2.452      0.014       0.011       0.097
# Hamada_d_mcap_ratio_HML_for_SBER                 0.0001      0.011      0.011      0.992      -0.021       0.022
# Hamada_d_mcap_ratio_SMB_for_SBER_lag_30_days     0.0548      0.019      2.890      0.004       0.018       0.092
# Hamada_d_mcap_ratio_HML_for_SBER_lag_30_days    -0.1330      0.012    -10.942      0.000      -0.157      -0.109
# Hamada_d_mcap_ratio_SMB_for_SBER_lag_60_days     0.0680      0.016      4.321      0.000       0.037       0.099
# Hamada_d_mcap_ratio_HML_for_SBER_lag_60_days    -0.0213      0.017     -1.228      0.219      -0.055       0.013
# Hamada_d_mcap_ratio_SMB_for_SBER_lag_90_days     0.0286      0.016      1.804      0.071      -0.002       0.060
# Hamada_d_mcap_ratio_HML_for_SBER_lag_90_days     0.0027      0.011      0.238      0.812      -0.020       0.025
# MOM                                              0.0815      0.042      1.929      0.054      -0.001       0.164
# MOM_lag_30_days                                 -0.4503      0.055     -8.241      0.000      -0.557      -0.343
# MOM_lag_60_days                                 -0.0304      0.038     -0.807      0.420      -0.104       0.043
# MOM_lag_90_days                                  0.4291      0.045      9.586      0.000       0.341       0.517
# ==============================================================================
# Omnibus:                       62.402   Durbin-Watson:                   0.133
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              104.024
# Skew:                          -0.269   Prob(JB):                     2.58e-23
# Kurtosis:                       3.986   Cond. No.                         8.58
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe698237bb0>
# ###################################################################################
# GAZP
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_GAZP_RM_Equity - risk free rate   R-squared (uncentered):                   0.725
# Model:                                                OLS   Adj. R-squared (uncentered):              0.723
# Method:                                     Least Squares   F-statistic:                              246.0
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                        0.00
# Time:                                            19:27:36   Log-Likelihood:                          3226.0
# No. Observations:                                    1979   AIC:                                     -6426.
# Df Residuals:                                        1966   BIC:                                     -6353.
# Df Model:                                              13
# Covariance Type:                                      HC1
# ================================================================================================================
#                                                    coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_GAZP                         0.6904      0.016     44.326      0.000       0.660       0.721
# Hamada_d_mcap_ratio_SMB_for_GAZP                -0.0872      0.020     -4.322      0.000      -0.127      -0.048
# Hamada_d_mcap_ratio_HML_for_GAZP                 0.0146      0.013      1.158      0.247      -0.010       0.039
# Hamada_d_mcap_ratio_SMB_for_GAZP_lag_30_days    -0.1894      0.019     -9.878      0.000      -0.227      -0.152
# Hamada_d_mcap_ratio_HML_for_GAZP_lag_30_days    -0.2067      0.016    -12.658      0.000      -0.239      -0.175
# Hamada_d_mcap_ratio_SMB_for_GAZP_lag_60_days    -0.0059      0.017     -0.353      0.724      -0.038       0.027
# Hamada_d_mcap_ratio_HML_for_GAZP_lag_60_days    -0.0680      0.012     -5.561      0.000      -0.092      -0.044
# Hamada_d_mcap_ratio_SMB_for_GAZP_lag_90_days    -0.0120      0.015     -0.786      0.432      -0.042       0.018
# Hamada_d_mcap_ratio_HML_for_GAZP_lag_90_days     0.0665      0.011      6.125      0.000       0.045       0.088
# MOM                                             -0.1370      0.029     -4.724      0.000      -0.194      -0.080
# MOM_lag_30_days                                  0.2368      0.038      6.260      0.000       0.163       0.311
# MOM_lag_60_days                                 -0.0521      0.034     -1.536      0.124      -0.118       0.014
# MOM_lag_90_days                                 -0.1098      0.029     -3.780      0.000      -0.167      -0.053
# ==============================================================================
# Omnibus:                      196.364   Durbin-Watson:                   0.128
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              420.497
# Skew:                           0.614   Prob(JB):                     4.90e-92
# Kurtosis:                       4.896   Cond. No.                         8.19
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe698253c40>
# ###################################################################################
# LKOH
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_LKOH_RM_Equity - risk free rate   R-squared (uncentered):                   0.716
# Model:                                                OLS   Adj. R-squared (uncentered):              0.714
# Method:                                     Least Squares   F-statistic:                              261.6
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                        0.00
# Time:                                            19:27:36   Log-Likelihood:                          3459.1
# No. Observations:                                    1979   AIC:                                     -6892.
# Df Residuals:                                        1966   BIC:                                     -6820.
# Df Model:                                              13
# Covariance Type:                                      HC1
# ================================================================================================================
#                                                    coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_LKOH                         0.8978      0.020     44.796      0.000       0.859       0.937
# Hamada_d_mcap_ratio_SMB_for_LKOH                 0.0555      0.020      2.818      0.005       0.017       0.094
# Hamada_d_mcap_ratio_HML_for_LKOH                 0.0172      0.016      1.096      0.273      -0.014       0.048
# Hamada_d_mcap_ratio_SMB_for_LKOH_lag_30_days    -0.1948      0.019    -10.152      0.000      -0.232      -0.157
# Hamada_d_mcap_ratio_HML_for_LKOH_lag_30_days     0.0726      0.019      3.797      0.000       0.035       0.110
# Hamada_d_mcap_ratio_SMB_for_LKOH_lag_60_days    -0.0849      0.022     -3.917      0.000      -0.127      -0.042
# Hamada_d_mcap_ratio_HML_for_LKOH_lag_60_days     0.0768      0.015      5.212      0.000       0.048       0.106
# Hamada_d_mcap_ratio_SMB_for_LKOH_lag_90_days     0.0091      0.018      0.511      0.609      -0.026       0.044
# Hamada_d_mcap_ratio_HML_for_LKOH_lag_90_days    -0.0167      0.012     -1.388      0.165      -0.040       0.007
# MOM                                              0.0411      0.026      1.602      0.109      -0.009       0.091
# MOM_lag_30_days                                  0.0280      0.037      0.760      0.447      -0.044       0.100
# MOM_lag_60_days                                 -0.1206      0.029     -4.163      0.000      -0.177      -0.064
# MOM_lag_90_days                                  0.0639      0.028      2.315      0.021       0.010       0.118
# ==============================================================================
# Omnibus:                      153.950   Durbin-Watson:                   0.155
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              266.094
# Skew:                          -0.562   Prob(JB):                     1.65e-58
# Kurtosis:                       4.402   Cond. No.                         8.33
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe698253100>
# ###################################################################################
# GMKN
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_GMKN_RM_Equity - risk free rate   R-squared (uncentered):                   0.521
# Model:                                                OLS   Adj. R-squared (uncentered):              0.518
# Method:                                     Least Squares   F-statistic:                              136.5
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                   4.57e-263
# Time:                                            19:27:36   Log-Likelihood:                          2837.5
# No. Observations:                                    1979   AIC:                                     -5649.
# Df Residuals:                                        1966   BIC:                                     -5576.
# Df Model:                                              13
# Covariance Type:                                      HC1
# ================================================================================================================
#                                                    coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_GMKN                         0.8586      0.023     37.241      0.000       0.813       0.904
# Hamada_d_mcap_ratio_SMB_for_GMKN                 0.0902      0.030      3.007      0.003       0.031       0.149
# Hamada_d_mcap_ratio_HML_for_GMKN                -0.0623      0.018     -3.518      0.000      -0.097      -0.028
# Hamada_d_mcap_ratio_SMB_for_GMKN_lag_30_days    -0.0101      0.029     -0.343      0.732      -0.068       0.048
# Hamada_d_mcap_ratio_HML_for_GMKN_lag_30_days     0.3097      0.021     14.437      0.000       0.268       0.352
# Hamada_d_mcap_ratio_SMB_for_GMKN_lag_60_days    -0.0876      0.026     -3.384      0.001      -0.138      -0.037
# Hamada_d_mcap_ratio_HML_for_GMKN_lag_60_days    -0.0769      0.025     -3.083      0.002      -0.126      -0.028
# Hamada_d_mcap_ratio_SMB_for_GMKN_lag_90_days    -0.0794      0.026     -3.002      0.003      -0.131      -0.028
# Hamada_d_mcap_ratio_HML_for_GMKN_lag_90_days    -0.1090      0.019     -5.606      0.000      -0.147      -0.071
# MOM                                              0.0948      0.036      2.665      0.008       0.025       0.165
# MOM_lag_30_days                                  0.0870      0.037      2.325      0.020       0.014       0.160
# MOM_lag_60_days                                 -0.0013      0.035     -0.037      0.971      -0.069       0.067
# MOM_lag_90_days                                 -0.1317      0.040     -3.285      0.001      -0.210      -0.053
# ==============================================================================
# Omnibus:                        7.341   Durbin-Watson:                   0.176
# Prob(Omnibus):                  0.025   Jarque-Bera (JB):                7.234
# Skew:                           0.127   Prob(JB):                       0.0269
# Kurtosis:                       2.848   Cond. No.                         8.38
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe719f18a30>
# ###################################################################################
# NVTK
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_NVTK_RM_Equity - risk free rate   R-squared (uncentered):                   0.534
# Model:                                                OLS   Adj. R-squared (uncentered):              0.530
# Method:                                     Least Squares   F-statistic:                              142.7
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                   3.82e-272
# Time:                                            19:27:36   Log-Likelihood:                          2873.3
# No. Observations:                                    1979   AIC:                                     -5721.
# Df Residuals:                                        1966   BIC:                                     -5648.
# Df Model:                                              13
# Covariance Type:                                      HC1
# ================================================================================================================
#                                                    coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_NVTK                         0.8430      0.027     30.752      0.000       0.789       0.897
# Hamada_d_mcap_ratio_SMB_for_NVTK                -0.2226      0.030     -7.472      0.000      -0.281      -0.164
# Hamada_d_mcap_ratio_HML_for_NVTK                -0.1391      0.024     -5.707      0.000      -0.187      -0.091
# Hamada_d_mcap_ratio_SMB_for_NVTK_lag_30_days    -0.3664      0.033    -11.131      0.000      -0.431      -0.302
# Hamada_d_mcap_ratio_HML_for_NVTK_lag_30_days     0.2009      0.020     10.171      0.000       0.162       0.240
# Hamada_d_mcap_ratio_SMB_for_NVTK_lag_60_days     0.1019      0.027      3.795      0.000       0.049       0.154
# Hamada_d_mcap_ratio_HML_for_NVTK_lag_60_days    -0.0533      0.019     -2.759      0.006      -0.091      -0.015
# Hamada_d_mcap_ratio_SMB_for_NVTK_lag_90_days    -0.0271      0.031     -0.880      0.379      -0.087       0.033
# Hamada_d_mcap_ratio_HML_for_NVTK_lag_90_days    -0.1025      0.019     -5.537      0.000      -0.139      -0.066
# MOM                                             -0.1728      0.035     -4.975      0.000      -0.241      -0.105
# MOM_lag_30_days                                 -0.0554      0.042     -1.333      0.183      -0.137       0.026
# MOM_lag_60_days                                  0.2241      0.035      6.454      0.000       0.156       0.292
# MOM_lag_90_days                                  0.0983      0.038      2.618      0.009       0.025       0.172
# ==============================================================================
# Omnibus:                        6.519   Durbin-Watson:                   0.166
# Prob(Omnibus):                  0.038   Jarque-Bera (JB):                6.653
# Skew:                           0.109   Prob(JB):                       0.0359
# Kurtosis:                       3.181   Cond. No.                         8.50
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe6d83eba00>
# ###################################################################################
# SNGS
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_SNGS_RM_Equity - risk free rate   R-squared (uncentered):                   0.601
# Model:                                                OLS   Adj. R-squared (uncentered):              0.598
# Method:                                     Least Squares   F-statistic:                              167.2
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                   6.29e-274
# Time:                                            19:27:36   Log-Likelihood:                          1718.5
# No. Observations:                                    1417   AIC:                                     -3411.
# Df Residuals:                                        1404   BIC:                                     -3343.
# Df Model:                                              13
# Covariance Type:                                      HC1
# ================================================================================================================
#                                                    coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_SNGS                         1.1698      0.036     32.726      0.000       1.100       1.240
# Hamada_d_mcap_ratio_SMB_for_SNGS                -0.1623      0.048     -3.399      0.001      -0.256      -0.069
# Hamada_d_mcap_ratio_HML_for_SNGS                 0.0182      0.027      0.667      0.505      -0.035       0.071
# Hamada_d_mcap_ratio_SMB_for_SNGS_lag_30_days    -0.0282      0.043     -0.655      0.512      -0.112       0.056
# Hamada_d_mcap_ratio_HML_for_SNGS_lag_30_days    -0.1004      0.027     -3.762      0.000      -0.153      -0.048
# Hamada_d_mcap_ratio_SMB_for_SNGS_lag_60_days     0.1115      0.041      2.752      0.006       0.032       0.191
# Hamada_d_mcap_ratio_HML_for_SNGS_lag_60_days     0.2413      0.029      8.420      0.000       0.185       0.298
# Hamada_d_mcap_ratio_SMB_for_SNGS_lag_90_days    -0.1912      0.043     -4.419      0.000      -0.276      -0.106
# Hamada_d_mcap_ratio_HML_for_SNGS_lag_90_days     0.1005      0.037      2.683      0.007       0.027       0.174
# MOM                                             -0.2219      0.047     -4.765      0.000      -0.313      -0.131
# MOM_lag_30_days                                 -0.3243      0.046     -6.998      0.000      -0.415      -0.234
# MOM_lag_60_days                                  0.2319      0.049      4.716      0.000       0.136       0.328
# MOM_lag_90_days                                  0.2490      0.051      4.848      0.000       0.148       0.350
# ==============================================================================
# Omnibus:                      227.057   Durbin-Watson:                   0.116
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              470.361
# Skew:                           0.936   Prob(JB):                    7.29e-103
# Kurtosis:                       5.112   Cond. No.                         8.63
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe6f84269a0>
# ###################################################################################
# PLZL
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_PLZL_RM_Equity - risk free rate   R-squared (uncentered):                   0.305
# Model:                                                OLS   Adj. R-squared (uncentered):              0.293
# Method:                                     Least Squares   F-statistic:                              53.25
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                    7.12e-97
# Time:                                            19:27:36   Log-Likelihood:                          745.23
# No. Observations:                                     753   AIC:                                     -1464.
# Df Residuals:                                         740   BIC:                                     -1404.
# Df Model:                                              13
# Covariance Type:                                      HC1
# ================================================================================================================
#                                                    coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_PLZL                         0.1271      0.079      1.611      0.107      -0.028       0.282
# Hamada_d_mcap_ratio_SMB_for_PLZL                -0.0171      0.075     -0.227      0.820      -0.165       0.130
# Hamada_d_mcap_ratio_HML_for_PLZL                 0.2847      0.059      4.841      0.000       0.169       0.400
# Hamada_d_mcap_ratio_SMB_for_PLZL_lag_30_days     0.4565      0.088      5.209      0.000       0.285       0.628
# Hamada_d_mcap_ratio_HML_for_PLZL_lag_30_days     0.1273      0.085      1.497      0.134      -0.039       0.294
# Hamada_d_mcap_ratio_SMB_for_PLZL_lag_60_days     0.5963      0.085      7.016      0.000       0.430       0.763
# Hamada_d_mcap_ratio_HML_for_PLZL_lag_60_days    -0.3461      0.074     -4.689      0.000      -0.491      -0.201
# Hamada_d_mcap_ratio_SMB_for_PLZL_lag_90_days     0.0544      0.076      0.716      0.474      -0.095       0.203
# Hamada_d_mcap_ratio_HML_for_PLZL_lag_90_days    -0.3797      0.064     -5.932      0.000      -0.505      -0.254
# MOM                                             -0.4829      0.082     -5.901      0.000      -0.643      -0.323
# MOM_lag_30_days                                  0.0886      0.105      0.843      0.399      -0.117       0.295
# MOM_lag_60_days                                  0.4511      0.088      5.101      0.000       0.278       0.624
# MOM_lag_90_days                                  0.4117      0.083      4.951      0.000       0.249       0.575
# ==============================================================================
# Omnibus:                       20.180   Durbin-Watson:                   0.136
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               43.039
# Skew:                           0.036   Prob(JB):                     4.51e-10
# Kurtosis:                       4.169   Cond. No.                         8.56
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe6e9408850>
# ###################################################################################
# TATN
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_TATN_RM_Equity - risk free rate   R-squared (uncentered):                   0.692
# Model:                                                OLS   Adj. R-squared (uncentered):              0.690
# Method:                                     Least Squares   F-statistic:                              248.7
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                        0.00
# Time:                                            19:27:36   Log-Likelihood:                          2896.4
# No. Observations:                                    1979   AIC:                                     -5767.
# Df Residuals:                                        1966   BIC:                                     -5694.
# Df Model:                                              13
# Covariance Type:                                      HC1
# ================================================================================================================
#                                                    coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_TATN                         1.1822      0.024     48.990      0.000       1.135       1.230
# Hamada_d_mcap_ratio_SMB_for_TATN                -0.1447      0.029     -4.964      0.000      -0.202      -0.088
# Hamada_d_mcap_ratio_HML_for_TATN                 0.0787      0.019      4.056      0.000       0.041       0.117
# Hamada_d_mcap_ratio_SMB_for_TATN_lag_30_days    -0.1406      0.028     -5.098      0.000      -0.195      -0.087
# Hamada_d_mcap_ratio_HML_for_TATN_lag_30_days    -0.0532      0.024     -2.219      0.026      -0.100      -0.006
# Hamada_d_mcap_ratio_SMB_for_TATN_lag_60_days     0.0048      0.027      0.178      0.859      -0.048       0.058
# Hamada_d_mcap_ratio_HML_for_TATN_lag_60_days     0.1841      0.022      8.448      0.000       0.141       0.227
# Hamada_d_mcap_ratio_SMB_for_TATN_lag_90_days    -0.0466      0.031     -1.496      0.135      -0.108       0.014
# Hamada_d_mcap_ratio_HML_for_TATN_lag_90_days     0.0511      0.019      2.625      0.009       0.013       0.089
# MOM                                             -0.0103      0.035     -0.298      0.766      -0.078       0.057
# MOM_lag_30_days                                  0.0356      0.043      0.822      0.411      -0.049       0.121
# MOM_lag_60_days                                 -0.1134      0.039     -2.925      0.003      -0.189      -0.037
# MOM_lag_90_days                                  0.0856      0.037      2.286      0.022       0.012       0.159
# ==============================================================================
# Omnibus:                       20.154   Durbin-Watson:                   0.180
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               20.657
# Skew:                           0.232   Prob(JB):                     3.27e-05
# Kurtosis:                       3.188   Cond. No.                         8.44
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe6e94085b0>
# ###################################################################################
# ROSN
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_ROSN_RM_Equity - risk free rate   R-squared (uncentered):                   0.596
# Model:                                                OLS   Adj. R-squared (uncentered):              0.593
# Method:                                     Least Squares   F-statistic:                              176.3
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                   5.45e-317
# Time:                                            19:27:36   Log-Likelihood:                          2664.8
# No. Observations:                                    1956   AIC:                                     -5304.
# Df Residuals:                                        1943   BIC:                                     -5231.
# Df Model:                                              13
# Covariance Type:                                      HC1
# ================================================================================================================
#                                                    coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_ROSN                         0.6722      0.021     31.373      0.000       0.630       0.714
# Hamada_d_mcap_ratio_SMB_for_ROSN                -0.0271      0.019     -1.436      0.151      -0.064       0.010
# Hamada_d_mcap_ratio_HML_for_ROSN                -0.0594      0.013     -4.743      0.000      -0.084      -0.035
# Hamada_d_mcap_ratio_SMB_for_ROSN_lag_30_days    -0.0492      0.020     -2.503      0.012      -0.088      -0.011
# Hamada_d_mcap_ratio_HML_for_ROSN_lag_30_days    -0.0746      0.016     -4.787      0.000      -0.105      -0.044
# Hamada_d_mcap_ratio_SMB_for_ROSN_lag_60_days     0.0145      0.019      0.779      0.436      -0.022       0.051
# Hamada_d_mcap_ratio_HML_for_ROSN_lag_60_days     0.0061      0.012      0.514      0.608      -0.017       0.029
# Hamada_d_mcap_ratio_SMB_for_ROSN_lag_90_days    -0.0223      0.018     -1.218      0.223      -0.058       0.014
# Hamada_d_mcap_ratio_HML_for_ROSN_lag_90_days     0.0293      0.012      2.418      0.016       0.006       0.053
# MOM                                              0.0547      0.034      1.626      0.104      -0.011       0.121
# MOM_lag_30_days                                 -0.1851      0.051     -3.615      0.000      -0.285      -0.085
# MOM_lag_60_days                                  0.0290      0.037      0.790      0.430      -0.043       0.101
# MOM_lag_90_days                                  0.0744      0.043      1.749      0.080      -0.009       0.158
# ==============================================================================
# Omnibus:                      118.518   Durbin-Watson:                   0.083
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              233.419
# Skew:                           0.418   Prob(JB):                     2.06e-51
# Kurtosis:                       4.471   Cond. No.                         8.19
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe719f831f0>
# ###################################################################################
# MGNT
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_MGNT_RM_Equity - risk free rate   R-squared (uncentered):                   0.358
# Model:                                                OLS   Adj. R-squared (uncentered):              0.354
# Method:                                     Least Squares   F-statistic:                              89.94
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                   2.65e-188
# Time:                                            19:27:36   Log-Likelihood:                          2089.0
# No. Observations:                                    1979   AIC:                                     -4152.
# Df Residuals:                                        1966   BIC:                                     -4079.
# Df Model:                                              13
# Covariance Type:                                      HC1
# ================================================================================================================
#                                                    coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_MGNT                         0.5479      0.027     20.173      0.000       0.495       0.601
# Hamada_d_mcap_ratio_SMB_for_MGNT                 0.1116      0.036      3.129      0.002       0.042       0.182
# Hamada_d_mcap_ratio_HML_for_MGNT                 0.3306      0.025     13.330      0.000       0.282       0.379
# Hamada_d_mcap_ratio_SMB_for_MGNT_lag_30_days     0.1091      0.035      3.075      0.002       0.040       0.179
# Hamada_d_mcap_ratio_HML_for_MGNT_lag_30_days     0.3708      0.030     12.215      0.000       0.311       0.430
# Hamada_d_mcap_ratio_SMB_for_MGNT_lag_60_days     0.3411      0.035      9.697      0.000       0.272       0.410
# Hamada_d_mcap_ratio_HML_for_MGNT_lag_60_days     0.0664      0.023      2.842      0.004       0.021       0.112
# Hamada_d_mcap_ratio_SMB_for_MGNT_lag_90_days    -0.0312      0.035     -0.886      0.376      -0.100       0.038
# Hamada_d_mcap_ratio_HML_for_MGNT_lag_90_days     0.2146      0.024      9.077      0.000       0.168       0.261
# MOM                                             -0.1890      0.049     -3.835      0.000      -0.286      -0.092
# MOM_lag_30_days                                 -0.4636      0.058     -8.057      0.000      -0.576      -0.351
# MOM_lag_60_days                                  0.4721      0.057      8.318      0.000       0.361       0.583
# MOM_lag_90_days                                 -0.0077      0.050     -0.152      0.879      -0.107       0.091
# ==============================================================================
# Omnibus:                      210.713   Durbin-Watson:                   0.140
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              421.017
# Skew:                          -0.674   Prob(JB):                     3.78e-92
# Kurtosis:                       4.813   Cond. No.                         8.14
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe6e9423940>
# ###################################################################################
# MTSS
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_MTSS_RM_Equity - risk free rate   R-squared (uncentered):                   0.489
# Model:                                                OLS   Adj. R-squared (uncentered):              0.485
# Method:                                     Least Squares   F-statistic:                              93.89
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                   3.44e-195
# Time:                                            19:27:36   Log-Likelihood:                          2646.8
# No. Observations:                                    1979   AIC:                                     -5268.
# Df Residuals:                                        1966   BIC:                                     -5195.
# Df Model:                                              13
# Covariance Type:                                      HC1
# ================================================================================================================
#                                                    coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_MTSS                         0.5576      0.020     27.201      0.000       0.517       0.598
# Hamada_d_mcap_ratio_SMB_for_MTSS                -0.0133      0.025     -0.537      0.591      -0.062       0.035
# Hamada_d_mcap_ratio_HML_for_MTSS                -0.0665      0.020     -3.381      0.001      -0.105      -0.028
# Hamada_d_mcap_ratio_SMB_for_MTSS_lag_30_days     0.0522      0.025      2.113      0.035       0.004       0.101
# Hamada_d_mcap_ratio_HML_for_MTSS_lag_30_days    -0.1023      0.024     -4.327      0.000      -0.149      -0.056
# Hamada_d_mcap_ratio_SMB_for_MTSS_lag_60_days     0.0606      0.020      3.016      0.003       0.021       0.100
# Hamada_d_mcap_ratio_HML_for_MTSS_lag_60_days    -0.1236      0.018     -6.952      0.000      -0.158      -0.089
# Hamada_d_mcap_ratio_SMB_for_MTSS_lag_90_days    -0.1462      0.022     -6.562      0.000      -0.190      -0.103
# Hamada_d_mcap_ratio_HML_for_MTSS_lag_90_days     0.0704      0.016      4.423      0.000       0.039       0.102
# MOM                                             -0.0811      0.036     -2.241      0.025      -0.152      -0.010
# MOM_lag_30_days                                 -0.1519      0.053     -2.843      0.004      -0.257      -0.047
# MOM_lag_60_days                                  0.3751      0.045      8.344      0.000       0.287       0.463
# MOM_lag_90_days                                 -0.1443      0.043     -3.377      0.001      -0.228      -0.061
# ==============================================================================
# Omnibus:                      135.323   Durbin-Watson:                   0.115
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              248.885
# Skew:                          -0.487   Prob(JB):                     9.02e-55
# Kurtosis:                       4.439   Cond. No.                         8.17
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe6e94234f0>
# ###################################################################################
# MOEX
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_MOEX_RM_Equity - risk free rate   R-squared (uncentered):                   0.214
# Model:                                                OLS   Adj. R-squared (uncentered):              0.207
# Method:                                     Least Squares   F-statistic:                              36.28
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                    8.95e-80
# Time:                                            19:27:36   Log-Likelihood:                          1763.6
# No. Observations:                                    1507   AIC:                                     -3501.
# Df Residuals:                                        1494   BIC:                                     -3432.
# Df Model:                                              13
# Covariance Type:                                      HC1
# ================================================================================================================
#                                                    coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_MOEX                         0.1039      0.010     10.498      0.000       0.084       0.123
# Hamada_d_mcap_ratio_SMB_for_MOEX                -0.0076      0.009     -0.825      0.409      -0.026       0.010
# Hamada_d_mcap_ratio_HML_for_MOEX                -0.0261      0.011     -2.364      0.018      -0.048      -0.004
# Hamada_d_mcap_ratio_SMB_for_MOEX_lag_30_days     0.0440      0.009      5.020      0.000       0.027       0.061
# Hamada_d_mcap_ratio_HML_for_MOEX_lag_30_days    -0.0294      0.010     -2.870      0.004      -0.050      -0.009
# Hamada_d_mcap_ratio_SMB_for_MOEX_lag_60_days     0.0795      0.009      9.148      0.000       0.062       0.097
# Hamada_d_mcap_ratio_HML_for_MOEX_lag_60_days    -0.0327      0.010     -3.286      0.001      -0.052      -0.013
# Hamada_d_mcap_ratio_SMB_for_MOEX_lag_90_days     0.0150      0.010      1.552      0.121      -0.004       0.034
# Hamada_d_mcap_ratio_HML_for_MOEX_lag_90_days     0.0055      0.009      0.623      0.533      -0.012       0.023
# MOM                                             -0.0468      0.044     -1.060      0.289      -0.133       0.040
# MOM_lag_30_days                                 -0.2087      0.061     -3.408      0.001      -0.329      -0.089
# MOM_lag_60_days                                  0.5455      0.062      8.770      0.000       0.424       0.667
# MOM_lag_90_days                                 -0.2030      0.054     -3.734      0.000      -0.310      -0.096
# ==============================================================================
# Omnibus:                        5.629   Durbin-Watson:                   0.129
# Prob(Omnibus):                  0.060   Jarque-Bera (JB):                5.819
# Skew:                          -0.107   Prob(JB):                       0.0545
# Kurtosis:                       3.217   Cond. No.                         9.52
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe719f83490>
# ###################################################################################
# IRAO
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_IRAO_RM_Equity - risk free rate   R-squared (uncentered):                   0.546
# Model:                                                OLS   Adj. R-squared (uncentered):              0.541
# Method:                                     Least Squares   F-statistic:                              106.4
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                   4.50e-184
# Time:                                            19:27:36   Log-Likelihood:                          1363.9
# No. Observations:                                    1114   AIC:                                     -2702.
# Df Residuals:                                        1101   BIC:                                     -2637.
# Df Model:                                              13
# Covariance Type:                                      HC1
# ================================================================================================================
#                                                    coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_IRAO                         0.6994      0.043     16.109      0.000       0.614       0.785
# Hamada_d_mcap_ratio_SMB_for_IRAO                 0.1714      0.054      3.193      0.001       0.066       0.277
# Hamada_d_mcap_ratio_HML_for_IRAO                 0.1473      0.043      3.421      0.001       0.063       0.232
# Hamada_d_mcap_ratio_SMB_for_IRAO_lag_30_days     0.6441      0.053     12.261      0.000       0.541       0.747
# Hamada_d_mcap_ratio_HML_for_IRAO_lag_30_days    -0.4925      0.041    -11.950      0.000      -0.573      -0.412
# Hamada_d_mcap_ratio_SMB_for_IRAO_lag_60_days     0.3255      0.044      7.318      0.000       0.238       0.413
# Hamada_d_mcap_ratio_HML_for_IRAO_lag_60_days    -0.0062      0.029     -0.212      0.832      -0.064       0.051
# Hamada_d_mcap_ratio_SMB_for_IRAO_lag_90_days     0.0504      0.045      1.110      0.267      -0.039       0.139
# Hamada_d_mcap_ratio_HML_for_IRAO_lag_90_days    -0.3717      0.038     -9.836      0.000      -0.446      -0.298
# MOM                                              0.1751      0.056      3.104      0.002       0.065       0.286
# MOM_lag_30_days                                  0.0572      0.051      1.112      0.266      -0.044       0.158
# MOM_lag_60_days                                  0.0255      0.051      0.501      0.616      -0.074       0.125
# MOM_lag_90_days                                 -0.0554      0.066     -0.842      0.400      -0.184       0.074
# ==============================================================================
# Omnibus:                        5.611   Durbin-Watson:                   0.215
# Prob(Omnibus):                  0.060   Jarque-Bera (JB):                5.632
# Skew:                           0.139   Prob(JB):                       0.0598
# ...
# MOM                                              0.0876      0.049      1.782      0.075      -0.009       0.184
# MOM_lag_30_days                                 -0.2688      0.056     -4.821      0.000      -0.378      -0.160
# MOM_lag_60_days                                 -0.0126      0.043     -0.294      0.769      -0.097       0.071
# MOM_lag_90_days                                  0.2421      0.058      4.183      0.000       0.129       0.356
# ==============================================================================
# Omnibus:                       74.911   Durbin-Watson:                   0.124
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              102.111
# Skew:                           0.869   Prob(JB):                     6.71e-23
# Kurtosis:                       3.906   Cond. No.                         8.25
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe719339940>
# ###################################################################################
# KMAZ
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_KMAZ_RM_Equity - risk free rate   R-squared (uncentered):                   0.284
# Model:                                                OLS   Adj. R-squared (uncentered):              0.279
# Method:                                     Least Squares   F-statistic:                              58.48
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                   2.53e-129
# Time:                                            19:27:37   Log-Likelihood:                          1784.6
# No. Observations:                                    1979   AIC:                                     -3543.
# Df Residuals:                                        1966   BIC:                                     -3471.
# Df Model:                                              13
# Covariance Type:                                      HC1
# ================================================================================================================
#                                                    coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_KMAZ                         0.4049      0.022     18.260      0.000       0.361       0.448
# Hamada_d_mcap_ratio_SMB_for_KMAZ                -0.0266      0.032     -0.833      0.405      -0.089       0.036
# Hamada_d_mcap_ratio_HML_for_KMAZ                -0.0592      0.021     -2.774      0.006      -0.101      -0.017
# Hamada_d_mcap_ratio_SMB_for_KMAZ_lag_30_days     0.2249      0.029      7.865      0.000       0.169       0.281
# Hamada_d_mcap_ratio_HML_for_KMAZ_lag_30_days    -0.1293      0.021     -6.287      0.000      -0.170      -0.089
# Hamada_d_mcap_ratio_SMB_for_KMAZ_lag_60_days     0.1029      0.023      4.501      0.000       0.058       0.148
# Hamada_d_mcap_ratio_HML_for_KMAZ_lag_60_days     0.0057      0.021      0.275      0.783      -0.035       0.047
# Hamada_d_mcap_ratio_SMB_for_KMAZ_lag_90_days    -0.1018      0.025     -4.128      0.000      -0.150      -0.053
# Hamada_d_mcap_ratio_HML_for_KMAZ_lag_90_days     0.0638      0.025      2.534      0.011       0.014       0.113
# MOM                                              0.0595      0.065      0.920      0.358      -0.067       0.186
# MOM_lag_30_days                                 -0.0928      0.052     -1.787      0.074      -0.194       0.009
# MOM_lag_60_days                                 -0.1424      0.055     -2.565      0.010      -0.251      -0.034
# MOM_lag_90_days                                  0.1619      0.063      2.572      0.010       0.039       0.285
# ==============================================================================
# Omnibus:                      401.089   Durbin-Watson:                   0.124
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              930.376
# Skew:                           1.123   Prob(JB):                    9.36e-203
# Kurtosis:                       5.497   Cond. No.                         8.09
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe6c82ea1f0>
# ###################################################################################
# RASP
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_RASP_RM_Equity - risk free rate   R-squared (uncentered):                   0.441
# Model:                                                OLS   Adj. R-squared (uncentered):              0.437
# Method:                                     Least Squares   F-statistic:                              86.31
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                   6.82e-182
# Time:                                            19:27:37   Log-Likelihood:                          1343.6
# No. Observations:                                    1979   AIC:                                     -2661.
# Df Residuals:                                        1966   BIC:                                     -2589.
# Df Model:                                              13
# Covariance Type:                                      HC1
# ================================================================================================================
#                                                    coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_RASP                         1.1369      0.044     26.066      0.000       1.051       1.222
# Hamada_d_mcap_ratio_SMB_for_RASP                -0.0633      0.049     -1.280      0.200      -0.160       0.034
# Hamada_d_mcap_ratio_HML_for_RASP                 0.0107      0.031      0.341      0.733      -0.051       0.072
# Hamada_d_mcap_ratio_SMB_for_RASP_lag_30_days     0.8803      0.057     15.496      0.000       0.769       0.992
# Hamada_d_mcap_ratio_HML_for_RASP_lag_30_days     0.2560      0.038      6.824      0.000       0.182       0.330
# Hamada_d_mcap_ratio_SMB_for_RASP_lag_60_days    -0.1231      0.045     -2.744      0.006      -0.211      -0.035
# Hamada_d_mcap_ratio_HML_for_RASP_lag_60_days     0.0535      0.037      1.465      0.143      -0.018       0.125
# Hamada_d_mcap_ratio_SMB_for_RASP_lag_90_days     0.1807      0.049      3.702      0.000       0.085       0.276
# Hamada_d_mcap_ratio_HML_for_RASP_lag_90_days    -0.0209      0.046     -0.453      0.651      -0.111       0.070
# MOM                                             -0.3261      0.063     -5.214      0.000      -0.449      -0.204
# MOM_lag_30_days                                 -0.0216      0.083     -0.260      0.795      -0.184       0.141
# MOM_lag_60_days                                  0.1338      0.074      1.796      0.073      -0.012       0.280
# MOM_lag_90_days                                  0.0639      0.078      0.818      0.414      -0.089       0.217
# ==============================================================================
# Omnibus:                       25.149   Durbin-Watson:                   0.130
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               26.779
# Skew:                           0.244   Prob(JB):                     1.53e-06
# Kurtosis:                       3.295   Cond. No.                         8.16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe6f842ac70>
# ###################################################################################
# OGKB
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_OGKB_RM_Equity - risk free rate   R-squared (uncentered):                   0.521
# Model:                                                OLS   Adj. R-squared (uncentered):              0.518
# Method:                                     Least Squares   F-statistic:                              118.8
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                   1.80e-235
# Time:                                            19:27:37   Log-Likelihood:                          1764.4
# No. Observations:                                    1956   AIC:                                     -3503.
# Df Residuals:                                        1943   BIC:                                     -3430.
# Df Model:                                              13
# Covariance Type:                                      HC1
# ================================================================================================================
#                                                    coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_OGKB                         0.5814      0.028     20.733      0.000       0.526       0.636
# Hamada_d_mcap_ratio_SMB_for_OGKB                -0.2444      0.030     -8.244      0.000      -0.302      -0.186
# Hamada_d_mcap_ratio_HML_for_OGKB                -0.0354      0.016     -2.212      0.027      -0.067      -0.004
# Hamada_d_mcap_ratio_SMB_for_OGKB_lag_30_days     0.5213      0.032     16.549      0.000       0.460       0.583
# Hamada_d_mcap_ratio_HML_for_OGKB_lag_30_days    -0.3053      0.023    -13.240      0.000      -0.350      -0.260
# Hamada_d_mcap_ratio_SMB_for_OGKB_lag_60_days     0.1336      0.026      5.153      0.000       0.083       0.184
# Hamada_d_mcap_ratio_HML_for_OGKB_lag_60_days    -0.0967      0.023     -4.125      0.000      -0.143      -0.051
# Hamada_d_mcap_ratio_SMB_for_OGKB_lag_90_days     0.1563      0.026      5.921      0.000       0.105       0.208
# Hamada_d_mcap_ratio_HML_for_OGKB_lag_90_days     0.1700      0.021      8.136      0.000       0.129       0.211
# MOM                                             -0.0599      0.055     -1.082      0.279      -0.168       0.049
# MOM_lag_30_days                                  0.1083      0.063      1.712      0.087      -0.016       0.232
# MOM_lag_60_days                                 -0.0919      0.059     -1.549      0.121      -0.208       0.024
# MOM_lag_90_days                                 -0.0110      0.067     -0.164      0.870      -0.142       0.120
# ==============================================================================
# Omnibus:                       58.166   Durbin-Watson:                   0.159
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               84.474
# Skew:                           0.299   Prob(JB):                     4.54e-19
# Kurtosis:                       3.824   Cond. No.                         8.31
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe6f842af70>
# ###################################################################################
# VZRZ
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_VZRZ_RM_Equity - risk free rate   R-squared (uncentered):                   0.163
# Model:                                                OLS   Adj. R-squared (uncentered):              0.158
# Method:                                     Least Squares   F-statistic:                              27.96
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                    1.48e-63
# Time:                                            19:27:37   Log-Likelihood:                          1801.6
# No. Observations:                                    1979   AIC:                                     -3577.
# Df Residuals:                                        1966   BIC:                                     -3504.
# Df Model:                                              13
# Covariance Type:                                      HC1
# ================================================================================================================
#                                                    coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_VZRZ                         0.0996      0.018      5.498      0.000       0.064       0.135
# Hamada_d_mcap_ratio_SMB_for_VZRZ                 0.1207      0.024      4.979      0.000       0.073       0.168
# Hamada_d_mcap_ratio_HML_for_VZRZ                 0.0403      0.017      2.357      0.018       0.007       0.074
# Hamada_d_mcap_ratio_SMB_for_VZRZ_lag_30_days     0.2961      0.024     12.465      0.000       0.250       0.343
# Hamada_d_mcap_ratio_HML_for_VZRZ_lag_30_days     0.0406      0.017      2.460      0.014       0.008       0.073
# Hamada_d_mcap_ratio_SMB_for_VZRZ_lag_60_days    -0.0526      0.022     -2.380      0.017      -0.096      -0.009
# Hamada_d_mcap_ratio_HML_for_VZRZ_lag_60_days     0.0034      0.018      0.183      0.855      -0.033       0.039
# Hamada_d_mcap_ratio_SMB_for_VZRZ_lag_90_days     0.0208      0.023      0.905      0.365      -0.024       0.066
# Hamada_d_mcap_ratio_HML_for_VZRZ_lag_90_days    -0.1182      0.017     -6.774      0.000      -0.152      -0.084
# MOM                                             -0.3329      0.054     -6.117      0.000      -0.440      -0.226
# MOM_lag_30_days                                 -0.0654      0.076     -0.856      0.392      -0.215       0.084
# MOM_lag_60_days                                  0.0451      0.062      0.726      0.468      -0.077       0.167
# MOM_lag_90_days                                  0.2854      0.058      4.886      0.000       0.171       0.400
# ==============================================================================
# Omnibus:                       18.249   Durbin-Watson:                   0.116
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               24.560
# Skew:                          -0.113   Prob(JB):                     4.64e-06
# Kurtosis:                       3.497   Cond. No.                         8.73
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe6f842aee0>

# %% [markdown]
# ## Carhart model with lags and autolags

# %%
lag_autolag_return_30 = 30
lag_autolag_return_60 = 60
lag_autolag_return_90 = 90
lag_30 = 30
lag_60 = 60
lag_90 = 90

r_2_results_carh_l_al = []
mse_results_carh_l_al = []

for name in data_ret.columns[2:]:
    
    df1 = data[[name, 'Hamada_beta_MRP_for_{}'.format(name[7:11]), 'risk_free_rate_based_on_g_curve',
                 'Hamada_d_mcap_ratio_SMB_for_{}'.format(name[7:11]),
                 'Hamada_d_mcap_ratio_HML_for_{}'.format(name[7:11]),
                 'MOM']].dropna()
    df_autolag = pd.DataFrame(data[name] - data['risk_free_rate_based_on_g_curve']).rename(columns = {0:'{}_premium_lag_{}_days'.format(name[7:], lag_autolag_return_30)})
    df_autolag = pd.DataFrame(df_autolag['{}_premium_lag_{}_days'.format(name[7:], lag_autolag_return_30)].shift(lag_autolag_return_30).dropna())
    
    df_autolag_2 = pd.DataFrame(data[name] - data['risk_free_rate_based_on_g_curve']).rename(columns = {0:'{}_premium_lag_{}_days'.format(name[7:], lag_autolag_return_60)})
    df_autolag_2 = pd.DataFrame(df_autolag_2['{}_premium_lag_{}_days'.format(name[7:], lag_autolag_return_60)].shift(lag_autolag_return_60).dropna())
    
    df_autolag_3 = pd.DataFrame(data[name] - data['risk_free_rate_based_on_g_curve']).rename(columns = {0:'{}_premium_lag_{}_days'.format(name[7:], lag_autolag_return_90)})
    df_autolag_3 = pd.DataFrame(df_autolag_3['{}_premium_lag_{}_days'.format(name[7:], lag_autolag_return_90)].shift(lag_autolag_return_90).dropna())
    
    df2 = data[['Hamada_d_mcap_ratio_SMB_for_{}'.format(name[7:11]),
            'Hamada_d_mcap_ratio_HML_for_{}'.format(name[7:11]), 'MOM']].shift(lag_30).dropna()
    
    
    
    df2.rename(columns = {'Hamada_d_mcap_ratio_SMB_for_{}'.format(name[7:11]):'Hamada_d_mcap_ratio_SMB_for_{}_lag_{}_days'.format(name[7:11], lag_30),
                          'Hamada_d_mcap_ratio_HML_for_{}'.format(name[7:11]):'Hamada_d_mcap_ratio_HML_for_{}_lag_{}_days'.format(name[7:11], lag_30), 
                          'MOM':'MOM_lag_{}_days'.format(lag_30)}, inplace = True)
    
    result = pd.concat([df1, df2], axis=1, join="inner")
    
    df3 = data[['Hamada_d_mcap_ratio_SMB_for_{}'.format(name[7:11]),
            'Hamada_d_mcap_ratio_HML_for_{}'.format(name[7:11]), 'MOM']].shift(lag_60).dropna()
    
    df3.rename(columns = {'Hamada_d_mcap_ratio_SMB_for_{}'.format(name[7:11]):'Hamada_d_mcap_ratio_SMB_for_{}_lag_{}_days'.format(name[7:11], lag_60),
                          'Hamada_d_mcap_ratio_HML_for_{}'.format(name[7:11]):'Hamada_d_mcap_ratio_HML_for_{}_lag_{}_days'.format(name[7:11], lag_60), 
                          'MOM':'MOM_lag_{}_days'.format(lag_60)}, inplace = True)
    
    result = pd.concat([result, df3], axis=1, join="inner")
    
    df4 = data[['Hamada_d_mcap_ratio_SMB_for_{}'.format(name[7:11]),
            'Hamada_d_mcap_ratio_HML_for_{}'.format(name[7:11]), 'MOM']].shift(lag_90).dropna()
    
    df4.rename(columns = {'Hamada_d_mcap_ratio_SMB_for_{}'.format(name[7:11]):'Hamada_d_mcap_ratio_SMB_for_{}_lag_{}_days'.format(name[7:11], lag_90),
                          'Hamada_d_mcap_ratio_HML_for_{}'.format(name[7:11]):'Hamada_d_mcap_ratio_HML_for_{}_lag_{}_days'.format(name[7:11], lag_90), 
                          'MOM':'MOM_lag_{}_days'.format(lag_90)}, inplace = True)
    
    result = pd.concat([result, df4], axis=1, join="inner")
    
    result = pd.merge(result, macro_data, left_index=True, right_index=True)
    result = pd.merge(result, df_autolag, left_index=True, right_index=True)
    result = pd.merge(result, df_autolag_2, left_index=True, right_index=True)
    result = pd.merge(result, df_autolag_3, left_index=True, right_index=True)
    
    Base = result.dropna()
    
    Y = pd.DataFrame(Base[name] - Base['risk_free_rate_based_on_g_curve'])
    Y.rename(columns = {0:'{} - risk free rate'.format(name)}, inplace = True)
    X = Base[['Hamada_beta_MRP_for_{}'.format(name[7:11]), 
              '{}_premium_lag_{}_days'.format(name[7:], lag_autolag_return_30),
              '{}_premium_lag_{}_days'.format(name[7:], lag_autolag_return_60),
              '{}_premium_lag_{}_days'.format(name[7:], lag_autolag_return_90),
              'Hamada_d_mcap_ratio_SMB_for_{}'.format(name[7:11]),
              'Hamada_d_mcap_ratio_HML_for_{}'.format(name[7:11]), 
              'Hamada_d_mcap_ratio_SMB_for_{}_lag_{}_days'.format(name[7:11], lag_30),
              'Hamada_d_mcap_ratio_HML_for_{}_lag_{}_days'.format(name[7:11], lag_30),
              'Hamada_d_mcap_ratio_SMB_for_{}_lag_{}_days'.format(name[7:11], lag_60),
              'Hamada_d_mcap_ratio_HML_for_{}_lag_{}_days'.format(name[7:11], lag_60),
              'Hamada_d_mcap_ratio_SMB_for_{}_lag_{}_days'.format(name[7:11], lag_90),
              'Hamada_d_mcap_ratio_HML_for_{}_lag_{}_days'.format(name[7:11], lag_90),
              'MOM','MOM_lag_{}_days'.format(lag_30),'MOM_lag_{}_days'.format(lag_60),
              'MOM_lag_{}_days'.format(lag_90)]]
    model = sm.OLS(Y,X)
    results = model.fit(cov_type = 'HC1')
    print('###################################################################################')
    print(name[7:11])
    print(results.summary())
    hypotheses = '({} = 0), ({} = 0), (MOM = 0)'.format('Hamada_d_mcap_ratio_SMB_for_{}'.format(name[7:11]), 'Hamada_d_mcap_ratio_HML_for_{}'.format(name[7:11]))
    f_test = results.f_test(hypotheses)
    print(f_test)
    print(results)
    r_2_results_carh_l_al.append(results.rsquared_adj)
    mse_results_carh_l_al.append(results.mse_resid)
# Out:
# ###################################################################################
# SBER
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_SBER_RM_Equity - risk free rate   R-squared (uncentered):                   0.555
# Model:                                                OLS   Adj. R-squared (uncentered):              0.551
# Method:                                     Least Squares   F-statistic:                              93.66
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                   8.39e-228
# Time:                                            19:27:37   Log-Likelihood:                          2535.4
# No. Observations:                                    1979   AIC:                                     -5039.
# Df Residuals:                                        1963   BIC:                                     -4949.
# Df Model:                                              16
# Covariance Type:                                      HC1
# ================================================================================================================
#                                                    coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_SBER                         0.4347      0.022     19.524      0.000       0.391       0.478
# SBER_RM_Equity_premium_lag_30_days               0.0527      0.018      2.918      0.004       0.017       0.088
# SBER_RM_Equity_premium_lag_60_days               0.0796      0.019      4.226      0.000       0.043       0.117
# SBER_RM_Equity_premium_lag_90_days               0.0854      0.017      4.930      0.000       0.051       0.119
# Hamada_d_mcap_ratio_SMB_for_SBER                 0.0452      0.022      2.062      0.039       0.002       0.088
# Hamada_d_mcap_ratio_HML_for_SBER                 0.0080      0.011      0.728      0.467      -0.014       0.030
# Hamada_d_mcap_ratio_SMB_for_SBER_lag_30_days     0.0519      0.019      2.759      0.006       0.015       0.089
# Hamada_d_mcap_ratio_HML_for_SBER_lag_30_days    -0.1281      0.012    -10.846      0.000      -0.151      -0.105
# Hamada_d_mcap_ratio_SMB_for_SBER_lag_60_days     0.0639      0.016      3.878      0.000       0.032       0.096
# Hamada_d_mcap_ratio_HML_for_SBER_lag_60_days    -0.0089      0.019     -0.481      0.630      -0.045       0.027
# Hamada_d_mcap_ratio_SMB_for_SBER_lag_90_days     0.0067      0.017      0.404      0.686      -0.026       0.039
# Hamada_d_mcap_ratio_HML_for_SBER_lag_90_days     0.0219      0.012      1.864      0.062      -0.001       0.045
# MOM                                              0.0649      0.043      1.503      0.133      -0.020       0.149
# MOM_lag_30_days                                 -0.4734      0.054     -8.748      0.000      -0.580      -0.367
# MOM_lag_60_days                                 -0.0231      0.038     -0.609      0.543      -0.097       0.051
# MOM_lag_90_days                                  0.4341      0.045      9.548      0.000       0.345       0.523
# ==============================================================================
# Omnibus:                       87.698   Durbin-Watson:                   0.143
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              156.455
# Skew:                          -0.343   Prob(JB):                     1.06e-34
# Kurtosis:                       4.195   Cond. No.                         8.78
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <F test: F=array([[2.55209034]]), p=0.05398797352617483, df_denom=1.96e+03, df_num=3>
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe719ecf640>
# ###################################################################################
# GAZP
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_GAZP_RM_Equity - risk free rate   R-squared (uncentered):                   0.728
# Model:                                                OLS   Adj. R-squared (uncentered):              0.726
# Method:                                     Least Squares   F-statistic:                              202.8
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                        0.00
# Time:                                            19:27:37   Log-Likelihood:                          3237.7
# No. Observations:                                    1979   AIC:                                     -6443.
# Df Residuals:                                        1963   BIC:                                     -6354.
# Df Model:                                              16
# Covariance Type:                                      HC1
# ================================================================================================================
#                                                    coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_GAZP                         0.6878      0.016     44.094      0.000       0.657       0.718
# GAZP_RM_Equity_premium_lag_30_days               0.0095      0.014      0.680      0.497      -0.018       0.037
# GAZP_RM_Equity_premium_lag_60_days              -0.0700      0.015     -4.703      0.000      -0.099      -0.041
# GAZP_RM_Equity_premium_lag_90_days              -0.0165      0.011     -1.503      0.133      -0.038       0.005
# Hamada_d_mcap_ratio_SMB_for_GAZP                -0.0781      0.020     -3.880      0.000      -0.118      -0.039
# Hamada_d_mcap_ratio_HML_for_GAZP                 0.0153      0.012      1.232      0.218      -0.009       0.040
# Hamada_d_mcap_ratio_SMB_for_GAZP_lag_30_days    -0.1906      0.019     -9.852      0.000      -0.228      -0.153
# Hamada_d_mcap_ratio_HML_for_GAZP_lag_30_days    -0.2109      0.017    -12.690      0.000      -0.244      -0.178
# Hamada_d_mcap_ratio_SMB_for_GAZP_lag_60_days     0.0084      0.017      0.496      0.620      -0.025       0.042
# Hamada_d_mcap_ratio_HML_for_GAZP_lag_60_days    -0.0713      0.013     -5.562      0.000      -0.096      -0.046
# Hamada_d_mcap_ratio_SMB_for_GAZP_lag_90_days    -0.0434      0.017     -2.606      0.009      -0.076      -0.011
# Hamada_d_mcap_ratio_HML_for_GAZP_lag_90_days     0.0408      0.012      3.395      0.001       0.017       0.064
# MOM                                             -0.1461      0.029     -5.047      0.000      -0.203      -0.089
# MOM_lag_30_days                                  0.2435      0.038      6.398      0.000       0.169       0.318
# MOM_lag_60_days                                 -0.0478      0.034     -1.423      0.155      -0.114       0.018
# MOM_lag_90_days                                 -0.1059      0.029     -3.633      0.000      -0.163      -0.049
# ==============================================================================
# Omnibus:                      189.568   Durbin-Watson:                   0.130
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              404.588
# Skew:                           0.596   Prob(JB):                     1.40e-88
# Kurtosis:                       4.867   Cond. No.                         8.25
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <F test: F=array([[9.44704279]]), p=3.3851494681204903e-06, df_denom=1.96e+03, df_num=3>
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe6e94083d0>
# ###################################################################################
# LKOH
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_LKOH_RM_Equity - risk free rate   R-squared (uncentered):                   0.717
# Model:                                                OLS   Adj. R-squared (uncentered):              0.714
# Method:                                     Least Squares   F-statistic:                              221.8
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                        0.00
# Time:                                            19:27:37   Log-Likelihood:                          3462.8
# No. Observations:                                    1979   AIC:                                     -6894.
# Df Residuals:                                        1963   BIC:                                     -6804.
# Df Model:                                              16
# Covariance Type:                                      HC1
# ================================================================================================================
#                                                    coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_LKOH                         0.9011      0.020     45.288      0.000       0.862       0.940
# LKOH_RM_Equity_premium_lag_30_days               0.0288      0.014      2.085      0.037       0.002       0.056
# LKOH_RM_Equity_premium_lag_60_days               0.0054      0.014      0.387      0.699      -0.022       0.033
# LKOH_RM_Equity_premium_lag_90_days              -0.0270      0.014     -1.875      0.061      -0.055       0.001
# Hamada_d_mcap_ratio_SMB_for_LKOH                 0.0441      0.021      2.101      0.036       0.003       0.085
# Hamada_d_mcap_ratio_HML_for_LKOH                 0.0272      0.016      1.707      0.088      -0.004       0.058
# Hamada_d_mcap_ratio_SMB_for_LKOH_lag_30_days    -0.2013      0.020    -10.188      0.000      -0.240      -0.163
# Hamada_d_mcap_ratio_HML_for_LKOH_lag_30_days     0.0755      0.019      3.964      0.000       0.038       0.113
# Hamada_d_mcap_ratio_SMB_for_LKOH_lag_60_days    -0.0702      0.024     -2.962      0.003      -0.117      -0.024
# Hamada_d_mcap_ratio_HML_for_LKOH_lag_60_days     0.0774      0.016      4.982      0.000       0.047       0.108
# Hamada_d_mcap_ratio_SMB_for_LKOH_lag_90_days     0.0192      0.019      1.024      0.306      -0.018       0.056
# Hamada_d_mcap_ratio_HML_for_LKOH_lag_90_days    -0.0223      0.013     -1.751      0.080      -0.047       0.003
# MOM                                              0.0238      0.026      0.898      0.369      -0.028       0.076
# MOM_lag_30_days                                  0.0252      0.037      0.691      0.490      -0.046       0.097
# MOM_lag_60_days                                 -0.1022      0.030     -3.421      0.001      -0.161      -0.044
# MOM_lag_90_days                                  0.0656      0.028      2.364      0.018       0.011       0.120
# ==============================================================================
# Omnibus:                      148.825   Durbin-Watson:                   0.158
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              255.307
# Skew:                          -0.549   Prob(JB):                     3.64e-56
# Kurtosis:                       4.375   Cond. No.                         8.62
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <F test: F=array([[2.97205861]]), p=0.03067471541646412, df_denom=1.96e+03, df_num=3>
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe6e9408a90>
# ###################################################################################
# GMKN
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_GMKN_RM_Equity - risk free rate   R-squared (uncentered):                   0.541
# Model:                                                OLS   Adj. R-squared (uncentered):              0.538
# Method:                                     Least Squares   F-statistic:                              125.5
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                   7.56e-286
# Time:                                            19:27:37   Log-Likelihood:                          2880.0
# No. Observations:                                    1979   AIC:                                     -5728.
# Df Residuals:                                        1963   BIC:                                     -5639.
# Df Model:                                              16
# Covariance Type:                                      HC1
# ================================================================================================================
#                                                    coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_GMKN                         0.8542      0.023     36.643      0.000       0.808       0.900
# GMKN_RM_Equity_premium_lag_30_days              -0.0520      0.018     -2.958      0.003      -0.086      -0.018
# GMKN_RM_Equity_premium_lag_60_days               0.1402      0.016      8.542      0.000       0.108       0.172
# GMKN_RM_Equity_premium_lag_90_days               0.0007      0.015      0.045      0.964      -0.029       0.030
# Hamada_d_mcap_ratio_SMB_for_GMKN                 0.0831      0.030      2.798      0.005       0.025       0.141
# Hamada_d_mcap_ratio_HML_for_GMKN                -0.0706      0.017     -4.186      0.000      -0.104      -0.038
# Hamada_d_mcap_ratio_SMB_for_GMKN_lag_30_days     0.0154      0.029      0.535      0.593      -0.041       0.072
# Hamada_d_mcap_ratio_HML_for_GMKN_lag_30_days     0.3158      0.021     14.805      0.000       0.274       0.358
# Hamada_d_mcap_ratio_SMB_for_GMKN_lag_60_days    -0.1606      0.027     -5.952      0.000      -0.213      -0.108
# Hamada_d_mcap_ratio_HML_for_GMKN_lag_60_days    -0.0511      0.024     -2.152      0.031      -0.098      -0.005
# Hamada_d_mcap_ratio_SMB_for_GMKN_lag_90_days    -0.0337      0.026     -1.303      0.193      -0.085       0.017
# Hamada_d_mcap_ratio_HML_for_GMKN_lag_90_days    -0.1316      0.020     -6.692      0.000      -0.170      -0.093
# MOM                                              0.1200      0.035      3.384      0.001       0.051       0.190
# MOM_lag_30_days                                  0.0473      0.038      1.256      0.209      -0.026       0.121
# MOM_lag_60_days                                 -0.0428      0.035     -1.240      0.215      -0.110       0.025
# MOM_lag_90_days                                 -0.0880      0.039     -2.229      0.026      -0.165      -0.011
# ==============================================================================
# Omnibus:                        4.788   Durbin-Watson:                   0.188
# Prob(Omnibus):                  0.091   Jarque-Bera (JB):                4.821
# Skew:                           0.108   Prob(JB):                       0.0898
# Kurtosis:                       2.892   Cond. No.                         8.61
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <F test: F=array([[8.89828339]]), p=7.415833258883737e-06, df_denom=1.96e+03, df_num=3>
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe6e9408370>
# ###################################################################################
# NVTK
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_NVTK_RM_Equity - risk free rate   R-squared (uncentered):                   0.536
# Model:                                                OLS   Adj. R-squared (uncentered):              0.532
# Method:                                     Least Squares   F-statistic:                              120.6
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                   2.01e-277
# Time:                                            19:27:37   Log-Likelihood:                          2878.2
# No. Observations:                                    1979   AIC:                                     -5724.
# Df Residuals:                                        1963   BIC:                                     -5635.
# Df Model:                                              16
# Covariance Type:                                      HC1
# ================================================================================================================
#                                                    coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_NVTK                         0.8499      0.028     30.873      0.000       0.796       0.904
# NVTK_RM_Equity_premium_lag_30_days              -0.0049      0.017     -0.281      0.778      -0.039       0.029
# NVTK_RM_Equity_premium_lag_60_days              -0.0343      0.018     -1.926      0.054      -0.069       0.001
# NVTK_RM_Equity_premium_lag_90_days               0.0373      0.016      2.401      0.016       0.007       0.068
# Hamada_d_mcap_ratio_SMB_for_NVTK                -0.2214      0.031     -7.235      0.000      -0.281      -0.161
# Hamada_d_mcap_ratio_HML_for_NVTK                -0.1385      0.024     -5.704      0.000      -0.186      -0.091
# Hamada_d_mcap_ratio_SMB_for_NVTK_lag_30_days    -0.3665      0.033    -11.166      0.000      -0.431      -0.302
# Hamada_d_mcap_ratio_HML_for_NVTK_lag_30_days     0.2066      0.021      9.964      0.000       0.166       0.247
# Hamada_d_mcap_ratio_SMB_for_NVTK_lag_60_days     0.1088      0.029      3.768      0.000       0.052       0.165
# Hamada_d_mcap_ratio_HML_for_NVTK_lag_60_days    -0.0679      0.020     -3.324      0.001      -0.108      -0.028
# Hamada_d_mcap_ratio_SMB_for_NVTK_lag_90_days    -0.0505      0.033     -1.536      0.125      -0.115       0.014
# Hamada_d_mcap_ratio_HML_for_NVTK_lag_90_days    -0.0953      0.019     -5.006      0.000      -0.133      -0.058
# MOM                                             -0.1769      0.035     -5.111      0.000      -0.245      -0.109
# MOM_lag_30_days                                 -0.0417      0.042     -0.987      0.324      -0.125       0.041
# MOM_lag_60_days                                  0.2225      0.036      6.268      0.000       0.153       0.292
# MOM_lag_90_days                                  0.0898      0.039      2.308      0.021       0.014       0.166
# ==============================================================================
# Omnibus:                        3.894   Durbin-Watson:                   0.168
# Prob(Omnibus):                  0.143   Jarque-Bera (JB):                3.889
# Skew:                           0.080   Prob(JB):                        0.143
# Kurtosis:                       3.147   Cond. No.                         8.70
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <F test: F=array([[36.29000748]]), p=8.021292097850668e-23, df_denom=1.96e+03, df_num=3>
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe6b90a1820>
# ###################################################################################
# SNGS
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_SNGS_RM_Equity - risk free rate   R-squared (uncentered):                   0.612
# Model:                                                OLS   Adj. R-squared (uncentered):              0.608
# Method:                                     Least Squares   F-statistic:                              138.0
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                   7.96e-274
# Time:                                            19:27:37   Log-Likelihood:                          1737.8
# No. Observations:                                    1417   AIC:                                     -3444.
# Df Residuals:                                        1401   BIC:                                     -3360.
# Df Model:                                              16
# Covariance Type:                                      HC1
# ================================================================================================================
#                                                    coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_SNGS                         1.2039      0.038     31.843      0.000       1.130       1.278
# SNGS_RM_Equity_premium_lag_30_days               0.1287      0.026      4.961      0.000       0.078       0.180
# SNGS_RM_Equity_premium_lag_60_days               0.0053      0.022      0.245      0.806      -0.037       0.048
# SNGS_RM_Equity_premium_lag_90_days               0.0104      0.019      0.536      0.592      -0.028       0.049
# Hamada_d_mcap_ratio_SMB_for_SNGS                -0.2135      0.047     -4.549      0.000      -0.306      -0.122
# Hamada_d_mcap_ratio_HML_for_SNGS                 0.0289      0.027      1.072      0.284      -0.024       0.082
# Hamada_d_mcap_ratio_SMB_for_SNGS_lag_30_days    -0.0456      0.045     -1.018      0.309      -0.133       0.042
# Hamada_d_mcap_ratio_HML_for_SNGS_lag_30_days    -0.0845      0.027     -3.130      0.002      -0.137      -0.032
# Hamada_d_mcap_ratio_SMB_for_SNGS_lag_60_days     0.1884      0.042      4.444      0.000       0.105       0.272
# Hamada_d_mcap_ratio_HML_for_SNGS_lag_60_days     0.2926      0.032      9.137      0.000       0.230       0.355
# Hamada_d_mcap_ratio_SMB_for_SNGS_lag_90_days    -0.1872      0.046     -4.027      0.000      -0.278      -0.096
# Hamada_d_mcap_ratio_HML_for_SNGS_lag_90_days     0.0539      0.039      1.393      0.164      -0.022       0.130
# MOM                                             -0.2961      0.048     -6.220      0.000      -0.389      -0.203
# MOM_lag_30_days                                 -0.3231      0.047     -6.833      0.000      -0.416      -0.230
# MOM_lag_60_days                                  0.3359      0.051      6.615      0.000       0.236       0.435
# MOM_lag_90_days                                  0.2138      0.050      4.253      0.000       0.115       0.312
# ==============================================================================
# Omnibus:                      164.594   Durbin-Watson:                   0.132
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              323.722
# Skew:                           0.724   Prob(JB):                     5.07e-71
# Kurtosis:                       4.840   Cond. No.                         9.01
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <F test: F=array([[14.87033034]]), p=1.560917834997986e-09, df_denom=1.4e+03, df_num=3>
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe6f8357ee0>
# ###################################################################################
# PLZL
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_PLZL_RM_Equity - risk free rate   R-squared (uncentered):                   0.371
# Model:                                                OLS   Adj. R-squared (uncentered):              0.357
# Method:                                     Least Squares   F-statistic:                              59.94
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                   1.51e-121
# Time:                                            19:27:38   Log-Likelihood:                          782.63
# No. Observations:                                     753   AIC:                                     -1533.
# Df Residuals:                                         737   BIC:                                     -1459.
# Df Model:                                              16
# Covariance Type:                                      HC1
# ================================================================================================================
#                                                    coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_PLZL                         0.1549      0.076      2.052      0.040       0.007       0.303
# PLZL_RM_Equity_premium_lag_30_days              -0.0258      0.032     -0.809      0.419      -0.088       0.037
# PLZL_RM_Equity_premium_lag_60_days              -0.2613      0.037     -7.016      0.000      -0.334      -0.188
# PLZL_RM_Equity_premium_lag_90_days              -0.2532      0.045     -5.607      0.000      -0.342      -0.165
# Hamada_d_mcap_ratio_SMB_for_PLZL                 0.1323      0.081      1.626      0.104      -0.027       0.292
# Hamada_d_mcap_ratio_HML_for_PLZL                 0.0650      0.061      1.063      0.288      -0.055       0.185
# Hamada_d_mcap_ratio_SMB_for_PLZL_lag_30_days     0.5605      0.089      6.309      0.000       0.386       0.735
# Hamada_d_mcap_ratio_HML_for_PLZL_lag_30_days    -0.0180      0.086     -0.210      0.834      -0.187       0.151
# Hamada_d_mcap_ratio_SMB_for_PLZL_lag_60_days     0.6554      0.085      7.689      0.000       0.488       0.822
# Hamada_d_mcap_ratio_HML_for_PLZL_lag_60_days    -0.3362      0.077     -4.346      0.000      -0.488      -0.185
# Hamada_d_mcap_ratio_SMB_for_PLZL_lag_90_days     0.1400      0.071      1.969      0.049       0.001       0.279
# Hamada_d_mcap_ratio_HML_for_PLZL_lag_90_days    -0.3521      0.068     -5.165      0.000      -0.486      -0.219
# MOM                                             -0.4368      0.098     -4.451      0.000      -0.629      -0.244
# MOM_lag_30_days                                  0.0311      0.116      0.269      0.788      -0.196       0.258
# MOM_lag_60_days                                  0.5141      0.084      6.152      0.000       0.350       0.678
# MOM_lag_90_days                                  0.4910      0.078      6.296      0.000       0.338       0.644
# ==============================================================================
# Omnibus:                       33.448   Durbin-Watson:                   0.159
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               75.398
# Skew:                          -0.227   Prob(JB):                     4.24e-17
# Kurtosis:                       4.482   Cond. No.                         9.55
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <F test: F=array([[19.46330133]]), p=3.751827345729796e-12, df_denom=737, df_num=3>
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe6e9420fd0>
# ###################################################################################
# TATN
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_TATN_RM_Equity - risk free rate   R-squared (uncentered):                   0.706
# Model:                                                OLS   Adj. R-squared (uncentered):              0.704
# Method:                                     Least Squares   F-statistic:                              216.2
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                        0.00
# Time:                                            19:27:38   Log-Likelihood:                          2945.5
# No. Observations:                                    1979   AIC:                                     -5859.
# Df Residuals:                                        1963   BIC:                                     -5770.
# Df Model:                                              16
# Covariance Type:                                      HC1
# ================================================================================================================
#                                                    coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_TATN                         1.2004      0.025     47.926      0.000       1.151       1.249
# TATN_RM_Equity_premium_lag_30_days               0.0142      0.017      0.851      0.395      -0.018       0.047
# TATN_RM_Equity_premium_lag_60_days               0.0269      0.018      1.526      0.127      -0.008       0.061
# TATN_RM_Equity_premium_lag_90_days               0.1554      0.015     10.423      0.000       0.126       0.185
# Hamada_d_mcap_ratio_SMB_for_TATN                -0.1246      0.029     -4.340      0.000      -0.181      -0.068
# Hamada_d_mcap_ratio_HML_for_TATN                 0.0555      0.018      3.002      0.003       0.019       0.092
# Hamada_d_mcap_ratio_SMB_for_TATN_lag_30_days    -0.1017      0.027     -3.720      0.000      -0.155      -0.048
# Hamada_d_mcap_ratio_HML_for_TATN_lag_30_days    -0.0731      0.024     -3.066      0.002      -0.120      -0.026
# Hamada_d_mcap_ratio_SMB_for_TATN_lag_60_days     0.0006      0.027      0.021      0.983      -0.053       0.054
# Hamada_d_mcap_ratio_HML_for_TATN_lag_60_days     0.2040      0.021      9.573      0.000       0.162       0.246
# Hamada_d_mcap_ratio_SMB_for_TATN_lag_90_days    -0.0671      0.032     -2.122      0.034      -0.129      -0.005
# Hamada_d_mcap_ratio_HML_for_TATN_lag_90_days     0.0616      0.021      2.972      0.003       0.021       0.102
# MOM                                              0.0298      0.033      0.907      0.365      -0.035       0.094
# MOM_lag_30_days                                  0.0525      0.041      1.270      0.204      -0.029       0.134
# MOM_lag_60_days                                 -0.1499      0.038     -3.977      0.000      -0.224      -0.076
# MOM_lag_90_days                                  0.0360      0.038      0.957      0.339      -0.038       0.110
# ==============================================================================
# Omnibus:                       32.145   Durbin-Watson:                   0.202
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               34.070
# Skew:                           0.289   Prob(JB):                     4.00e-08
# Kurtosis:                       3.283   Cond. No.                         8.67
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <F test: F=array([[12.18195165]]), p=6.730929013724422e-08, df_denom=1.96e+03, df_num=3>
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe6c82d1910>
# ###################################################################################
# ROSN
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_ROSN_RM_Equity - risk free rate   R-squared (uncentered):                   0.603
# Model:                                                OLS   Adj. R-squared (uncentered):              0.600
# Method:                                     Least Squares   F-statistic:                              153.2
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                        0.00
# Time:                                            19:27:38   Log-Likelihood:                          2683.7
# No. Observations:                                    1956   AIC:                                     -5335.
# Df Residuals:                                        1940   BIC:                                     -5246.
# Df Model:                                              16
# Covariance Type:                                      HC1
# ================================================================================================================
#                                                    coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_ROSN                         0.6565      0.022     30.426      0.000       0.614       0.699
# ROSN_RM_Equity_premium_lag_30_days              -0.0970      0.015     -6.626      0.000      -0.126      -0.068
# ROSN_RM_Equity_premium_lag_60_days              -0.0656      0.019     -3.375      0.001      -0.104      -0.028
# ROSN_RM_Equity_premium_lag_90_days              -0.0239      0.017     -1.403      0.160      -0.057       0.009
# Hamada_d_mcap_ratio_SMB_for_ROSN                -0.0087      0.019     -0.444      0.657      -0.047       0.030
# Hamada_d_mcap_ratio_HML_for_ROSN                -0.0544      0.013     -4.314      0.000      -0.079      -0.030
# Hamada_d_mcap_ratio_SMB_for_ROSN_lag_30_days    -0.0343      0.020     -1.746      0.081      -0.073       0.004
# Hamada_d_mcap_ratio_HML_for_ROSN_lag_30_days    -0.0958      0.016     -6.063      0.000      -0.127      -0.065
# Hamada_d_mcap_ratio_SMB_for_ROSN_lag_60_days    -0.0082      0.020     -0.413      0.679      -0.047       0.031
# Hamada_d_mcap_ratio_HML_for_ROSN_lag_60_days    -0.0272      0.013     -2.097      0.036      -0.053      -0.002
# Hamada_d_mcap_ratio_SMB_for_ROSN_lag_90_days    -0.0435      0.019     -2.267      0.023      -0.081      -0.006
# Hamada_d_mcap_ratio_HML_for_ROSN_lag_90_days     0.0263      0.013      2.084      0.037       0.002       0.051
# MOM                                              0.0662      0.034      1.945      0.052      -0.001       0.133
# MOM_lag_30_days                                 -0.1512      0.051     -2.938      0.003      -0.252      -0.050
# MOM_lag_60_days                                 -0.0060      0.040     -0.150      0.881      -0.084       0.072
# MOM_lag_90_days                                  0.0794      0.043      1.827      0.068      -0.006       0.164
# ==============================================================================
# Omnibus:                      123.225   Durbin-Watson:                   0.082
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              250.578
# Skew:                           0.423   Prob(JB):                     3.87e-55
# Kurtosis:                       4.536   Cond. No.                         8.40
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <F test: F=array([[6.78630992]]), p=0.00015007045645599668, df_denom=1.94e+03, df_num=3>
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe6d8d10970>
# ###################################################################################
# MGNT
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_MGNT_RM_Equity - risk free rate   R-squared (uncentered):                   0.381
# Model:                                                OLS   Adj. R-squared (uncentered):              0.376
# Method:                                     Least Squares   F-statistic:                              78.18
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                   1.75e-196
# Time:                                            19:27:38   Log-Likelihood:                          2125.3
# No. Observations:                                    1979   AIC:                                     -4219.
# Df Residuals:                                        1963   BIC:                                     -4129.
# Df Model:                                              16
# Covariance Type:                                      HC1
# ================================================================================================================
#                                                    coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_MGNT                         0.5375      0.027     19.995      0.000       0.485       0.590
# MGNT_RM_Equity_premium_lag_30_days               0.0162      0.019      0.843      0.399      -0.021       0.054
# MGNT_RM_Equity_premium_lag_60_days               0.0982      0.030      3.320      0.001       0.040       0.156
# MGNT_RM_Equity_premium_lag_90_days               0.1361      0.018      7.650      0.000       0.101       0.171
# Hamada_d_mcap_ratio_SMB_for_MGNT                 0.1312      0.036      3.665      0.000       0.061       0.201
# Hamada_d_mcap_ratio_HML_for_MGNT                 0.2938      0.024     12.061      0.000       0.246       0.342
# Hamada_d_mcap_ratio_SMB_for_MGNT_lag_30_days     0.1288      0.036      3.609      0.000       0.059       0.199
# Hamada_d_mcap_ratio_HML_for_MGNT_lag_30_days     0.3443      0.030     11.549      0.000       0.286       0.403
# Hamada_d_mcap_ratio_SMB_for_MGNT_lag_60_days     0.3145      0.034      9.138      0.000       0.247       0.382
# Hamada_d_mcap_ratio_HML_for_MGNT_lag_60_days     0.0293      0.024      1.211      0.226      -0.018       0.077
# Hamada_d_mcap_ratio_SMB_for_MGNT_lag_90_days    -0.0501      0.035     -1.422      0.155      -0.119       0.019
# Hamada_d_mcap_ratio_HML_for_MGNT_lag_90_days     0.1435      0.024      5.870      0.000       0.096       0.191
# MOM                                             -0.1546      0.048     -3.187      0.001      -0.250      -0.060
# MOM_lag_30_days                                 -0.4688      0.058     -8.026      0.000      -0.583      -0.354
# MOM_lag_60_days                                  0.4455      0.056      7.934      0.000       0.335       0.556
# MOM_lag_90_days                                  0.0168      0.050      0.338      0.736      -0.081       0.114
# ==============================================================================
# Omnibus:                      211.861   Durbin-Watson:                   0.142
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              437.842
# Skew:                          -0.667   Prob(JB):                     8.39e-96
# Kurtosis:                       4.879   Cond. No.                         8.33
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <F test: F=array([[59.49408069]]), p=8.24957426120736e-37, df_denom=1.96e+03, df_num=3>
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe6b9094fd0>
# ###################################################################################
# MTSS
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_MTSS_RM_Equity - risk free rate   R-squared (uncentered):                   0.491
# Model:                                                OLS   Adj. R-squared (uncentered):              0.486
# Method:                                     Least Squares   F-statistic:                              78.62
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                   2.06e-197
# Time:                                            19:27:38   Log-Likelihood:                          2650.6
# No. Observations:                                    1979   AIC:                                     -5269.
# Df Residuals:                                        1963   BIC:                                     -5180.
# Df Model:                                              16
# Covariance Type:                                      HC1
# ================================================================================================================
#                                                    coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_MTSS                         0.5630      0.022     25.054      0.000       0.519       0.607
# MTSS_RM_Equity_premium_lag_30_days               0.0163      0.022      0.749      0.454      -0.026       0.059
# MTSS_RM_Equity_premium_lag_60_days               0.0257      0.020      1.290      0.197      -0.013       0.065
# MTSS_RM_Equity_premium_lag_90_days              -0.0348      0.020     -1.776      0.076      -0.073       0.004
# Hamada_d_mcap_ratio_SMB_for_MTSS                -0.0136      0.025     -0.545      0.586      -0.062       0.035
# Hamada_d_mcap_ratio_HML_for_MTSS                -0.0650      0.020     -3.294      0.001      -0.104      -0.026
# Hamada_d_mcap_ratio_SMB_for_MTSS_lag_30_days     0.0532      0.024      2.196      0.028       0.006       0.101
# Hamada_d_mcap_ratio_HML_for_MTSS_lag_30_days    -0.0909      0.026     -3.502      0.000      -0.142      -0.040
# Hamada_d_mcap_ratio_SMB_for_MTSS_lag_60_days     0.0507      0.022      2.331      0.020       0.008       0.093
# Hamada_d_mcap_ratio_HML_for_MTSS_lag_60_days    -0.1164      0.018     -6.348      0.000      -0.152      -0.080
# Hamada_d_mcap_ratio_SMB_for_MTSS_lag_90_days    -0.1356      0.023     -5.904      0.000      -0.181      -0.091
# Hamada_d_mcap_ratio_HML_for_MTSS_lag_90_days     0.0710      0.017      4.228      0.000       0.038       0.104
# MOM                                             -0.0831      0.037     -2.249      0.024      -0.155      -0.011
# MOM_lag_30_days                                 -0.1608      0.054     -2.964      0.003      -0.267      -0.054
# MOM_lag_60_days                                  0.3798      0.043      8.792      0.000       0.295       0.465
# MOM_lag_90_days                                 -0.1419      0.044     -3.248      0.001      -0.228      -0.056
# ==============================================================================
# Omnibus:                      137.662   Durbin-Watson:                   0.115
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              245.499
# Skew:                          -0.503   Prob(JB):                     4.90e-54
# Kurtosis:                       4.401   Cond. No.                         8.35
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <F test: F=array([[6.31816349]]), p=0.00029107847899244007, df_denom=1.96e+03, df_num=3>
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe6e9408610>
# ###################################################################################
# MOEX
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_MOEX_RM_Equity - risk free rate   R-squared (uncentered):                   0.253
# Model:                                                OLS   Adj. R-squared (uncentered):              0.245
# Method:                                     Least Squares   F-statistic:                              32.52
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                    2.60e-85
# Time:                                            19:27:38   Log-Likelihood:                          1801.6
# No. Observations:                                    1507   AIC:                                     -3571.
# Df Residuals:                                        1491   BIC:                                     -3486.
# Df Model:                                              16
# Covariance Type:                                      HC1
# ================================================================================================================
#                                                    coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_MOEX                         0.0902      0.010      9.005      0.000       0.071       0.110
# MOEX_RM_Equity_premium_lag_30_days              -0.2181      0.028     -7.687      0.000      -0.274      -0.162
# MOEX_RM_Equity_premium_lag_60_days              -0.0886      0.023     -3.786      0.000      -0.134      -0.043
# MOEX_RM_Equity_premium_lag_90_days              -0.0016      0.026     -0.062      0.951      -0.053       0.050
# Hamada_d_mcap_ratio_SMB_for_MOEX                -0.0085      0.009     -0.903      0.367      -0.027       0.010
# Hamada_d_mcap_ratio_HML_for_MOEX                -0.0334      0.012     -2.795      0.005      -0.057      -0.010
# Hamada_d_mcap_ratio_SMB_for_MOEX_lag_30_days     0.0471      0.009      5.246      0.000       0.029       0.065
# ...
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                   1.86e-137
# Time:                                            19:27:39   Log-Likelihood:                          1818.9
# No. Observations:                                    1979   AIC:                                     -3606.
# Df Residuals:                                        1963   BIC:                                     -3516.
# Df Model:                                              16
# Covariance Type:                                      HC1
# ================================================================================================================
#                                                    coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_KMAZ                         0.4100      0.023     18.166      0.000       0.366       0.454
# KMAZ_RM_Equity_premium_lag_30_days               0.0857      0.028      3.044      0.002       0.031       0.141
# KMAZ_RM_Equity_premium_lag_60_days              -0.1251      0.026     -4.900      0.000      -0.175      -0.075
# KMAZ_RM_Equity_premium_lag_90_days              -0.0818      0.023     -3.584      0.000      -0.126      -0.037
# Hamada_d_mcap_ratio_SMB_for_KMAZ                -0.0114      0.031     -0.372      0.710      -0.071       0.049
# Hamada_d_mcap_ratio_HML_for_KMAZ                -0.0665      0.021     -3.107      0.002      -0.108      -0.025
# Hamada_d_mcap_ratio_SMB_for_KMAZ_lag_30_days     0.2022      0.029      6.883      0.000       0.145       0.260
# Hamada_d_mcap_ratio_HML_for_KMAZ_lag_30_days    -0.1018      0.020     -5.199      0.000      -0.140      -0.063
# Hamada_d_mcap_ratio_SMB_for_KMAZ_lag_60_days     0.0968      0.022      4.359      0.000       0.053       0.140
# Hamada_d_mcap_ratio_HML_for_KMAZ_lag_60_days     0.0258      0.019      1.324      0.185      -0.012       0.064
# Hamada_d_mcap_ratio_SMB_for_KMAZ_lag_90_days    -0.0895      0.025     -3.609      0.000      -0.138      -0.041
# Hamada_d_mcap_ratio_HML_for_KMAZ_lag_90_days     0.0165      0.023      0.718      0.473      -0.029       0.062
# MOM                                             -0.0040      0.064     -0.064      0.949      -0.129       0.121
# MOM_lag_30_days                                 -0.1551      0.053     -2.946      0.003      -0.258      -0.052
# MOM_lag_60_days                                 -0.0719      0.055     -1.314      0.189      -0.179       0.035
# MOM_lag_90_days                                  0.2239      0.062      3.586      0.000       0.102       0.346
# ==============================================================================
# Omnibus:                      340.015   Durbin-Watson:                   0.137
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              731.991
# Skew:                           0.991   Prob(JB):                    1.12e-159
# Kurtosis:                       5.224   Cond. No.                         8.16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <F test: F=array([[4.42211]]), p=0.004174321106320694, df_denom=1.96e+03, df_num=3>
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe6b9094fd0>
# ###################################################################################
# RASP
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_RASP_RM_Equity - risk free rate   R-squared (uncentered):                   0.468
# Model:                                                OLS   Adj. R-squared (uncentered):              0.464
# Method:                                     Least Squares   F-statistic:                              73.06
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                   1.30e-185
# Time:                                            19:27:39   Log-Likelihood:                          1392.5
# No. Observations:                                    1979   AIC:                                     -2753.
# Df Residuals:                                        1963   BIC:                                     -2664.
# Df Model:                                              16
# Covariance Type:                                      HC1
# ================================================================================================================
#                                                    coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_RASP                         1.1542      0.044     26.481      0.000       1.069       1.240
# RASP_RM_Equity_premium_lag_30_days               0.1365      0.020      6.702      0.000       0.097       0.176
# RASP_RM_Equity_premium_lag_60_days               0.1010      0.018      5.639      0.000       0.066       0.136
# RASP_RM_Equity_premium_lag_90_days              -0.0545      0.015     -3.723      0.000      -0.083      -0.026
# Hamada_d_mcap_ratio_SMB_for_RASP                -0.0998      0.048     -2.060      0.039      -0.195      -0.005
# Hamada_d_mcap_ratio_HML_for_RASP                 0.0269      0.029      0.914      0.360      -0.031       0.085
# Hamada_d_mcap_ratio_SMB_for_RASP_lag_30_days     0.8204      0.054     15.072      0.000       0.714       0.927
# Hamada_d_mcap_ratio_HML_for_RASP_lag_30_days     0.2622      0.037      7.114      0.000       0.190       0.334
# Hamada_d_mcap_ratio_SMB_for_RASP_lag_60_days    -0.2315      0.047     -4.976      0.000      -0.323      -0.140
# Hamada_d_mcap_ratio_HML_for_RASP_lag_60_days     0.0404      0.037      1.105      0.269      -0.031       0.112
# Hamada_d_mcap_ratio_SMB_for_RASP_lag_90_days     0.1678      0.050      3.375      0.001       0.070       0.265
# Hamada_d_mcap_ratio_HML_for_RASP_lag_90_days    -0.0623      0.046     -1.354      0.176      -0.153       0.028
# MOM                                             -0.3167      0.063     -5.038      0.000      -0.440      -0.193
# MOM_lag_30_days                                 -0.0656      0.084     -0.785      0.433      -0.230       0.098
# MOM_lag_60_days                                  0.1969      0.074      2.668      0.008       0.052       0.342
# MOM_lag_90_days                                  0.0523      0.080      0.650      0.515      -0.105       0.210
# ==============================================================================
# Omnibus:                       27.117   Durbin-Watson:                   0.147
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               28.516
# Skew:                           0.263   Prob(JB):                     6.42e-07
# Kurtosis:                       3.264   Cond. No.                         8.24
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <F test: F=array([[9.33602662]]), p=3.967433606854649e-06, df_denom=1.96e+03, df_num=3>
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe719ecc7c0>
# ###################################################################################
# OGKB
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_OGKB_RM_Equity - risk free rate   R-squared (uncentered):                   0.532
# Model:                                                OLS   Adj. R-squared (uncentered):              0.528
# Method:                                     Least Squares   F-statistic:                              104.1
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                   5.58e-247
# Time:                                            19:27:39   Log-Likelihood:                          1785.8
# No. Observations:                                    1956   AIC:                                     -3540.
# Df Residuals:                                        1940   BIC:                                     -3450.
# Df Model:                                              16
# Covariance Type:                                      HC1
# ================================================================================================================
#                                                    coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_OGKB                         0.5717      0.027     21.204      0.000       0.519       0.625
# OGKB_RM_Equity_premium_lag_30_days              -0.0393      0.018     -2.228      0.026      -0.074      -0.005
# OGKB_RM_Equity_premium_lag_60_days              -0.0742      0.018     -4.159      0.000      -0.109      -0.039
# OGKB_RM_Equity_premium_lag_90_days               0.0751      0.019      3.956      0.000       0.038       0.112
# Hamada_d_mcap_ratio_SMB_for_OGKB                -0.2556      0.029     -8.715      0.000      -0.313      -0.198
# Hamada_d_mcap_ratio_HML_for_OGKB                -0.0425      0.016     -2.621      0.009      -0.074      -0.011
# Hamada_d_mcap_ratio_SMB_for_OGKB_lag_30_days     0.5186      0.031     16.611      0.000       0.457       0.580
# Hamada_d_mcap_ratio_HML_for_OGKB_lag_30_days    -0.3289      0.025    -13.343      0.000      -0.377      -0.281
# Hamada_d_mcap_ratio_SMB_for_OGKB_lag_60_days     0.1596      0.027      6.004      0.000       0.108       0.212
# Hamada_d_mcap_ratio_HML_for_OGKB_lag_60_days    -0.1106      0.025     -4.407      0.000      -0.160      -0.061
# Hamada_d_mcap_ratio_SMB_for_OGKB_lag_90_days     0.1695      0.029      5.892      0.000       0.113       0.226
# Hamada_d_mcap_ratio_HML_for_OGKB_lag_90_days     0.1539      0.022      6.905      0.000       0.110       0.198
# MOM                                             -0.0360      0.054     -0.666      0.505      -0.142       0.070
# MOM_lag_30_days                                  0.1065      0.064      1.668      0.095      -0.019       0.232
# MOM_lag_60_days                                 -0.0696      0.061     -1.137      0.255      -0.189       0.050
# MOM_lag_90_days                                 -0.0425      0.066     -0.645      0.519      -0.172       0.087
# ==============================================================================
# Omnibus:                       58.454   Durbin-Watson:                   0.165
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               76.125
# Skew:                           0.335   Prob(JB):                     2.95e-17
# Kurtosis:                       3.696   Cond. No.                         8.52
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <F test: F=array([[27.84044485]]), p=1.2649750939448542e-17, df_denom=1.94e+03, df_num=3>
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe698244d90>
# ###################################################################################
# VZRZ
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_VZRZ_RM_Equity - risk free rate   R-squared (uncentered):                   0.199
# Model:                                                OLS   Adj. R-squared (uncentered):              0.192
# Method:                                     Least Squares   F-statistic:                              31.02
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                    2.06e-84
# Time:                                            19:27:39   Log-Likelihood:                          1844.0
# No. Observations:                                    1979   AIC:                                     -3656.
# Df Residuals:                                        1963   BIC:                                     -3567.
# Df Model:                                              16
# Covariance Type:                                      HC1
# ================================================================================================================
#                                                    coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_VZRZ                         0.1097      0.018      6.088      0.000       0.074       0.145
# VZRZ_RM_Equity_premium_lag_30_days              -0.1158      0.022     -5.208      0.000      -0.159      -0.072
# VZRZ_RM_Equity_premium_lag_60_days              -0.0495      0.023     -2.143      0.032      -0.095      -0.004
# VZRZ_RM_Equity_premium_lag_90_days              -0.1688      0.021     -7.904      0.000      -0.211      -0.127
# Hamada_d_mcap_ratio_SMB_for_VZRZ                 0.1743      0.024      7.125      0.000       0.126       0.222
# Hamada_d_mcap_ratio_HML_for_VZRZ                 0.0472      0.017      2.748      0.006       0.014       0.081
# Hamada_d_mcap_ratio_SMB_for_VZRZ_lag_30_days     0.3457      0.024     14.316      0.000       0.298       0.393
# Hamada_d_mcap_ratio_HML_for_VZRZ_lag_30_days     0.0639      0.016      3.939      0.000       0.032       0.096
# Hamada_d_mcap_ratio_SMB_for_VZRZ_lag_60_days     0.0046      0.023      0.201      0.841      -0.040       0.050
# Hamada_d_mcap_ratio_HML_for_VZRZ_lag_60_days     0.0228      0.017      1.335      0.182      -0.011       0.056
# Hamada_d_mcap_ratio_SMB_for_VZRZ_lag_90_days     0.0466      0.023      2.029      0.043       0.002       0.092
# Hamada_d_mcap_ratio_HML_for_VZRZ_lag_90_days    -0.1203      0.016     -7.433      0.000      -0.152      -0.089
# MOM                                             -0.3260      0.055     -5.946      0.000      -0.433      -0.219
# MOM_lag_30_days                                 -0.1317      0.075     -1.757      0.079      -0.279       0.015
# MOM_lag_60_days                                  0.0624      0.061      1.017      0.309      -0.058       0.183
# MOM_lag_90_days                                  0.2701      0.057      4.745      0.000       0.159       0.382
# ==============================================================================
# Omnibus:                       37.721   Durbin-Watson:                   0.122
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               44.974
# Skew:                          -0.269   Prob(JB):                     1.71e-10
# Kurtosis:                       3.505   Cond. No.                         8.90
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <F test: F=array([[32.62491255]]), p=1.415387415045811e-20, df_denom=1.96e+03, df_num=3>
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe6982442b0>

# %% [markdown]
# ## Carhart model with lags autolags and specific for Russia factors

# %%
lag_autolag_return_30 = 30
lag_autolag_return_60 = 60
lag_autolag_return_90 = 90
lag_30 = 30
lag_60 = 60
lag_90 = 90

r_2_results_carh_l_al_spec = []
mse_results_carh_l_al_spec = []

for name in data_ret.columns[2:]:
    
    df1 = data[[name, 'Hamada_beta_MRP_for_{}'.format(name[7:11]), 'risk_free_rate_based_on_g_curve',
                 'Hamada_d_mcap_ratio_SMB_for_{}'.format(name[7:11]),
                 'Hamada_d_mcap_ratio_HML_for_{}'.format(name[7:11]),
                 'MOM']].dropna()
    df_autolag = pd.DataFrame(data[name] - data['risk_free_rate_based_on_g_curve']).rename(columns = {0:'{}_premium_lag_{}_days'.format(name[7:], lag_autolag_return_30)})
    df_autolag = pd.DataFrame(df_autolag['{}_premium_lag_{}_days'.format(name[7:], lag_autolag_return_30)].shift(lag_autolag_return_30).dropna())
    
    df_autolag_2 = pd.DataFrame(data[name] - data['risk_free_rate_based_on_g_curve']).rename(columns = {0:'{}_premium_lag_{}_days'.format(name[7:], lag_autolag_return_60)})
    df_autolag_2 = pd.DataFrame(df_autolag_2['{}_premium_lag_{}_days'.format(name[7:], lag_autolag_return_60)].shift(lag_autolag_return_60).dropna())
    
    df_autolag_3 = pd.DataFrame(data[name] - data['risk_free_rate_based_on_g_curve']).rename(columns = {0:'{}_premium_lag_{}_days'.format(name[7:], lag_autolag_return_90)})
    df_autolag_3 = pd.DataFrame(df_autolag_3['{}_premium_lag_{}_days'.format(name[7:], lag_autolag_return_90)].shift(lag_autolag_return_90).dropna())
    
    df2 = data[['Hamada_d_mcap_ratio_SMB_for_{}'.format(name[7:11]),
            'Hamada_d_mcap_ratio_HML_for_{}'.format(name[7:11]), 'MOM']].shift(lag_30).dropna()
    
    
    
    df2.rename(columns = {'Hamada_d_mcap_ratio_SMB_for_{}'.format(name[7:11]):'Hamada_d_mcap_ratio_SMB_for_{}_lag_{}_days'.format(name[7:11], lag_30),
                          'Hamada_d_mcap_ratio_HML_for_{}'.format(name[7:11]):'Hamada_d_mcap_ratio_HML_for_{}_lag_{}_days'.format(name[7:11], lag_30), 
                          'MOM':'MOM_lag_{}_days'.format(lag_30)}, inplace = True)
    
    result = pd.concat([df1, df2], axis=1, join="inner")
    
    df3 = data[['Hamada_d_mcap_ratio_SMB_for_{}'.format(name[7:11]),
            'Hamada_d_mcap_ratio_HML_for_{}'.format(name[7:11]), 'MOM']].shift(lag_60).dropna()
    
    df3.rename(columns = {'Hamada_d_mcap_ratio_SMB_for_{}'.format(name[7:11]):'Hamada_d_mcap_ratio_SMB_for_{}_lag_{}_days'.format(name[7:11], lag_60),
                          'Hamada_d_mcap_ratio_HML_for_{}'.format(name[7:11]):'Hamada_d_mcap_ratio_HML_for_{}_lag_{}_days'.format(name[7:11], lag_60), 
                          'MOM':'MOM_lag_{}_days'.format(lag_60)}, inplace = True)
    
    result = pd.concat([result, df3], axis=1, join="inner")
    
    df4 = data[['Hamada_d_mcap_ratio_SMB_for_{}'.format(name[7:11]),
            'Hamada_d_mcap_ratio_HML_for_{}'.format(name[7:11]), 'MOM']].shift(lag_90).dropna()
    
    df4.rename(columns = {'Hamada_d_mcap_ratio_SMB_for_{}'.format(name[7:11]):'Hamada_d_mcap_ratio_SMB_for_{}_lag_{}_days'.format(name[7:11], lag_90),
                          'Hamada_d_mcap_ratio_HML_for_{}'.format(name[7:11]):'Hamada_d_mcap_ratio_HML_for_{}_lag_{}_days'.format(name[7:11], lag_90), 
                          'MOM':'MOM_lag_{}_days'.format(lag_90)}, inplace = True)
    
    result = pd.concat([result, df4], axis=1, join="inner")
    
    result = pd.merge(result, macro_data, left_index=True, right_index=True)
    result = pd.merge(result, df_autolag, left_index=True, right_index=True)
    result = pd.merge(result, df_autolag_2, left_index=True, right_index=True)
    result = pd.merge(result, df_autolag_3, left_index=True, right_index=True)
    
    Base = result.dropna()
    
    Y = pd.DataFrame(Base[name] - Base['risk_free_rate_based_on_g_curve'])
    Y.rename(columns = {0:'{} - risk free rate'.format(name)}, inplace = True)
    X = Base[['Hamada_beta_MRP_for_{}'.format(name[7:11]), 
              '{}_premium_lag_{}_days'.format(name[7:], lag_autolag_return_30),
              '{}_premium_lag_{}_days'.format(name[7:], lag_autolag_return_60),
              '{}_premium_lag_{}_days'.format(name[7:], lag_autolag_return_90),
              'Hamada_d_mcap_ratio_SMB_for_{}'.format(name[7:11]),
              'Hamada_d_mcap_ratio_HML_for_{}'.format(name[7:11]), 
              'Hamada_d_mcap_ratio_SMB_for_{}_lag_{}_days'.format(name[7:11], lag_30),
              'Hamada_d_mcap_ratio_HML_for_{}_lag_{}_days'.format(name[7:11], lag_30),
              'Hamada_d_mcap_ratio_SMB_for_{}_lag_{}_days'.format(name[7:11], lag_60),
              'Hamada_d_mcap_ratio_HML_for_{}_lag_{}_days'.format(name[7:11], lag_60),
              'Hamada_d_mcap_ratio_SMB_for_{}_lag_{}_days'.format(name[7:11], lag_90),
              'Hamada_d_mcap_ratio_HML_for_{}_lag_{}_days'.format(name[7:11], lag_90),
              'MOM','MOM_lag_{}_days'.format(lag_30),'MOM_lag_{}_days'.format(lag_60),
              'MOM_lag_{}_days'.format(lag_90),'dollar_30d_return','wti_30d_return']]
    model = sm.OLS(Y,X)
    results = model.fit(cov_type = 'HC1')
    print('###################################################################################')
    print(name[7:11])
    print(results.summary())
    hypotheses = '({} = 0), ({} = 0), (MOM = 0)'.format('Hamada_d_mcap_ratio_SMB_for_{}'.format(name[7:11]), 'Hamada_d_mcap_ratio_HML_for_{}'.format(name[7:11]))
    f_test = results.f_test(hypotheses)
    print(f_test)
    print(results)
    r_2_results_carh_l_al_spec.append(results.rsquared_adj)
    mse_results_carh_l_al_spec.append(results.mse_resid)
# Out:
# ###################################################################################
# SBER
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_SBER_RM_Equity - risk free rate   R-squared (uncentered):                   0.680
# Model:                                                OLS   Adj. R-squared (uncentered):              0.677
# Method:                                     Least Squares   F-statistic:                              190.8
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                        0.00
# Time:                                            19:27:39   Log-Likelihood:                          2860.9
# No. Observations:                                    1979   AIC:                                     -5686.
# Df Residuals:                                        1961   BIC:                                     -5585.
# Df Model:                                              18
# Covariance Type:                                      HC1
# ================================================================================================================
#                                                    coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_SBER                         0.4336      0.016     27.130      0.000       0.402       0.465
# SBER_RM_Equity_premium_lag_30_days               0.0680      0.016      4.199      0.000       0.036       0.100
# SBER_RM_Equity_premium_lag_60_days               0.1286      0.016      8.012      0.000       0.097       0.160
# SBER_RM_Equity_premium_lag_90_days               0.0584      0.016      3.750      0.000       0.028       0.089
# Hamada_d_mcap_ratio_SMB_for_SBER                 0.0628      0.017      3.590      0.000       0.029       0.097
# Hamada_d_mcap_ratio_HML_for_SBER                 0.0536      0.009      5.675      0.000       0.035       0.072
# Hamada_d_mcap_ratio_SMB_for_SBER_lag_30_days     0.0451      0.016      2.862      0.004       0.014       0.076
# Hamada_d_mcap_ratio_HML_for_SBER_lag_30_days     0.0546      0.012      4.697      0.000       0.032       0.077
# Hamada_d_mcap_ratio_SMB_for_SBER_lag_60_days     0.0468      0.014      3.459      0.001       0.020       0.073
# Hamada_d_mcap_ratio_HML_for_SBER_lag_60_days     0.0307      0.013      2.442      0.015       0.006       0.055
# Hamada_d_mcap_ratio_SMB_for_SBER_lag_90_days     0.0488      0.015      3.200      0.001       0.019       0.079
# Hamada_d_mcap_ratio_HML_for_SBER_lag_90_days     0.0249      0.013      1.958      0.050   -2.37e-05       0.050
# MOM                                              0.0610      0.037      1.665      0.096      -0.011       0.133
# MOM_lag_30_days                                 -0.1166      0.047     -2.498      0.012      -0.208      -0.025
# MOM_lag_60_days                                 -0.1993      0.035     -5.714      0.000      -0.268      -0.131
# MOM_lag_90_days                                  0.2720      0.035      7.749      0.000       0.203       0.341
# dollar_30d_return                               -0.7609      0.039    -19.750      0.000      -0.836      -0.685
# wti_30d_return                                   0.0146      0.011      1.375      0.169      -0.006       0.035
# ==============================================================================
# Omnibus:                       33.497   Durbin-Watson:                   0.154
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               64.066
# Skew:                          -0.015   Prob(JB):                     1.23e-14
# Kurtosis:                       3.881   Cond. No.                         9.56
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <F test: F=array([[19.40865126]]), p=2.1185850706188445e-12, df_denom=1.96e+03, df_num=3>
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe698244640>
# ###################################################################################
# GAZP
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_GAZP_RM_Equity - risk free rate   R-squared (uncentered):                   0.732
# Model:                                                OLS   Adj. R-squared (uncentered):              0.729
# Method:                                     Least Squares   F-statistic:                              193.5
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                        0.00
# Time:                                            19:27:39   Log-Likelihood:                          3250.9
# No. Observations:                                    1979   AIC:                                     -6466.
# Df Residuals:                                        1961   BIC:                                     -6365.
# Df Model:                                              18
# Covariance Type:                                      HC1
# ================================================================================================================
#                                                    coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_GAZP                         0.7006      0.018     39.813      0.000       0.666       0.735
# GAZP_RM_Equity_premium_lag_30_days               0.0099      0.014      0.726      0.468      -0.017       0.037
# GAZP_RM_Equity_premium_lag_60_days              -0.0804      0.015     -5.234      0.000      -0.110      -0.050
# GAZP_RM_Equity_premium_lag_90_days              -0.0206      0.011     -1.828      0.067      -0.043       0.001
# Hamada_d_mcap_ratio_SMB_for_GAZP                -0.0788      0.020     -3.898      0.000      -0.118      -0.039
# Hamada_d_mcap_ratio_HML_for_GAZP                 0.0046      0.013      0.368      0.713      -0.020       0.029
# Hamada_d_mcap_ratio_SMB_for_GAZP_lag_30_days    -0.1926      0.019     -9.970      0.000      -0.230      -0.155
# Hamada_d_mcap_ratio_HML_for_GAZP_lag_30_days    -0.2426      0.019    -12.994      0.000      -0.279      -0.206
# Hamada_d_mcap_ratio_SMB_for_GAZP_lag_60_days     0.0018      0.018      0.101      0.919      -0.033       0.037
# Hamada_d_mcap_ratio_HML_for_GAZP_lag_60_days    -0.0773      0.013     -6.003      0.000      -0.103      -0.052
# Hamada_d_mcap_ratio_SMB_for_GAZP_lag_90_days    -0.0426      0.017     -2.489      0.013      -0.076      -0.009
# Hamada_d_mcap_ratio_HML_for_GAZP_lag_90_days     0.0356      0.013      2.718      0.007       0.010       0.061
# MOM                                             -0.1483      0.029     -5.133      0.000      -0.205      -0.092
# MOM_lag_30_days                                  0.1954      0.037      5.316      0.000       0.123       0.267
# MOM_lag_60_days                                 -0.0395      0.035     -1.121      0.262      -0.108       0.030
# MOM_lag_90_days                                 -0.0679      0.029     -2.355      0.019      -0.124      -0.011
# dollar_30d_return                                0.0588      0.027      2.184      0.029       0.006       0.112
# wti_30d_return                                  -0.0254      0.013     -2.001      0.045      -0.050      -0.001
# ==============================================================================
# Omnibus:                      156.635   Durbin-Watson:                   0.137
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              309.521
# Skew:                           0.527   Prob(JB):                     6.14e-68
# Kurtosis:                       4.625   Cond. No.                         9.10
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <F test: F=array([[9.97850341]]), p=1.5828569477766205e-06, df_denom=1.96e+03, df_num=3>
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe6982539d0>
# ###################################################################################
# LKOH
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_LKOH_RM_Equity - risk free rate   R-squared (uncentered):                   0.734
# Model:                                                OLS   Adj. R-squared (uncentered):              0.731
# Method:                                     Least Squares   F-statistic:                              224.8
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                        0.00
# Time:                                            19:27:39   Log-Likelihood:                          3524.5
# No. Observations:                                    1979   AIC:                                     -7013.
# Df Residuals:                                        1961   BIC:                                     -6912.
# Df Model:                                              18
# Covariance Type:                                      HC1
# ================================================================================================================
#                                                    coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_LKOH                         0.8521      0.018     46.731      0.000       0.816       0.888
# LKOH_RM_Equity_premium_lag_30_days               0.0161      0.015      1.111      0.267      -0.012       0.045
# LKOH_RM_Equity_premium_lag_60_days               0.0303      0.014      2.146      0.032       0.003       0.058
# LKOH_RM_Equity_premium_lag_90_days              -0.0129      0.014     -0.908      0.364      -0.041       0.015
# Hamada_d_mcap_ratio_SMB_for_LKOH                 0.0568      0.020      2.777      0.005       0.017       0.097
# Hamada_d_mcap_ratio_HML_for_LKOH                 0.0310      0.016      1.901      0.057      -0.001       0.063
# Hamada_d_mcap_ratio_SMB_for_LKOH_lag_30_days    -0.1830      0.020     -9.117      0.000      -0.222      -0.144
# Hamada_d_mcap_ratio_HML_for_LKOH_lag_30_days     0.0409      0.020      2.066      0.039       0.002       0.080
# Hamada_d_mcap_ratio_SMB_for_LKOH_lag_60_days    -0.0518      0.022     -2.362      0.018      -0.095      -0.009
# Hamada_d_mcap_ratio_HML_for_LKOH_lag_60_days     0.0635      0.015      4.186      0.000       0.034       0.093
# Hamada_d_mcap_ratio_SMB_for_LKOH_lag_90_days    -0.0010      0.019     -0.051      0.959      -0.039       0.037
# Hamada_d_mcap_ratio_HML_for_LKOH_lag_90_days    -0.0019      0.013     -0.148      0.882      -0.027       0.023
# MOM                                              0.0096      0.026      0.369      0.712      -0.042       0.061
# MOM_lag_30_days                                 -0.0161      0.035     -0.463      0.644      -0.084       0.052
# MOM_lag_60_days                                 -0.0556      0.029     -1.914      0.056      -0.113       0.001
# MOM_lag_90_days                                  0.0708      0.026      2.737      0.006       0.020       0.122
# dollar_30d_return                                0.1913      0.023      8.277      0.000       0.146       0.237
# wti_30d_return                                   0.0809      0.011      7.678      0.000       0.060       0.101
# ==============================================================================
# Omnibus:                       95.307   Durbin-Watson:                   0.175
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              135.621
# Skew:                          -0.441   Prob(JB):                     3.55e-30
# Kurtosis:                       3.932   Cond. No.                         9.43
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <F test: F=array([[3.89153677]]), p=0.0087118817041238, df_denom=1.96e+03, df_num=3>
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe719339dc0>
# ###################################################################################
# GMKN
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_GMKN_RM_Equity - risk free rate   R-squared (uncentered):                   0.569
# Model:                                                OLS   Adj. R-squared (uncentered):              0.565
# Method:                                     Least Squares   F-statistic:                              139.5
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                        0.00
# Time:                                            19:27:39   Log-Likelihood:                          2941.1
# No. Observations:                                    1979   AIC:                                     -5846.
# Df Residuals:                                        1961   BIC:                                     -5746.
# Df Model:                                              18
# Covariance Type:                                      HC1
# ================================================================================================================
#                                                    coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_GMKN                         0.8729      0.023     37.884      0.000       0.828       0.918
# GMKN_RM_Equity_premium_lag_30_days              -0.0488      0.018     -2.767      0.006      -0.083      -0.014
# GMKN_RM_Equity_premium_lag_60_days               0.1570      0.016      9.622      0.000       0.125       0.189
# GMKN_RM_Equity_premium_lag_90_days              -0.0031      0.015     -0.209      0.835      -0.032       0.026
# Hamada_d_mcap_ratio_SMB_for_GMKN                 0.0792      0.030      2.646      0.008       0.021       0.138
# Hamada_d_mcap_ratio_HML_for_GMKN                -0.1020      0.018     -5.721      0.000      -0.137      -0.067
# Hamada_d_mcap_ratio_SMB_for_GMKN_lag_30_days     0.0105      0.028      0.379      0.705      -0.044       0.065
# Hamada_d_mcap_ratio_HML_for_GMKN_lag_30_days     0.1949      0.022      8.720      0.000       0.151       0.239
# Hamada_d_mcap_ratio_SMB_for_GMKN_lag_60_days    -0.1802      0.026     -7.062      0.000      -0.230      -0.130
# Hamada_d_mcap_ratio_HML_for_GMKN_lag_60_days    -0.0746      0.022     -3.416      0.001      -0.117      -0.032
# Hamada_d_mcap_ratio_SMB_for_GMKN_lag_90_days    -0.0242      0.025     -0.961      0.336      -0.074       0.025
# Hamada_d_mcap_ratio_HML_for_GMKN_lag_90_days    -0.1286      0.020     -6.329      0.000      -0.168      -0.089
# MOM                                              0.1108      0.035      3.177      0.001       0.042       0.179
# MOM_lag_30_days                                 -0.1006      0.041     -2.430      0.015      -0.182      -0.019
# MOM_lag_60_days                                  0.0053      0.034      0.154      0.878      -0.062       0.073
# MOM_lag_90_days                                  0.0098      0.038      0.256      0.798      -0.065       0.085
# dollar_30d_return                                0.2406      0.034      7.107      0.000       0.174       0.307
# wti_30d_return                                  -0.0254      0.013     -2.026      0.043      -0.050      -0.001
# ==============================================================================
# Omnibus:                        1.023   Durbin-Watson:                   0.184
# Prob(Omnibus):                  0.600   Jarque-Bera (JB):                1.062
# Skew:                           0.017   Prob(JB):                        0.588
# Kurtosis:                       2.892   Cond. No.                         9.46
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <F test: F=array([[12.69079715]]), p=3.2443586673982974e-08, df_denom=1.96e+03, df_num=3>
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe719339610>
# ###################################################################################
# NVTK
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_NVTK_RM_Equity - risk free rate   R-squared (uncentered):                   0.552
# Model:                                                OLS   Adj. R-squared (uncentered):              0.548
# Method:                                     Least Squares   F-statistic:                              103.9
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                   3.99e-269
# Time:                                            19:27:39   Log-Likelihood:                          2912.6
# No. Observations:                                    1979   AIC:                                     -5789.
# Df Residuals:                                        1961   BIC:                                     -5689.
# Df Model:                                              18
# Covariance Type:                                      HC1
# ================================================================================================================
#                                                    coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_NVTK                         0.8078      0.029     27.752      0.000       0.751       0.865
# NVTK_RM_Equity_premium_lag_30_days              -0.0357      0.018     -2.015      0.044      -0.070      -0.001
# NVTK_RM_Equity_premium_lag_60_days              -0.0317      0.018     -1.785      0.074      -0.066       0.003
# NVTK_RM_Equity_premium_lag_90_days               0.0515      0.015      3.376      0.001       0.022       0.081
# Hamada_d_mcap_ratio_SMB_for_NVTK                -0.2148      0.030     -7.156      0.000      -0.274      -0.156
# Hamada_d_mcap_ratio_HML_for_NVTK                -0.1374      0.023     -5.995      0.000      -0.182      -0.092
# Hamada_d_mcap_ratio_SMB_for_NVTK_lag_30_days    -0.3494      0.032    -10.868      0.000      -0.412      -0.286
# Hamada_d_mcap_ratio_HML_for_NVTK_lag_30_days     0.1204      0.025      4.914      0.000       0.072       0.168
# Hamada_d_mcap_ratio_SMB_for_NVTK_lag_60_days     0.1155      0.029      4.013      0.000       0.059       0.172
# Hamada_d_mcap_ratio_HML_for_NVTK_lag_60_days    -0.0939      0.020     -4.789      0.000      -0.132      -0.055
# Hamada_d_mcap_ratio_SMB_for_NVTK_lag_90_days    -0.0757      0.031     -2.408      0.016      -0.137      -0.014
# Hamada_d_mcap_ratio_HML_for_NVTK_lag_90_days    -0.0742      0.019     -3.900      0.000      -0.111      -0.037
# MOM                                             -0.1957      0.034     -5.837      0.000      -0.261      -0.130
# MOM_lag_30_days                                 -0.1097      0.043     -2.525      0.012      -0.195      -0.025
# MOM_lag_60_days                                  0.2753      0.036      7.638      0.000       0.205       0.346
# MOM_lag_90_days                                  0.1238      0.039      3.196      0.001       0.048       0.200
# dollar_30d_return                                0.2399      0.029      8.294      0.000       0.183       0.297
# wti_30d_return                                   0.0636      0.012      5.199      0.000       0.040       0.088
# ==============================================================================
# Omnibus:                        5.114   Durbin-Watson:                   0.172
# Prob(Omnibus):                  0.078   Jarque-Bera (JB):                5.769
# Skew:                           0.045   Prob(JB):                       0.0559
# Kurtosis:                       3.249   Cond. No.                         9.28
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <F test: F=array([[40.79701872]]), p=1.4317013173068114e-25, df_denom=1.96e+03, df_num=3>
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe719339d30>
# ###################################################################################
# SNGS
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_SNGS_RM_Equity - risk free rate   R-squared (uncentered):                   0.616
# Model:                                                OLS   Adj. R-squared (uncentered):              0.611
# Method:                                     Least Squares   F-statistic:                              121.5
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                   2.75e-270
# Time:                                            19:27:39   Log-Likelihood:                          1744.0
# No. Observations:                                    1417   AIC:                                     -3452.
# Df Residuals:                                        1399   BIC:                                     -3357.
# Df Model:                                              18
# Covariance Type:                                      HC1
# ================================================================================================================
#                                                    coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_SNGS                         1.2398      0.040     30.881      0.000       1.161       1.319
# SNGS_RM_Equity_premium_lag_30_days               0.1430      0.027      5.334      0.000       0.090       0.196
# SNGS_RM_Equity_premium_lag_60_days               0.0042      0.022      0.193      0.847      -0.038       0.047
# SNGS_RM_Equity_premium_lag_90_days              -0.0110      0.020     -0.557      0.577      -0.050       0.028
# Hamada_d_mcap_ratio_SMB_for_SNGS                -0.2207      0.047     -4.701      0.000      -0.313      -0.129
# Hamada_d_mcap_ratio_HML_for_SNGS                 0.0100      0.028      0.355      0.723      -0.045       0.065
# Hamada_d_mcap_ratio_SMB_for_SNGS_lag_30_days    -0.0445      0.045     -0.993      0.321      -0.132       0.043
# Hamada_d_mcap_ratio_HML_for_SNGS_lag_30_days    -0.1283      0.033     -3.860      0.000      -0.193      -0.063
# Hamada_d_mcap_ratio_SMB_for_SNGS_lag_60_days     0.1733      0.043      4.073      0.000       0.090       0.257
# Hamada_d_mcap_ratio_HML_for_SNGS_lag_60_days     0.2855      0.032      8.935      0.000       0.223       0.348
# Hamada_d_mcap_ratio_SMB_for_SNGS_lag_90_days    -0.1597      0.049     -3.272      0.001      -0.255      -0.064
# Hamada_d_mcap_ratio_HML_for_SNGS_lag_90_days     0.0322      0.040      0.800      0.424      -0.047       0.111
# MOM                                             -0.2907      0.047     -6.131      0.000      -0.384      -0.198
# MOM_lag_30_days                                 -0.3699      0.049     -7.586      0.000      -0.465      -0.274
# MOM_lag_60_days                                  0.3396      0.052      6.524      0.000       0.238       0.442
# MOM_lag_90_days                                  0.2456      0.051      4.856      0.000       0.146       0.345
# dollar_30d_return                                0.0192      0.040      0.480      0.631      -0.059       0.097
# wti_30d_return                                  -0.0440      0.014     -3.143      0.002      -0.071      -0.017
# ==============================================================================
# Omnibus:                      153.715   Durbin-Watson:                   0.138
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              299.544
# Skew:                           0.686   Prob(JB):                     9.01e-66
# Kurtosis:                       4.786   Cond. No.                         9.57
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <F test: F=array([[15.46526676]]), p=6.700746479561342e-10, df_denom=1.4e+03, df_num=3>
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe7193393d0>
# ###################################################################################
# PLZL
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_PLZL_RM_Equity - risk free rate   R-squared (uncentered):                   0.628
# Model:                                                OLS   Adj. R-squared (uncentered):              0.619
# Method:                                     Least Squares   F-statistic:                              61.55
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                   3.10e-133
# Time:                                            19:27:39   Log-Likelihood:                          980.10
# No. Observations:                                     753   AIC:                                     -1924.
# Df Residuals:                                         735   BIC:                                     -1841.
# Df Model:                                              18
# Covariance Type:                                      HC1
# ================================================================================================================
#                                                    coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_PLZL                         0.2542      0.061      4.163      0.000       0.135       0.374
# PLZL_RM_Equity_premium_lag_30_days               0.0952      0.030      3.205      0.001       0.037       0.153
# PLZL_RM_Equity_premium_lag_60_days              -0.2459      0.030     -8.304      0.000      -0.304      -0.188
# PLZL_RM_Equity_premium_lag_90_days              -0.3583      0.035    -10.205      0.000      -0.427      -0.290
# Hamada_d_mcap_ratio_SMB_for_PLZL                 0.0404      0.064      0.636      0.525      -0.084       0.165
# Hamada_d_mcap_ratio_HML_for_PLZL                -0.0045      0.052     -0.085      0.932      -0.107       0.098
# Hamada_d_mcap_ratio_SMB_for_PLZL_lag_30_days     0.3755      0.069      5.411      0.000       0.240       0.512
# Hamada_d_mcap_ratio_HML_for_PLZL_lag_30_days    -0.1001      0.063     -1.590      0.112      -0.224       0.023
# Hamada_d_mcap_ratio_SMB_for_PLZL_lag_60_days     0.1671      0.070      2.389      0.017       0.030       0.304
# Hamada_d_mcap_ratio_HML_for_PLZL_lag_60_days    -0.2621      0.054     -4.866      0.000      -0.368      -0.157
# Hamada_d_mcap_ratio_SMB_for_PLZL_lag_90_days     0.3275      0.065      5.075      0.000       0.201       0.454
# Hamada_d_mcap_ratio_HML_for_PLZL_lag_90_days    -0.4294      0.062     -6.883      0.000      -0.552      -0.307
# MOM                                             -0.2534      0.075     -3.384      0.001      -0.400      -0.107
# MOM_lag_30_days                                 -0.0623      0.096     -0.650      0.516      -0.250       0.126
# MOM_lag_60_days                                  0.1535      0.067      2.293      0.022       0.022       0.285
# MOM_lag_90_days                                  0.6284      0.059     10.579      0.000       0.512       0.745
# dollar_30d_return                               -0.8333      0.138     -6.047      0.000      -1.103      -0.563
# wti_30d_return                                  -0.3717      0.031    -11.991      0.000      -0.433      -0.311
# ==============================================================================
# Omnibus:                        4.410   Durbin-Watson:                   0.313
# Prob(Omnibus):                  0.110   Jarque-Bera (JB):                5.390
# Skew:                          -0.006   Prob(JB):                       0.0675
# Kurtosis:                       3.414   Cond. No.                         12.9
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <F test: F=array([[5.89264507]]), p=0.0005628100202443545, df_denom=735, df_num=3>
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe719339c40>
# ###################################################################################
# TATN
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_TATN_RM_Equity - risk free rate   R-squared (uncentered):                   0.717
# Model:                                                OLS   Adj. R-squared (uncentered):              0.715
# Method:                                     Least Squares   F-statistic:                              204.8
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                        0.00
# Time:                                            19:27:40   Log-Likelihood:                          2982.4
# No. Observations:                                    1979   AIC:                                     -5929.
# Df Residuals:                                        1961   BIC:                                     -5828.
# Df Model:                                              18
# Covariance Type:                                      HC1
# ================================================================================================================
#                                                    coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_TATN                         1.1413      0.026     43.406      0.000       1.090       1.193
# TATN_RM_Equity_premium_lag_30_days              -0.0053      0.018     -0.299      0.765      -0.040       0.030
# TATN_RM_Equity_premium_lag_60_days               0.0313      0.018      1.766      0.077      -0.003       0.066
# TATN_RM_Equity_premium_lag_90_days               0.1661      0.015     11.301      0.000       0.137       0.195
# Hamada_d_mcap_ratio_SMB_for_TATN                -0.1078      0.028     -3.831      0.000      -0.163      -0.053
# Hamada_d_mcap_ratio_HML_for_TATN                 0.0716      0.019      3.812      0.000       0.035       0.108
# Hamada_d_mcap_ratio_SMB_for_TATN_lag_30_days    -0.0734      0.027     -2.750      0.006      -0.126      -0.021
# Hamada_d_mcap_ratio_HML_for_TATN_lag_30_days    -0.0813      0.025     -3.219      0.001      -0.131      -0.032
# Hamada_d_mcap_ratio_SMB_for_TATN_lag_60_days     0.0281      0.026      1.065      0.287      -0.024       0.080
# Hamada_d_mcap_ratio_HML_for_TATN_lag_60_days     0.1823      0.022      8.430      0.000       0.140       0.225
# Hamada_d_mcap_ratio_SMB_for_TATN_lag_90_days    -0.1029      0.031     -3.273      0.001      -0.165      -0.041
# Hamada_d_mcap_ratio_HML_for_TATN_lag_90_days     0.0864      0.020      4.261      0.000       0.047       0.126
# MOM                                              0.0201      0.031      0.639      0.523      -0.041       0.082
# MOM_lag_30_days                                  0.0601      0.040      1.508      0.132      -0.018       0.138
# MOM_lag_60_days                                 -0.1163      0.037     -3.134      0.002      -0.189      -0.044
# MOM_lag_90_days                                  0.0094      0.036      0.262      0.794      -0.061       0.080
# dollar_30d_return                                0.1232      0.030      4.161      0.000       0.065       0.181
# wti_30d_return                                   0.0887      0.013      6.815      0.000       0.063       0.114
# ==============================================================================
# Omnibus:                       31.582   Durbin-Watson:                   0.212
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               35.819
# Skew:                           0.255   Prob(JB):                     1.67e-08
# Kurtosis:                       3.417   Cond. No.                         9.37
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <F test: F=array([[11.3957728]]), p=2.0784916109535415e-07, df_denom=1.96e+03, df_num=3>
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe7193396d0>
# ###################################################################################
# ROSN
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_ROSN_RM_Equity - risk free rate   R-squared (uncentered):                   0.634
# Model:                                                OLS   Adj. R-squared (uncentered):              0.631
# Method:                                     Least Squares   F-statistic:                              145.0
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                        0.00
# Time:                                            19:27:40   Log-Likelihood:                          2762.1
# No. Observations:                                    1956   AIC:                                     -5488.
# Df Residuals:                                        1938   BIC:                                     -5388.
# Df Model:                                              18
# Covariance Type:                                      HC1
# ================================================================================================================
#                                                    coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_ROSN                         0.5943      0.020     30.421      0.000       0.556       0.633
# ROSN_RM_Equity_premium_lag_30_days              -0.1118      0.016     -6.988      0.000      -0.143      -0.080
# ROSN_RM_Equity_premium_lag_60_days              -0.0481      0.019     -2.482      0.013      -0.086      -0.010
# ROSN_RM_Equity_premium_lag_90_days               0.0096      0.017      0.576      0.564      -0.023       0.042
# Hamada_d_mcap_ratio_SMB_for_ROSN                 0.0058      0.019      0.301      0.763      -0.032       0.043
# Hamada_d_mcap_ratio_HML_for_ROSN                -0.0329      0.012     -2.684      0.007      -0.057      -0.009
# Hamada_d_mcap_ratio_SMB_for_ROSN_lag_30_days    -0.0214      0.019     -1.113      0.266      -0.059       0.016
# Hamada_d_mcap_ratio_HML_for_ROSN_lag_30_days    -0.0671      0.018     -3.747      0.000      -0.102      -0.032
# Hamada_d_mcap_ratio_SMB_for_ROSN_lag_60_days     0.0244      0.018      1.351      0.177      -0.011       0.060
# Hamada_d_mcap_ratio_HML_for_ROSN_lag_60_days    -0.0259      0.012     -2.108      0.035      -0.050      -0.002
# Hamada_d_mcap_ratio_SMB_for_ROSN_lag_90_days    -0.0731      0.019     -3.806      0.000      -0.111      -0.035
# Hamada_d_mcap_ratio_HML_for_ROSN_lag_90_days     0.0522      0.012      4.340      0.000       0.029       0.076
# MOM                                              0.0627      0.033      1.921      0.055      -0.001       0.127
# MOM_lag_30_days                                 -0.0842      0.049     -1.732      0.083      -0.180       0.011
# MOM_lag_60_days                                  0.0158      0.038      0.421      0.674      -0.058       0.089
# MOM_lag_90_days                                  0.0012      0.040      0.030      0.976      -0.078       0.080
# dollar_30d_return                                0.0713      0.034      2.100      0.036       0.005       0.138
# wti_30d_return                                   0.1357      0.014      9.674      0.000       0.108       0.163
# ==============================================================================
# Omnibus:                      123.643   Durbin-Watson:                   0.094
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              221.082
# Skew:                           0.464   Prob(JB):                     9.83e-49
# Kurtosis:                       4.360   Cond. No.                         9.28
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <F test: F=array([[2.71033593]]), p=0.043672415582813526, df_denom=1.94e+03, df_num=3>
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe719fe9af0>
# ###################################################################################
# MGNT
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_MGNT_RM_Equity - risk free rate   R-squared (uncentered):                   0.389
# Model:                                                OLS   Adj. R-squared (uncentered):              0.383
# Method:                                     Least Squares   F-statistic:                              70.36
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                   8.35e-197
# Time:                                            19:27:40   Log-Likelihood:                          2138.1
# No. Observations:                                    1979   AIC:                                     -4240.
# Df Residuals:                                        1961   BIC:                                     -4139.
# Df Model:                                              18
# Covariance Type:                                      HC1
# ================================================================================================================
#                                                    coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_MGNT                         0.5659      0.027     21.007      0.000       0.513       0.619
# MGNT_RM_Equity_premium_lag_30_days               0.0253      0.019      1.299      0.194      -0.013       0.063
# MGNT_RM_Equity_premium_lag_60_days               0.0977      0.030      3.247      0.001       0.039       0.157
# MGNT_RM_Equity_premium_lag_90_days               0.1297      0.018      7.154      0.000       0.094       0.165
# Hamada_d_mcap_ratio_SMB_for_MGNT                 0.1311      0.035      3.749      0.000       0.063       0.200
# Hamada_d_mcap_ratio_HML_for_MGNT                 0.2957      0.026     11.538      0.000       0.245       0.346
# Hamada_d_mcap_ratio_SMB_for_MGNT_lag_30_days     0.1161      0.035      3.332      0.001       0.048       0.184
# Hamada_d_mcap_ratio_HML_for_MGNT_lag_30_days     0.4018      0.033     12.147      0.000       0.337       0.467
# Hamada_d_mcap_ratio_SMB_for_MGNT_lag_60_days     0.2802      0.033      8.397      0.000       0.215       0.346
# Hamada_d_mcap_ratio_HML_for_MGNT_lag_60_days     0.0471      0.024      1.950      0.051      -0.000       0.095
# Hamada_d_mcap_ratio_SMB_for_MGNT_lag_90_days    -0.0322      0.036     -0.907      0.364      -0.102       0.037
# Hamada_d_mcap_ratio_HML_for_MGNT_lag_90_days     0.1301      0.024      5.396      0.000       0.083       0.177
# MOM                                             -0.1305      0.049     -2.665      0.008      -0.226      -0.035
# MOM_lag_30_days                                 -0.3931      0.061     -6.488      0.000      -0.512      -0.274
# MOM_lag_60_days                                  0.3840      0.056      6.903      0.000       0.275       0.493
# MOM_lag_90_days                                 -0.0190      0.050     -0.379      0.704      -0.117       0.079
# dollar_30d_return                               -0.2088      0.036     -5.855      0.000      -0.279      -0.139
# wti_30d_return                                  -0.0523      0.015     -3.552      0.000      -0.081      -0.023
# ==============================================================================
# Omnibus:                      205.409   Durbin-Watson:                   0.144
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              414.209
# Skew:                          -0.657   Prob(JB):                     1.14e-90
# Kurtosis:                       4.816   Cond. No.                         9.03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <F test: F=array([[55.85691448]]), p=1.2102524838703165e-34, df_denom=1.96e+03, df_num=3>
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe6e9246820>
# ###################################################################################
# MTSS
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_MTSS_RM_Equity - risk free rate   R-squared (uncentered):                   0.515
# Model:                                                OLS   Adj. R-squared (uncentered):              0.511
# Method:                                     Least Squares   F-statistic:                              76.02
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                   7.07e-210
# Time:                                            19:27:40   Log-Likelihood:                          2699.4
# No. Observations:                                    1979   AIC:                                     -5363.
# Df Residuals:                                        1961   BIC:                                     -5262.
# Df Model:                                              18
# Covariance Type:                                      HC1
# ================================================================================================================
#                                                    coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_MTSS                         0.5499      0.023     24.176      0.000       0.505       0.595
# MTSS_RM_Equity_premium_lag_30_days              -0.0399      0.022     -1.836      0.066      -0.083       0.003
# MTSS_RM_Equity_premium_lag_60_days              -0.0009      0.019     -0.045      0.964      -0.038       0.036
# MTSS_RM_Equity_premium_lag_90_days              -0.0313      0.019     -1.688      0.091      -0.068       0.005
# Hamada_d_mcap_ratio_SMB_for_MTSS                -0.0095      0.024     -0.389      0.697      -0.057       0.038
# Hamada_d_mcap_ratio_HML_for_MTSS                -0.0480      0.020     -2.450      0.014      -0.086      -0.010
# Hamada_d_mcap_ratio_SMB_for_MTSS_lag_30_days     0.0479      0.024      2.007      0.045       0.001       0.095
# Hamada_d_mcap_ratio_HML_for_MTSS_lag_30_days    -0.0020      0.025     -0.078      0.938      -0.051       0.047
# Hamada_d_mcap_ratio_SMB_for_MTSS_lag_60_days     0.0397      0.022      1.789      0.074      -0.004       0.083
# Hamada_d_mcap_ratio_HML_for_MTSS_lag_60_days    -0.1070      0.018     -5.831      0.000      -0.143      -0.071
# Hamada_d_mcap_ratio_SMB_for_MTSS_lag_90_days    -0.1267      0.023     -5.573      0.000      -0.171      -0.082
# Hamada_d_mcap_ratio_HML_for_MTSS_lag_90_days     0.0524      0.017      3.134      0.002       0.020       0.085
# MOM                                             -0.0514      0.036     -1.440      0.150      -0.121       0.019
# MOM_lag_30_days                                 -0.0187      0.052     -0.360      0.719      -0.120       0.083
# MOM_lag_60_days                                  0.2862      0.046      6.225      0.000       0.196       0.376
# MOM_lag_90_days                                 -0.2062      0.044     -4.729      0.000      -0.292      -0.121
# dollar_30d_return                               -0.3202      0.039     -8.222      0.000      -0.397      -0.244
# wti_30d_return                                  -0.0260      0.011     -2.436      0.015      -0.047      -0.005
# ==============================================================================
# Omnibus:                      103.713   Durbin-Watson:                   0.119
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              186.915
# Skew:                          -0.394   Prob(JB):                     2.58e-41
# Kurtosis:                       4.283   Cond. No.                         9.12
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <F test: F=array([[3.16940499]]), p=0.02346305209684625, df_denom=1.96e+03, df_num=3>
# ...
# ----------------------------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_KMAZ                         0.3809      0.023     16.378      0.000       0.335       0.426
# KMAZ_RM_Equity_premium_lag_30_days               0.0843      0.028      3.011      0.003       0.029       0.139
# KMAZ_RM_Equity_premium_lag_60_days              -0.1223      0.025     -4.835      0.000      -0.172      -0.073
# KMAZ_RM_Equity_premium_lag_90_days              -0.0689      0.023     -3.011      0.003      -0.114      -0.024
# Hamada_d_mcap_ratio_SMB_for_KMAZ                -0.0106      0.031     -0.346      0.729      -0.070       0.049
# Hamada_d_mcap_ratio_HML_for_KMAZ                -0.0511      0.021     -2.409      0.016      -0.093      -0.010
# Hamada_d_mcap_ratio_SMB_for_KMAZ_lag_30_days     0.2043      0.029      6.947      0.000       0.147       0.262
# Hamada_d_mcap_ratio_HML_for_KMAZ_lag_30_days    -0.0774      0.022     -3.537      0.000      -0.120      -0.035
# Hamada_d_mcap_ratio_SMB_for_KMAZ_lag_60_days     0.1249      0.023      5.396      0.000       0.080       0.170
# Hamada_d_mcap_ratio_HML_for_KMAZ_lag_60_days     0.0261      0.019      1.341      0.180      -0.012       0.064
# Hamada_d_mcap_ratio_SMB_for_KMAZ_lag_90_days    -0.1077      0.025     -4.226      0.000      -0.158      -0.058
# Hamada_d_mcap_ratio_HML_for_KMAZ_lag_90_days     0.0268      0.024      1.140      0.254      -0.019       0.073
# MOM                                             -0.0130      0.064     -0.204      0.838      -0.137       0.112
# MOM_lag_30_days                                 -0.1048      0.056     -1.871      0.061      -0.215       0.005
# MOM_lag_60_days                                 -0.0480      0.056     -0.862      0.388      -0.157       0.061
# MOM_lag_90_days                                  0.1673      0.062      2.700      0.007       0.046       0.289
# dollar_30d_return                                0.0128      0.042      0.302      0.763      -0.070       0.096
# wti_30d_return                                   0.0815      0.015      5.504      0.000       0.052       0.111
# ==============================================================================
# Omnibus:                      325.897   Durbin-Watson:                   0.139
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              697.699
# Skew:                           0.956   Prob(JB):                    3.14e-152
# Kurtosis:                       5.192   Cond. No.                         9.14
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <F test: F=array([[2.70891655]]), p=0.04375237633752203, df_denom=1.96e+03, df_num=3>
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe69825d610>
# ###################################################################################
# RASP
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_RASP_RM_Equity - risk free rate   R-squared (uncentered):                   0.484
# Model:                                                OLS   Adj. R-squared (uncentered):              0.480
# Method:                                     Least Squares   F-statistic:                              80.75
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                   1.70e-220
# Time:                                            19:27:41   Log-Likelihood:                          1423.6
# No. Observations:                                    1979   AIC:                                     -2811.
# Df Residuals:                                        1961   BIC:                                     -2711.
# Df Model:                                              18
# Covariance Type:                                      HC1
# ================================================================================================================
#                                                    coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_RASP                         1.2094      0.043     28.390      0.000       1.126       1.293
# RASP_RM_Equity_premium_lag_30_days               0.1256      0.020      6.400      0.000       0.087       0.164
# RASP_RM_Equity_premium_lag_60_days               0.0987      0.018      5.561      0.000       0.064       0.133
# RASP_RM_Equity_premium_lag_90_days              -0.0584      0.015     -3.861      0.000      -0.088      -0.029
# Hamada_d_mcap_ratio_SMB_for_RASP                -0.1151      0.048     -2.397      0.017      -0.209      -0.021
# Hamada_d_mcap_ratio_HML_for_RASP                 0.0270      0.030      0.898      0.369      -0.032       0.086
# Hamada_d_mcap_ratio_SMB_for_RASP_lag_30_days     0.8134      0.052     15.657      0.000       0.712       0.915
# Hamada_d_mcap_ratio_HML_for_RASP_lag_30_days     0.3604      0.042      8.641      0.000       0.279       0.442
# Hamada_d_mcap_ratio_SMB_for_RASP_lag_60_days    -0.2577      0.047     -5.513      0.000      -0.349      -0.166
# Hamada_d_mcap_ratio_HML_for_RASP_lag_60_days     0.0644      0.036      1.773      0.076      -0.007       0.136
# Hamada_d_mcap_ratio_SMB_for_RASP_lag_90_days     0.2048      0.050      4.087      0.000       0.107       0.303
# Hamada_d_mcap_ratio_HML_for_RASP_lag_90_days    -0.0854      0.044     -1.928      0.054      -0.172       0.001
# MOM                                             -0.2922      0.060     -4.869      0.000      -0.410      -0.175
# MOM_lag_30_days                                  0.0550      0.086      0.641      0.521      -0.113       0.223
# MOM_lag_60_days                                  0.0854      0.075      1.138      0.255      -0.062       0.233
# MOM_lag_90_days                                  0.0232      0.077      0.301      0.763      -0.127       0.174
# dollar_30d_return                               -0.4721      0.072     -6.560      0.000      -0.613      -0.331
# wti_30d_return                                  -0.1382      0.019     -7.284      0.000      -0.175      -0.101
# ==============================================================================
# Omnibus:                       33.040   Durbin-Watson:                   0.157
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               34.608
# Skew:                           0.302   Prob(JB):                     3.06e-08
# Kurtosis:                       3.234   Cond. No.                         9.07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <F test: F=array([[9.14053072]]), p=5.246846160907281e-06, df_denom=1.96e+03, df_num=3>
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe69825d6d0>
# ###################################################################################
# OGKB
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_OGKB_RM_Equity - risk free rate   R-squared (uncentered):                   0.534
# Model:                                                OLS   Adj. R-squared (uncentered):              0.529
# Method:                                     Least Squares   F-statistic:                              93.89
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                   6.00e-248
# Time:                                            19:27:41   Log-Likelihood:                          1790.2
# No. Observations:                                    1956   AIC:                                     -3544.
# Df Residuals:                                        1938   BIC:                                     -3444.
# Df Model:                                              18
# Covariance Type:                                      HC1
# ================================================================================================================
#                                                    coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_OGKB                         0.5763      0.027     21.227      0.000       0.523       0.630
# OGKB_RM_Equity_premium_lag_30_days              -0.0449      0.018     -2.513      0.012      -0.080      -0.010
# OGKB_RM_Equity_premium_lag_60_days              -0.0730      0.018     -4.108      0.000      -0.108      -0.038
# OGKB_RM_Equity_premium_lag_90_days               0.0711      0.019      3.710      0.000       0.034       0.109
# Hamada_d_mcap_ratio_SMB_for_OGKB                -0.2541      0.029     -8.770      0.000      -0.311      -0.197
# Hamada_d_mcap_ratio_HML_for_OGKB                -0.0380      0.016     -2.303      0.021      -0.070      -0.006
# Hamada_d_mcap_ratio_SMB_for_OGKB_lag_30_days     0.5181      0.031     16.852      0.000       0.458       0.578
# Hamada_d_mcap_ratio_HML_for_OGKB_lag_30_days    -0.2932      0.028    -10.398      0.000      -0.348      -0.238
# Hamada_d_mcap_ratio_SMB_for_OGKB_lag_60_days     0.1571      0.027      5.864      0.000       0.105       0.210
# Hamada_d_mcap_ratio_HML_for_OGKB_lag_60_days    -0.1054      0.025     -4.291      0.000      -0.154      -0.057
# Hamada_d_mcap_ratio_SMB_for_OGKB_lag_90_days     0.1755      0.029      6.081      0.000       0.119       0.232
# Hamada_d_mcap_ratio_HML_for_OGKB_lag_90_days     0.1478      0.022      6.801      0.000       0.105       0.190
# MOM                                             -0.0290      0.054     -0.536      0.592      -0.135       0.077
# MOM_lag_30_days                                  0.1740      0.065      2.672      0.008       0.046       0.302
# MOM_lag_60_days                                 -0.1090      0.064     -1.697      0.090      -0.235       0.017
# MOM_lag_90_days                                 -0.0723      0.063     -1.143      0.253      -0.196       0.052
# dollar_30d_return                               -0.1544      0.058     -2.673      0.008      -0.268      -0.041
# wti_30d_return                                  -0.0137      0.018     -0.775      0.438      -0.049       0.021
# ==============================================================================
# Omnibus:                       55.277   Durbin-Watson:                   0.161
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               70.186
# Skew:                           0.330   Prob(JB):                     5.74e-16
# Kurtosis:                       3.651   Cond. No.                         9.41
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <F test: F=array([[27.81106551]]), p=1.3200421539397856e-17, df_denom=1.94e+03, df_num=3>
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe69825dee0>
# ###################################################################################
# VZRZ
#                                            OLS Regression Results
# ===========================================================================================================
# Dep. Variable:     return_VZRZ_RM_Equity - risk free rate   R-squared (uncentered):                   0.217
# Model:                                                OLS   Adj. R-squared (uncentered):              0.210
# Method:                                     Least Squares   F-statistic:                              28.89
# Date:                                    Thu, 29 Apr 2021   Prob (F-statistic):                    5.91e-87
# Time:                                            19:27:41   Log-Likelihood:                          1867.2
# No. Observations:                                    1979   AIC:                                     -3698.
# Df Residuals:                                        1961   BIC:                                     -3598.
# Df Model:                                              18
# Covariance Type:                                      HC1
# ================================================================================================================
#                                                    coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------
# Hamada_beta_MRP_for_VZRZ                         0.1331      0.018      7.438      0.000       0.098       0.168
# VZRZ_RM_Equity_premium_lag_30_days              -0.1228      0.022     -5.540      0.000      -0.166      -0.079
# VZRZ_RM_Equity_premium_lag_60_days              -0.0703      0.022     -3.142      0.002      -0.114      -0.026
# VZRZ_RM_Equity_premium_lag_90_days              -0.1816      0.021     -8.511      0.000      -0.223      -0.140
# Hamada_d_mcap_ratio_SMB_for_VZRZ                 0.1707      0.025      6.932      0.000       0.122       0.219
# Hamada_d_mcap_ratio_HML_for_VZRZ                 0.0478      0.017      2.770      0.006       0.014       0.082
# Hamada_d_mcap_ratio_SMB_for_VZRZ_lag_30_days     0.3419      0.024     14.000      0.000       0.294       0.390
# Hamada_d_mcap_ratio_HML_for_VZRZ_lag_30_days     0.1141      0.021      5.484      0.000       0.073       0.155
# Hamada_d_mcap_ratio_SMB_for_VZRZ_lag_60_days    -0.0049      0.024     -0.207      0.836      -0.051       0.042
# Hamada_d_mcap_ratio_HML_for_VZRZ_lag_60_days     0.0378      0.017      2.184      0.029       0.004       0.072
# Hamada_d_mcap_ratio_SMB_for_VZRZ_lag_90_days     0.0769      0.025      3.046      0.002       0.027       0.126
# Hamada_d_mcap_ratio_HML_for_VZRZ_lag_90_days    -0.1285      0.016     -8.138      0.000      -0.159      -0.098
# MOM                                             -0.3111      0.055     -5.691      0.000      -0.418      -0.204
# MOM_lag_30_days                                 -0.0526      0.074     -0.708      0.479      -0.198       0.093
# MOM_lag_60_days                                 -0.0175      0.062     -0.283      0.777      -0.139       0.104
# MOM_lag_90_days                                  0.2483      0.059      4.214      0.000       0.133       0.364
# dollar_30d_return                               -0.3252      0.060     -5.377      0.000      -0.444      -0.207
# wti_30d_return                                  -0.0953      0.019     -5.097      0.000      -0.132      -0.059
# ==============================================================================
# Omnibus:                       12.175   Durbin-Watson:                   0.126
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               15.743
# Skew:                          -0.075   Prob(JB):                     0.000382
# Kurtosis:                       3.411   Cond. No.                         9.69
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# <F test: F=array([[30.26166818]]), p=4.027065840744734e-19, df_denom=1.96e+03, df_num=3>
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7fe698254cd0>

# %% [markdown]
# # Make a plot of R2 adj and MSE average for all companies

# %%
R2_total = pd.DataFrame([r_2_results_capm,
                        r_2_results_ff3,
                        r_2_results_carh,
                        r_2_results_carh_l, 
                        r_2_results_carh_l_al, 
                        r_2_results_carh_l_al_spec])


names = {'SBER':'Сбербанк', 'GAZP':'Газпром', 'LKOH':'Лукойл','GMKN':'Норникель' ,'NVTK':'Новатэк', 'SNGS':'Сургутнефтегаз',
         'PLZL':'Полюс','TATN':'Татнефть','ROSN':'Роснефть','MGNT':'Магнит','MTSS':'МТС', 'MOEX':'МосБиржа', 
         'IRAO':'Интер РАО', 'NLMK':'НЛМК', 'ALRS':'Алроса','CHMF':'Северсталь','VTBR':'ВТБ','RTKM':'Ростелеком',
         'PHOR':'Фосагро','AFKS':'АФК «Система»','MAGN':'ММК','PIKK':'ПИК',
         'HYDR':'Русгидро','FEES':'ФСК ЕЭС','AFLT':'Аэрофлот','LSRG':'ЛСР','RSTI':'Россети','UPRO':'Юнипро',
         'LNTA':'Лента','MVID':'М.Видео','TRMK':'ТМК','MTLR':'Мечел','NMTP':'НМТП','AKRN':'Акрон',
         'MSNG':'Мосэнерго','URKA':'Уралкалий','BANE':'Башнефть','VSMO':'ВСМПО-Ависма','NKNC':'Нижнекамскнефтехим',
         'GCHE':'Черкизово','SVAV':'Соллерс','MSTT':'Мостотрест','BSPB':'Банк Санкт-Петербург', 'MSRS':'МОЭСК',
         'KMAZ':'Камаз','RASP':'Распадская','OGKB':'ОГК №2','VZRZ':'Банк "Возрождение"'}
R2_total.columns = names.values()
R2_total.index = ['CAPM','Фама-Френч','Кархарт','Кархарт + лаги','Кархарт + лаги и автолаги', 'Кархарт + лаги и автолаги + специфические']
R2_total['Средний исправленный R2'] = R2_total.mean(axis = 1)

MSE_total = pd.DataFrame([mse_results_capm,
                          mse_results_ff3,
                          mse_results_carh,
                          mse_results_carh_l, 
                          mse_results_carh_l_al, 
                          mse_results_carh_l_al_spec])

MSE_total.columns = names.values()
MSE_total.index = ['CAPM','Фама-Френч','Кархарт','Кархарт + лаги','Кархарт + лаги и автолаги', 'Кархарт + лаги и автолаги + специфические']
MSE_total['Средний MSE'] = MSE_total.mean(axis = 1)

# %% [markdown]
# # Plot summary

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# Create figure with secondary y-axis
fig = make_subplots(specs=[[{"secondary_y": True}]])

# Add traces
fig.add_trace(
    go.Scatter(x=MSE_total.index, y=MSE_total['Средний MSE'],mode='lines+markers',name='Средний MSE'),
    secondary_y=True,
)

fig.add_trace(
    go.Scatter(x=R2_total.index, y=R2_total['Средний исправленный R2'],mode='lines+markers',name='Средний исправленный R2'),
    secondary_y=False,
)
    

    

# Set y-axes titles
fig.update_yaxes(title_text="Средний по всем компаниям MSE", secondary_y=True)
fig.update_yaxes(title_text="Средний по всем компаниям исправленный R2", secondary_y=False)
fig.update_layout(xaxis_title = 'Модель',autosize=True,
                 legend=dict(yanchor="middle", y=0.5, xanchor="left", x=0.6))

fig.show()
# Out:
# <div>                            <div id="5939d25f-b1ea-424f-8912-9ae88481c6b7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5939d25f-b1ea-424f-8912-9ae88481c6b7")) {                    Plotly.newPlot(                        "5939d25f-b1ea-424f-8912-9ae88481c6b7",                        [{"mode": "lines+markers", "name": "\u0421\u0440\u0435\u0434\u043d\u0438\u0439 MSE", "type": "scatter", "x": ["CAPM", "\u0424\u0430\u043c\u0430-\u0424\u0440\u0435\u043d\u0447", "\u041a\u0430\u0440\u0445\u0430\u0440\u0442", "\u041a\u0430\u0440\u0445\u0430\u0440\u0442 + \u043b\u0430\u0433\u0438", "\u041a\u0430\u0440\u0445\u0430\u0440\u0442 + \u043b\u0430\u0433\u0438 \u0438 \u0430\u0432\u0442\u043e\u043b\u0430\u0433\u0438", "\u041a\u0430\u0440\u0445\u0430\u0440\u0442 + \u043b\u0430\u0433\u0438 \u0438 \u0430\u0432\u0442\u043e\u043b\u0430\u0433\u0438 + \u0441\u043f\u0435\u0446\u0438\u0444\u0438\u0447\u0435\u0441\u043a\u0438\u0435"], "xaxis": "x", "y": [0.009573062243278236, 0.009299021562584558, 0.00913565252800578, 0.0073121546394577805, 0.007056239165436317, 0.006751339235289156], "yaxis": "y2"}, {"mode": "lines+markers", "name": "\u0421\u0440\u0435\u0434\u043d\u0438\u0439 \u0438\u0441\u043f\u0440\u0430\u0432\u043b\u0435\u043d\u043d\u044b\u0439 R2", "type": "scatter", "x": ["CAPM", "\u0424\u0430\u043c\u0430-\u0424\u0440\u0435\u043d\u0447", "\u041a\u0430\u0440\u0445\u0430\u0440\u0442", "\u041a\u0430\u0440\u0445\u0430\u0440\u0442 + \u043b\u0430\u0433\u0438", "\u041a\u0430\u0440\u0445\u0430\u0440\u0442 + \u043b\u0430\u0433\u0438 \u0438 \u0430\u0432\u0442\u043e\u043b\u0430\u0433\u0438", "\u041a\u0430\u0440\u0445\u0430\u0440\u0442 + \u043b\u0430\u0433\u0438 \u0438 \u0430\u0432\u0442\u043e\u043b\u0430\u0433\u0438 + \u0441\u043f\u0435\u0446\u0438\u0444\u0438\u0447\u0435\u0441\u043a\u0438\u0435"], "xaxis": "x", "y": [0.2626300872481097, 0.27961497062891133, 0.29257728935454835, 0.43062371152789586, 0.4510512584463083, 0.4775985250902736], "yaxis": "y"}],                        {"autosize": true, "legend": {"x": 0.6, "xanchor": "left", "y": 0.5, "yanchor": "middle"}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.22222222222222 ...
